# %% [markdown]
# # Видобуток та збагачення структурованих даних

# %% [markdown]
# ### ТЕОРЕТИЧНА ЧАСТИНА ТА ПРИКЛАДИ

# %% [markdown]
# Для роботи з структурованими табличними даними, які розміщені в реляційній БД [SQLite](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwiUyMOv1orvAhWDK3cKHac9DyMQFjAAegQIBxAD&url=https%3A%2F%2Fru.wikipedia.org%2Fwiki%2FSQLite&usg=AOvVaw1s-RMK2VC2tXyDZxZXDYDo) в Python передбачена стандартна бібліотека [sqlite3](https://docs.python.org/3/library/sqlite3.html)

# %%
# підключення бібліотеки
import sqlite3

# %% [markdown]
# #### ПРИКЛАД ВИЛУЧЕННЯ ДАНИХ З БД
# Створити БД SQLite з ім'ям `FIT-3m`, та імпорувати в неї таблицю, що містить журнал групи `jornal`

# %%
# створюємо з'єднання з БД
conn = sqlite3.connect("FIT-3m.db")

# %% [markdown]
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %%
# створюємо об'єкт `cursor`, що відповідає за реалізацію операцій з таблицями БД
cur = conn.cursor()

# %%
print(type(cur), end='\n\n')
print(dir(cur))
# Out:
# <class 'sqlite3.Cursor'>
#
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'arraysize', 'close', 'connection', 'description', 'execute', 'executemany', 'executescript', 'fetchall', 'fetchmany', 'fetchone', 'lastrowid', 'row_factory', 'rowcount', 'setinputsizes', 'setoutputsize']

# %% [markdown]
# ##### виведемо ВСІ записи таблиці `jornal`

# %%
# створимо інстанс для операції `SELECT`
students_cur = cur.execute("SELECT * FROM Jornal")

# будуємо список записів за допомогою метода `fetchall()`
students_list = students_cur.fetchall()

_ = [print(x) for x in students_list]
# Out:
# ('Адаменко', 'Назар', 'N.Adamenko')
# ('Акішев', 'Володимир', 'v.akishev')
# ('Акунішніков', 'Єгор', 'Y.Akunishnikov')
# ('Артюх', 'Федір', 'f.artyukh')
# ('Барабаш', 'Нікіта', None)
# ('Бойчас', 'Валентин', 'v.boychas')
# ('Будюка', 'Тимур', 'T.Budyuka')
# ('Горб', 'Богдан', 'B.Horb')
# ('Дьяков', 'Денис', 'D.Dyakov')
# ('Іванченко', 'Сергій', None)
# ('Колесник', 'Дмитро', 'D.Kolesnyk')
# ('Мозговенко', 'Денис', 'd.mozhovenko')
# ('Муха', 'Кирило', None)
# ('Назаренко', 'Катерина', None)
# ('Очеретний', 'Олексій', 'O.Ocheretnyy')
# ('Поліщук', 'Аліна', None)
# ('Поліщук', 'Владислав', None)
# ('Полюхович', 'Аліна', 'A.Polyukhovych')
# ('Старовойтов', 'Олександр', 'O.Starovoytov')
# ('Тарнавський', 'Ростислав', None)
# ('Тимошенко', 'Євгеній', 'Y.Tymoshenko')
# ('Харчевка', 'Іван', 'I.Kharchevka')

# %% [markdown]
# #### ПРИКЛАД ЗБАГАЧЕННЯ ДАНИХ З ЗОВНІШНЬОГО ДЖЕРЕЛА
#
# Додати до списка студентів їх оцінки за вступне тестування, які розташовані в csv файлі `test_result.csv`

# %% [markdown]
# імпортуємо `test_result.csv` в робочу БД як таблицю `test`
#
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %% [markdown]
# ##### Cтворимо нову таблицю, яка буде містити вміст таблиці `jornal` та поле оцінок з таблиці `test`

# %%
# створимо вираз на побудову пустої таблиці `jornal_test` з відповідними полями
sql_stmt = "CREATE TABLE IF NOT EXISTS jornal_test \
              (Surname TEXT,         \
               Name TEXT,            \
               Email TEXT,           \
               Test_result INT);"

# виконаемо запит на створення таблиці
cur.execute(sql_stmt)

# перевіримо стан виконання операції - виведемо список таблиць
tables_list = cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
tables_list.fetchall()
# Out:
# [('Jornal',), ('jornal_test',)]

# %%
# створимо запит на об'єднання таблиць 'jornal' та 'test' по прізвищу студента
sql_stmt = "SELECT Jornal.*, jornal_test.Test_result FROM  \
            Jornal LEFT JOIN jornal_test ON Jornal.Surname = jornal_test.Surname"

# для перевірки виконаємо і виведемо результати запиту
cur.execute(sql_stmt).fetchall()
# Out:
# [('Адаменко', 'Назар', 'N.Adamenko', None),
#  ('Акішев', 'Володимир', 'v.akishev', None),
#  ('Акунішніков', 'Єгор', 'Y.Akunishnikov', None),
#  ('Артюх', 'Федір', 'f.artyukh', None),
#  ('Барабаш', 'Нікіта', None, None),
#  ('Бойчас', 'Валентин', 'v.boychas', None),
#  ('Будюка', 'Тимур', 'T.Budyuka', None),
#  ('Горб', 'Богдан', 'B.Horb', None),
#  ('Дьяков', 'Денис', 'D.Dyakov', None),
#  ('Іванченко', 'Сергій', None, None),
#  ('Колесник', 'Дмитро', 'D.Kolesnyk', None),
#  ('Мозговенко', 'Денис', 'd.mozhovenko', None),
#  ('Муха', 'Кирило', None, None),
#  ('Назаренко', 'Катерина', None, None),
#  ('Очеретний', 'Олексій', 'O.Ocheretnyy', None),
#  ('Поліщук', 'Аліна', None, None),
#  ('Поліщук', 'Владислав', None, None),
#  ('Полюхович', 'Аліна', 'A.Polyukhovych', None),
#  ('Старовойтов', 'Олександр', 'O.Starovoytov', None),
#  ('Тарнавський', 'Ростислав', None, None),
#  ('Тимошенко', 'Євгеній', 'Y.Tymoshenko', None),
#  ('Харчевка', 'Іван', 'I.Kharchevka', None)]

# %%
# заповнимо пусту таблицю результатми  запиту на злиття
_ = cur.execute("INSERT INTO jornal_test " + sql_stmt)

# %%
# збережемо вміст нової таблиці в список
jornal_test_list = cur.execute("SELECT * FROM jornal_test").fetchall()

_ = [print(x) for x in jornal_test_list]
# Out:
# ('Адаменко', 'Назар', 'N.Adamenko', None)
# ('Акішев', 'Володимир', 'v.akishev', None)
# ('Акунішніков', 'Єгор', 'Y.Akunishnikov', None)
# ('Артюх', 'Федір', 'f.artyukh', None)
# ('Барабаш', 'Нікіта', None, None)
# ('Бойчас', 'Валентин', 'v.boychas', None)
# ('Будюка', 'Тимур', 'T.Budyuka', None)
# ('Горб', 'Богдан', 'B.Horb', None)
# ('Дьяков', 'Денис', 'D.Dyakov', None)
# ('Іванченко', 'Сергій', None, None)
# ('Колесник', 'Дмитро', 'D.Kolesnyk', None)
# ('Мозговенко', 'Денис', 'd.mozhovenko', None)
# ('Муха', 'Кирило', None, None)
# ('Назаренко', 'Катерина', None, None)
# ('Очеретний', 'Олексій', 'O.Ocheretnyy', None)
# ('Поліщук', 'Аліна', None, None)
# ('Поліщук', 'Владислав', None, None)
# ('Полюхович', 'Аліна', 'A.Polyukhovych', None)
# ('Старовойтов', 'Олександр', 'O.Starovoytov', None)
# ('Тарнавський', 'Ростислав', None, None)
# ('Тимошенко', 'Євгеній', 'Y.Tymoshenko', None)
# ('Харчевка', 'Іван', 'I.Kharchevka', None)

# %%
# завершимо всі транзакції
conn.commit()

# закріємо з'єднання
conn.close()

# %% [markdown]
# #### ПРИКЛАД  ДЕСКРИПТИВНОГО АНАЛІЗУ ДАНИХ
#
# Провести [попередній аналіз](https://ru.wikipedia.org/wiki/Описательная_статистика) отриманих даних з ціллю виявленя відхилень, помилок та інших непридатних даних.

# %% [markdown]
# Сведемо результати аналізу в таблицю, яка має наступний вигляд:
#
# №| Показчик | Значення
# :--:|:-------|-------:
# 1| кількість спостережень | xx
# 2| кількість пустих значень | xx
# 4| середній бал|  xx.x
# 5| максимальний бал | xx
# 6| мінімальний бал  | xx
# 7| стандартне відхилення | xx.x
# 8| розмах вариації  | xx

# %%
# підключимо бібліотеку 'numpy' і дамо їй аліас 'np'
import numpy as np

# %% [markdown]
# ознайомитись з призначенням, можливостями та основним функціями [бібліотеки numpy](https://numpy.org)

# %%
# перетворимо список студетів в numpay матрицю
jornal_test_arr = np.array(jornal_test_list)

# %%
print(type (jornal_test_arr), jornal_test_arr.shape)
# Out:
# <class 'numpy.ndarray'> (22, 4)

# %%
# створимо масив с результатами тестів 
test_result = np.delete(jornal_test_arr, [0,1,2], 1)

# %%
# Значення 'None' - не є числом, то заміним його на 0
test_result[test_result == None] = 0

# %%
# будуємо словник з вихідними розрахунками
result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
    "середній бал"             : round(np.mean(test_result),1),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result),#[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result)#[np.nonzero(test_result)]) 
    }

# %%
result_dict
# Out:
# {'кількість спостережень': 22,
#  'кількість пустих значень': 22,
#  'середній бал': 0.0,
#  'максимальний бал': 0,
#  'мінімальний бал': 0,
#  'стандартне відхилення': 0.0,
#  'розмах вариації': 0}

# %%
# вивести шапку
print(
"""
=======================================
№  : ПОКАЗЧИК               : ЗНАЧЕННЯ     
=======================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1
# Out:
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     22
# 2   кількість пустих значень   22
# 3   середній бал               0.0
# 4   максимальний бал           0
# 5   мінімальний бал            0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0

# %% [markdown]
# ### ІНДИВІДУАЛЬНЕ ЗАВДАННЯ

# %% [markdown]
# Користуючись результатами, що отримані в [Лабораторній роботі № 3](https://shkliarskiy.moodlecloud.com/mod/page/view.php?id=1193) виконати процедури видобутку, збагачення та попереднього аналізу даних.
#
# __Постановка__: В 3-й лабораторній роботі отримано показчик, що характеризує окрему властивість квартири (ціна, метраж та ін.).
# Необхідно:
# 1. Відобразити цей показчик на адресу квартири, яка знаходиться в файлі `street_name.csv`, тобто побудувати новий файл `street_flat_propery.csv` якій містить 2 колонки: _<назва вулиці> <ваш показчик>_
# 2. На основі цьго файлу зробити відповідну таблицю в _SQLite_ та збагатити цю дані в цій таблиці назвою району де розташована квартира (дані по районах додаються)
# 3. Провести попередній аналіз отриманих даних - вивести первинні статистики показчика по районах (_середне_ , _мінімальне_ , _максимальне_ і т.д. - див. приклад вище)

# %%
# Злиття файлу з показчиком та файлу з назвами вулиць в новий файл

YOUR_FILE = r"./aprt_year.txt"
with open(YOUR_FILE) as f1, \
     open('kiev-districts.csv', encoding="utf8") as f2, \
     open(r'./street_flat_propery.csv', 'w+', encoding="utf8") as f3:
    
    for x, y in zip(f1, f2):
        line = f'{x[:-1].strip()},{y[:-1].strip()}\n'
        print(line)
        f3.write(line)
# Out:
# year,street, type, district
#
# 2015,9-го Травня,вулиця,Святошинський
#
# 0,Абрикосова,вулиця,Оболонський
#
# 2011,Абрикосова,вулиця,Дарницький
#
# 1902,Абрикосова,вулиця,Подільський
#
# 2014,Августина Волошина,вулиця,Солом’янський
#
# 2009,Авдєєнка Генерала,вулиця,Святошинський
#
# 2018,Автозаводська,вулиця,Оболонський
#
# 2012,Автозаводський ,провулок,Оболонський
#
# 2017,Автопаркова,вулиця,Дарницький
#
# 1980,Авторемонтна,вулиця,Солом'янський
#
# 2012,Автотранспортна,вулиця,Дарницький
#
# 0,Агітаторська,вулиця,Солом'янський
#
# 2018,Агрегатна,вулиця,Оболонський
#
# 1985,Аеродромна,вулиця,Солом'янський
#
# 2017,Азербайджанська,вулиця,Дніпровський
#
# 1981,Азовська,вулиця,Солом'янський
#
# 2016,Айвазовського,провулок,Шевченківський
#
# 0,Академіка Єфремова,вулиця,Святошинський
#
# 1987,Академіка Оппокова,вулиця,Оболонський
#
# 0,Академіка Ромоданова,вулиця,Шевченківський
#
# 2016,Академіка Тронька,вулиця,Голосіївський
#
# 1976,Акацієвий,провулок,Дарницький
#
# 1960,Алексухіна Василя,вулиця,Святошинський
#
# 1966,Алли Горської,провулок,Шевченківський
#
# 1964,Алматинська,вулиця,Дніпровський
#
# 2008,Аляб'єва,вулиця,Оболонський
#
# 0,Аманда Струве,вулиця,Оболонський
#
# 0,Аміни Окуєвої ,вулиця,Шевченківський
#
# 2007,Амосова Миколи,вулиця,Солом'янський
#
# 1916,Амурська,вулиця,Голосіївський
#
# 0,Амурська,площа,Голосіївський
#
# 0,Ананасна,вулиця,Подільський
#
# 2013,Анатоліївська,вулиця,Деснянський
#
# 2019,Анатолія Кентія,вулиця,Голосіївський
#
# 0,Анатолія Лупиноса,вулиця,Солом’янський
#
# 2009,Анатолія Солов'яненка,вулиця,Дніпровський
#
# 2017,Андріївська,вулиця,Подільський
#
# 0,Андріївський ,узвіз,Подільський
#
# 0,Андрія Аболмасова ,вулиця,Дніпровський
#
# 2016,Андрія Кизила,вулиця,Дарницький
#
# 1986,Андрія Меленського,вулиця,Голосіївський
#
# 2019,Андрія Ніковського,вулиця,Голосіївський
#
# 1977,Андрія Первозванного,площа,Печерський
#
# 0,Андрющенка Григорія,вулиця,Шевченківський
#
# 2018,Анкари,площа,Деснянський
#
# 1983,Анни Ярославни,вулиця,Святошинський
#
# 0,Антіна Ждановича,вулиця,Солом'янський
#
# 1963,Антона Цедіка,вулиця,Шевченківський
#
# 2014,Антоненка-Давидовича Бориса,вулиця,Дарницький
#
# 1906,Антоні Новосельського,вулиця,Святошинський
#
# 1962,Антонова Авіаконструктора,вулиця,Солом'янський
#
# 0,Антоновича,вулиця,"Голосіївський, Печерський"
#
# 2017,Ареф'єва Костянтина,вулиця,Дарницький
#
# 2009,Аркасівська,вулиця,Оболонський
#
# 2002,Армійська ,вулиця,Голосіївський
#
# 1990,Арсенальна ,площа,Печерський
#
# 1971,Арсенальна ,вулиця,Печерський
#
# 2010,Арсенальний,провулок,Печерський
#
# 1969,Артезіанський,провулок,Подільський
#
# 0,Артемія Веделя,вулиця,Голосіївський
#
# 1983,Артилерійський,провулок,Шевченківський
#
# 1892,Архипа Люльки,вулиця,Солом’янський
#
# 0,Архипенка Олександра,вулиця,Оболонський
#
# 2006,Архітектора Дяченка,вулиця,Голосіївський
#
# 2017,Архітектора Кобелєва,вулиця,Солом'янський
#
# 0,Архітекторська,вулиця,Солом'янський
#
# 0,Аскольдів,провулок,Печерський
#
# 0,Астраханська,вулиця,Дніпровський
#
# 2008,Астраханський,провулок,Дніпровський
#
# 2010,Астрономічна,вулиця,Святошинський
#
# 1990,Атени Пашко,вулиця,Голосіївський
#
# 2018,Аттили Могильного,вулиця,Солом’янський
#
# 2014,Ахматової Анни,вулиця,Дарницький
#
# 1906,Бабушкіна,провулок,Шевченківський
#
# 1962,Багговутівська,вулиця,Шевченківський
#
# 0,Багратіона,вулиця,Солом'янський
#
# 2017,Багряна Дуброва,вулиця,Голосіївський
#
# 2009,Багряного Івана,вулиця,Дніпровський
#
# 2002,Бажана Миколи,проспект,Дарницький
#
# 1990,Бажова,вулиця,Дніпровський
#
# 1971,Байкальська,вулиця,Голосіївський
#
# 2010,Байкова,вулиця,Голосіївський
#
# 1969,Бакинська,вулиця,Шевченківський
#
# 0,Бакинський,провулок,Шевченківський
#
# 1983,Баклажанна,вулиця,Подільський
#
# 1892,Бакуніна,вулиця,Солом'янський
#
# 0,Балакірева,вулиця,Голосіївський
#
# 2006,Балаклієвська,вулиця,Шевченківський
#
# 2017,Балтійський,провулок,Оболонський
#
# 0,Бальзака Оноре де,вулиця,Деснянський
#
# 0,Банкова,вулиця,Печерський
#
# 0,Баренбойма,вулиця,Голосіївський
#
# 2008,Барикадна,вулиця,Голосіївський
#
# 2010,Баришівська,вулиця,Печерський
#
# 1990,Басейна,вулиця,"Печерський, Шевченківський"
#
# 2018,Бастіонна,вулиця,Печерський
#
# 1994,Бастіонний,провулок,Печерський
#
# 2016,Батумська,вулиця,Голосіївський
#
# 2014,Батуринська,вулиця,Дарницький
#
# 1959,Батуринський  ,провулок,Дарницький
#
# 1990,Баха Академіка ,вулиця,Дніпровський
#
# 1962,Бахмацька,вулиця,Святошинський
#
# 2017,Бджолиний,провулок,Дарницький
#
# 2013,Безручка Марка,вулиця,Шевченківський
#
# 0,Бердичівська,вулиця,Шевченківський
#
# 1969,Бердянська,вулиця,Шевченківський
#
# 0,Бердянський,провулок,Шевченківський
#
# 2020,Берегова,вулиця,Деснянський
#
# 0,Бережанська,вулиця,Оболонський
#
# 2004,Березнева,вулиця,Дніпровський
#
# 2008,Березнева,вулиця,Дарницький
#
# 2018,Березневий,провулок,Дарницький
#
# 2013,Березневий 3,провулок,Дарницький
#
# 0,Березняківська,вулиця,Дніпровський
#
# 2017,Березова,вулиця,Солом'янський
#
# 2020,Берестецька,вулиця,Оболонський
#
# 2011,Беретті Вікентія,вулиця,Деснянський
#
# 0,Берізоньки (Озерна 14),вулиця,Дарницький
#
# 2018,Берковецька,вулиця,Святошинський
#
# 2019,Берлінського Максима,вулиця,Шевченківський
#
# 2019,Бессарабська,площа,Шевченківський
#
# 1957,Бестужева Олександра,провулок,Подільський
#
# 2001,Бестужева Олександра,вулиця,Подільський
#
# 2017,Бетховена,вулиця,Святошинський
#
# 2018,Бехтерівський,провулок,Шевченківський
#
# 2013,Биківнянська,вулиця,Деснянський
#
# 2007,Биківнянський,провулок,Деснянський
#
# 0,Биківський,провулок,Подільський
#
# 2020,Бикова Леоніда,бульвар,Деснянський
#
# 0,Бишівський,провулок,Дніпровський
#
# 2013,Бігова ,вулиця,Деснянський
#
# 2015,Білаша Олександра,вулиця,Деснянський
#
# 0,Білгородська,вулиця,Солом'янський
#
# 1963,Білецького Академіка,вулиця,Солом'янський
#
# 2019,Білицька,вулиця,Подільський
#
# 2013,Білицький,провулок,Подільський
#
# 0,Біличанська,вулиця,Святошинський
#
# 2018,Білогородська,вулиця,Святошинський
#
# 1981,Білокур Катерини,вулиця,Печерський
#
# 0,Біломорська,вулиця,Деснянський
#
# 2015,Білоруська,вулиця,Шевченківський
#
# 2005,Біляшівського Академіка,вулиця,Святошинський
#
# 2003,Бірюзова Маршала,вулиця,Святошинський
#
# 0,Блакитного,вулиця,Голосіївський
#
# 2019,Блока Олександра,вулиця,Святошинський
#
# 1971,Бобринецька,вулиця,Деснянський
#
# 0,Бобринецький,провулок,Деснянський
#
# 1980,Бобруйський,провулок,Подільський
#
# 1959,Богатирська,вулиця,Оболонський
#
# 2014,Богатирський,проїзд,Оболонський
#
# 0,Богдана Гаврилишина,вулиця,Шевченківський
#
# 0,Богданівська,вулиця,Солом'янський
#
# 1980,Богданівський,провулок,Солом'янський
#
# 2019,Богомольця Академіка,вулиця,Печерський
#
# 1993,Богуна Івана,вулиця,Дарницький
#
# 2003,Богунська,вулиця,Голосіївський
#
# 2017,Богунський,провулок,Голосіївський
#
# 1996,Богуславський,узвіз,Подільський
#
# 0,Богушевський,провулок,Деснянський
#
# 0,Божків Яр,вулиця,Солом'янський
#
# 1914,Бойка Івана,вулиця,Дарницький
#
# 2005,Бойова,вулиця,Голосіївський
#
# 0,Бойчука Михайла,вулиця,Печерський
#
# 0,Болбочана Петра,вулиця,Печерський
#
# 0,Болсуновська,вулиця,Печерський
#
# 0,Бондарська,вулиця,Подільський
#
# 1999,Бондарський,провулок,Подільський
#
# 2007,Бориса Матюшенка,вулиця,Голосіївський
#
# 2009,Бориса Мозолевського,вулиця,Голосіївський
#
# 2014,Бориса Тена,вулиця,Голосіївський
#
# 2005,Бориса Шахліна,провулок,Голосіївський
#
# 2017,Бориславська,вулиця,Солом'янський
#
# 2007,Борисоглібська,вулиця,Подільський
#
# 0,Бориспільська,вулиця,Дарницький
#
# 0,Бориспільське,шосе,Дарницький
#
# 2015,Боричів ,узвіз,Подільський
#
# 0,Боричів Тік,вулиця,Подільський
#
# 2014,Борова,вулиця,Дарницький
#
# 1977,Борова,вулиця,Дарницький
#
# 1974,Боровий,провулок,Дарницький
#
# 2005,Боровий,провулок,Дарницький (Бортничі)
#
# 1958,Боровиковського,вулиця,Оболонський
#
# 0,Боровинська,вулиця,Подільський
#
# 2017,Боровиченко Марії,вулиця,Голосіївський
#
# 2018,Бородянський ,провулок,Святошинський
#
# 2005,Бортницька,вулиця,Дарницький
#
# 2012,Бортницька,вулиця,Дарницький
#
# 1964,Бортницький,провулок,Дарницький
#
# 2015,Бортницький 1,провулок,Дарницький
#
# 2017,Бортницький 2,провулок,Дарницький
#
# 0,Борщагівська,вулиця,"Солом'янський, Шевченківський "
#
# 2011,Ботанічна,площа,Шевченківський
#
# 1964,Боткіна,вулиця,Солом'янський
#
# 2016,Брановицького Ігоря,вулиця,Печерський
#
# 0,Братиславська,вулиця,"Деснянський, Дніпровський"
#
# 2021,Братів Зерових,вулиця,Солом'янський
#
# 1946,Братів Шеметів,вулиця,Голосіївський
#
# 2017,Братська,вулиця,Подільський
#
# 1977,Брацлавська,вулиця,Дарницький
#
# 2018,Брест-Литовський,провулок,Шевченківський
#
# 0,Брестська,вулиця,Подільський
#
# 2013,Броварський,провулок,Деснянський
#
# 2015,Броварський,проспект,"Деснянський, Дніпровський"
#
# 2001,Бродівська,вулиця,Голосіївський
#
# 0,Бродівський,провулок,Голосіївський
#
# 2015,Брусилівська,вулиця,Святошинський
#
# 0,Брюлова,вулиця,Солом'янський
#
# 2003,Брюсова,вулиця,Подільський
#
# 1963,Брянська,вулиця,Солом'янський
#
# 1962,Бугорна ,вулиця,Шевченківський
#
# 1895,Бугорний,провулок,Шевченківський
#
# 0,Бударіна,вулиця,Святошинський
#
# 0,Будищанська,вулиця,Деснянський
#
# 2001,Будівельників,провулок,Дніпровський
#
# 0,Будівельників,вулиця,Дніпровський
#
# 0,Будівельників,вулиця,Деснянський
#
# 1970,Будівельників,провулок,Святошинський
#
# 1973,Будіндустрії,вулиця,Голосіївський
#
# 0,Бузинова,вулиця,Дарницький
#
# 2010,Буйка Професора,вулиця,Голосіївський
#
# 0,Букіної Раїси,вулиця,Святошинський
#
# 1979,Букіної Раїси,провулок,Святошинський
#
# 2002,Буковинська,вулиця,Голосіївський
#
# 2018,Буковинський,провулок,Голосіївський
#
# 2005,Булаховського Академіка,вулиця,Святошинський
#
# 0,Булгакова,вулиця,Святошинський
#
# 2019,Бульварно-Кудрявська,вулиця,Шевченківський
#
# 1975,Бурденка,провулок,Подільський
#
# 2010,Бурмистенка,вулиця,Голосіївський
#
# 2005,Бурмистенка,провулок,Голосіївський
#
# 2020,Буслівська,вулиця,Печерський
#
# 1986,Бутишів,провулок,Печерський
#
# 0,Бутлерова Академіка,вулиця,Дніпровський
#
# 2005,Бучанська,вулиця,Святошинський
#
# 2018,Бучми Амвросія,бульвар,Дніпровський
#
# 2011,В’ячеслава Липинського,вулиця,Шевченківський
#
# 2018,Вавілових,вулиця,Шевченківський
#
# 1971,Вакуленчука,вулиця,Дарницький
#
# 2020,Вакуленчука,провулок,Дарницький
#
# 1960,Валентина Отамановського,вулиця,Голосіївський
#
# 2005,Валерія Марченка,площа,"Подільський, Шевченківський"
#
# 0,Валер'яна Підмогильного,вулиця,Голосіївський
#
# 2006,Валківська,вулиця,Подільський
#
# 1969,Василенка Миколи,вулиця,Солом'янський
#
# 2015,Василівська,вулиця,Солом'янський
#
# 0,Васильківська,вулиця,Голосіївський
#
# 2006,Васильківський,провулок,Голосіївський
#
# 2019,Васильченка,вулиця,Солом'янський
#
# 0,Василя Барки,вулиця,Солом’янський
#
# 2007,Василя Біднова,вулиця,Деснянський
#
# 0,Василя Вишиваного,вулиця,Дніпровський
#
# 1973,Василя Макуха,вулиця,Шевченківський
#
# 2012,Василя Седляра,вулиця,Солом'янський
#
# 2017,Василя Тютюнника,вулиця,Печерський
#
# 1997,Василя Щавинського,вулиця,Деснянський
#
# 1936,Васнецова,вулиця,Дніпровський
#
# 2005,Ватутіна,вулиця,Солом'янський
#
# 1971,Ватутінський,провулок,Деснянський
#
# 0,Ващенка Григорія,вулиця,Дарницький
#
# 1883,Введенська,вулиця,Подільський
#
# 2010,Велика Васильківська,вулиця,"Голосіївський, Шевченківський, Печерський"
#
# 2016,Велика Житомирська,вулиця,Шевченківський
#
# 2016,Велика Китаївська,вулиця,Голосіївський
#
# 2001,Велика Кільцева,дорога,Оболонський
#
# 0,Велика Окружна,вулиця,Святошинський
#
# 2015,Вербицького Архітектора,вулиця,Дарницький
#
# 0,Вербна,вулиця,Оболонський
#
# 0,Вербний,провулок,Деснянський
#
# 0,Вербова,вулиця,Оболонський
#
# 0,Верболозна,вулиця,Подільський
#
# 0,Верболозний,провулок,Подільський
#
# 2013,Вересая Остапа,вулиця,Деснянський
#
# 0,Вересковий,провулок,Дарницький
#
# 0,Вереснева,вулиця,Дарницький
#
# 0,Верещагіна,вулиця,Подільський
#
# 1982,Вернадського Академіка,бульвар,Святошинський
#
# 0,Верхній,провулок,Печерський
#
# 0,Верхній Вал,вулиця,Подільський
#
# 1983,Верхньогірська,вулиця,Печерський
#
# 0,Верхньоключова,вулиця,Солом'янський
#
# 0,Верхня,вулиця,Печерський
#
# 2013,Верховинна,вулиця,Святошинський
#
# 2014,Верховинця Василя,вулиця,Святошинський
#
# 2013,Верховної Ради,бульвар,"Дніпровський, Деснянський"
#
# 2019,Вершигори Петра,вулиця,Дніпровський
#
# 0,Веселковий,провулок,Подільський
#
# 1905,Весняна,вулиця,Голосіївський
#
# 0,Вешенський,провулок,Деснянський
#
# 2012,Виборзький,провулок,Солом'янський
#
# 1959,Вигурівський,бульвар,Деснянський
#
# 2016,Видубицька,вулиця,Печерський
#
# 0,Визволителів,проспект,Дніпровський
#
# 0,Винахідників,вулиця,Дніпровський
#
# 1973,Винахідників,провулок,Дніпровський
#
# 0,Виноградна,вулиця,Солом'янський
#
# 2009,Виноградний,провулок,Печерський
#
# 0,Вирлицька,вулиця,Дарницький
#
# 0,Високовольтний,провулок,Дарницький
#
# 2003,Висоцького Володимира,бульвар,Деснянський
#
# 1971,Вифлеємська,вулиця,Дніпровський
#
# 0,Вишгородська,вулиця,"Подільський, Оболонський"
#
# 1983,Вишнева,вулиця,Солом'янський
#
# 0,Вишнева,вулиця,Святошинський
#
# 2015,Вишнева,вулиця,Оболонський
#
# 1982,Вишнева,вулиця,Дарницький
#
# 0,Вишнева (Озерна 3),вулиця,Дарницький
#
# 1961,Вишняківська,вулиця,Дарницький
#
# 2019,Відпочинку,вулиця,Святошинський
#
# 0,Відрадний,проспект,"Солом'янський, Святошинський"
#
# 0,Військова,вулиця,Голосіївський
#
# 2018,Військовий,проїзд,Печерський
#
# 2016,Віктора Зарецького,вулиця,Голосіївський
#
# 2020,Вільде Едуарда,вулиця,Дніпровський
#
# 2018,Вільнюська,вулиця,Дніпровський
#
# 2012,Вільхова ,вулиця,Дніпровський
#
# 2006,Вільшанська,вулиця,Печерський
#
# 1989,Вільшанський ,провулок,Печерський
#
# 0,Вільямса Академіка,вулиця,Голосіївський
#
# 2015,Вінграновського Миколи,вулиця,Дарницький
#
# 2014,Вінницька,вулиця,Солом'янський
#
# 0,Вірменська,вулиця,Дарницький
#
# 2004,Вірменський,провулок,Дарницький
#
# 0,Вірності,вулиця,Деснянський
#
# 2018,Вірського Павла,вулиця,Деснянський
#
# 2012,Вірьовки Григорія,вулиця,Деснянський
#
# 2015,Віскозна,вулиця,"Дніпровський, Деснянський"
#
# 2018,Вітавська,вулиця,Голосіївський
#
# 1977,Віто-Литовський,провулок,Голосіївський
#
# 2012,Вітрука Генерала,вулиця,Святошинський
#
# 2006,Вітряні Гори,вулиця,Подільський
#
# 2015,Вітчизняна,вулиця,Подільський
#
# 1966,Вітянська,вулиця,Голосіївський
#
# 2019,Владлена Кузнецова,вулиця,Деснянський
#
# 2018,Водників,вулиця,Подільський
#
# 0,Водогінна,вулиця,Голосіївський
#
# 0,Воздвиженська,вулиця,Подільський
#
# 2014,Воздвиженський,провулок,Подільський
#
# 0,Вознесенський,узвіз,Шевченківський
#
# 0,Вокзальна,площа,Солом'янський
#
# 2017,Вокзальна,вулиця,"Солом'янський, Шевченківський"
#
# 2018,Волгоградська,вулиця,Солом'янський
#
# 1879,Волгоградська,площа,Деснянський
#
# 1991,Волго-Донська,вулиця,Дарницький
#
# 0,Волго-Донський,провулок,Дарницький
#
# 0,Волзька,вулиця,Голосіївський
#
# 1961,Волзький,провулок,Голосіївський
#
# 2017,Волинська,вулиця,Солом'янський
#
# 0,Волкова Космонавта,вулиця,Деснянський
#
# 1913,Володарська,вулиця,Голосіївський
#
# 0,Володимира Беца,вулиця,Деснянський
#
# 0,Володимира Брожка,вулиця,"Голосіївський, Солом'янський"
#
# 1999,Володимира Винниченка,вулиця,Шевченківський
#
# 1961,Володимира Горовиця,вулиця,Голосіївський
#
# 0,Володимира Науменко,вулиця,Голосіївський
#
# 0,Володимиро-Либідська,вулиця,Голосіївський
#
# 0,Володимирська,вулиця,"Голосіївський, Шевченківський"
#
# 0,Володимирський,узвіз,"Печерський, Подільський, Шевченківський"
#
# 2013,Володимирський,проїзд,Шевченківський
#
# 2013,Волоська,вулиця,Подільський
#
# 0,Волошкова,вулиця,Солом'янський
#
# 1993,Волошковий,провулок,Деснянський
#
# 0,Волховська,вулиця,Дніпровський
#
# 2016,Волховський,провулок,Дніпровський
#
# 2018,Воскресенська,вулиця,Дніпровський
#
# 0,Восьмого Березня,вулиця,Оболонський
#
# 2015,Врубелівський,узвіз,Шевченківський
#
# 2019,Всеволода Змієнка,вулиця,Подільський
#
# 0,Вузівська,вулиця,Солом'янський
#
# 0,Вуликова,вулиця,Дарницький
#
# 2010,Вчительська,вулиця,Солом'янський
#
# 2005,Гаванська,вулиця,Подільський
#
# 2011,Гаванський,провулок,Оболонський
#
# 2007,Гавела Вацлава,бульвар,Солом'янський
#
# 2009,Гаврилюка,вулиця,Солом’янський
#
# 0,Гагаріна Юрія,проспект,"Деснянський, Дніпровський"
#
# 2003,Газова,вулиця,Солом’янський
#
# 2014,Газопровідна,вулиця,"Подільський, Святошинський"
#
# 1999,Гайдай Зої,вулиця,Оболонський
#
# 2018,Гайова,вулиця,Солом’янський
#
# 2020,Гайсинська,вулиця,Солом’янський
#
# 2018,Галерна,вулиця,Голосіївський
#
# 1972,Галицька,вулиця,Подільський
#
# 2018,Ганни Арендт,вулиця,Солом'янський
#
# 2011,Ганни Барвінок,вулиця,Оболонський
#
# 2019,Гаражна,вулиця,Дніпровський
#
# 0,Гаражна,вулиця,Дарницький
#
# 2007,Гарета Джонса,провулок,Шевченківський
#
# 0,Гаріна Бориса,вулиця,Солом’янський
#
# 1978,Гарматна,вулиця,Солом’янський
#
# 1858,Гаршина,вулиця,Святошинський
#
# 1974,Гастелло Миколи,вулиця,Печерський
#
# 2017,Гатна,вулиця,Голосіївський
#
# 0,Гашека Ярослава,бульвар,Дніпровський
#
# 2008,Гвардійська,вулиця,Голосіївський
#
# 0,Генерала Алмазова,вулиця,Печерський
#
# 0,Генерала Гандзюка,вулиця,Оболонський
#
# 2007,Генерала Генадія Воробйова,вулиця,Солом'янський
#
# 2014,Генерала Грекова,вулиця,Подільський
#
# 2016,Генерала Павленка,вулиця,Солом'янський
#
# 1993,Генерала Шаповала,вулиця,Солом'янський
#
# 1978,Георгіївський,провулок,Шевченківський
#
# 0,Геофізиків,вулиця,Дарницький
#
# 2016,Геофізиків,провулок,Дарницький
#
# 1936,Герасименка Костянтина,вулиця,Святошинський
#
# 0,Героїв Бресту,площа,Святошинський
#
# 2005,Героїв Великої Вітчизняної війни,площа,Печерський
#
# 1959,Героїв Війни,вулиця,Солом’янський
#
# 2001,Героїв Дніпра,вулиця,Оболонський
#
# 2015,Героїв Космосу,вулиця,Святошинський
#
# 1988,Героїв Крут,алея,Печерський
#
# 1981,Героїв Небесної Сотні,алея,Печерський
#
# 1936,Героїв Оборони,вулиця,Голосіївський
#
# 2019,Героїв Севастополя,вулиця,Солом'янський
#
# 2005,Героїв Сталінграда,проспект,Оболонський
#
# 0,Герцена,вулиця,Шевченківський
#
# 1965,Герцена,узвіз,Шевченківський
#
# 2018,Герцена,провулок,Шевченківський
#
# 0,Гетьмана Вадима,вулиця,Солом'янський
#
# 2010,Гійома де Боплана,вулиця,Деснянський
#
# 2014,Гіллястий,провулок,Дніпровський
#
# 2016,Гладківська,вулиця,Солом'янський
#
# 2002,Глазунова,вулиця,Печерський
#
# 0,Глибочицька,вулиця,Шевченківський
#
# 0,Глибочицький,проїзд,Шевченківський
#
# 1963,Глібова,вулиця,Шевченківський
#
# 2005,Глієра Рейнгольда,вулиця,Святошинський
#
# 2016,Глінки,вулиця,Солом’янський
#
# 2018,Глухівська,вулиця,Подільський
#
# 2015,Глушкова Академіка,проспект,Голосіївський
#
# 1985,Гмирі Бориса,вулиця,Дарницький
#
# 2007,Говорова Маршала,вулиця,Голосіївський
#
# 2010,Говорова Маршала,провулок,Голосіївський
#
# 0,Гоголівська,вулиця,Шевченківський
#
# 2014,Гоголя,вулиця,Солом’янський
#
# 0,Гоголя,вулиця,Дарницький
#
# 1970,Гоголя,вулиця,Деснянський
#
# 1975,Гоголя 2,провулок,Дарницький
#
# 2014,Голованьова Степана,вулиця,Дарницький
#
# 2012,Головка Андрія,вулиця,Солом’янський
#
# 2019,Голосіївська,площа,Голосіївський
#
# 0,Голосіївська,вулиця,Голосіївський
#
# 1974,Голосіївський,проспект,Голосіївський
#
# 2019,Голосіївський,провулок,Голосіївський
#
# 1975,Гомельська,вулиця,Подільський
#
# 2002,Гомельський,провулок,Подільський
#
# 1998,Гонгадзе Георгія,проспект,Подільський
#
# 2016,Гонти Івана,вулиця,Шевченківський
#
# 2016,Гончара Олеся,вулиця,Шевченківський
#
# 2012,Гончарна,вулиця,Подільський
#
# 0,Гончарова,вулиця,Шевченківський
#
# 2008,Горбунова Академіка,вулиця,Дарницький
#
# 2013,Горенська,вулиця,Святошинський
#
# 1969,Гориста,вулиця,Голосіївський
#
# 2020,Гористий,провулок,Голосіївський
#
# 1913,Горіхова,вулиця,Солом'янський
#
# 2017,Горіхова (Озерна 5),вулиця,Дарницький
#
# 2017,Горлівська,вулиця,Дарницький
#
# 2020,Городецького Архітектора,вулиця,Печерський
#
# 0,Городище,вулиця,Деснянський
#
# 1954,Городищенська,вулиця,Подільський
#
# 0,Городня,вулиця,Солом’янський
#
# 1936,Горюшка Георгія,вулиця,Голосіївський
#
# 2016,Госпітальна,вулиця,Печерський
#
# 2018,Госпітальний,провулок,Печерський
#
# 0,Гостинна,вулиця,Дарницький
#
# 2019,Гостинний,провулок,Дарницький
#
# 2014,Гостомельська,вулиця,Святошинський
#
# 0,Гостомельська,площа,Святошинський
# 0,Гостомельське,шосе,Оболонський
#
# 2003,Грабовського Павла,вулиця,Голосіївський
#
# 2009,Грабовського Павла,провулок,Голосіївський
#
# 1964,Градинська,вулиця,Деснянський
#
# 1986,Гранична,вулиця,Святошинський
#
# 0,Гребінки,вулиця,Голосіївський
#
# 2011,Грекова Академіка,вулиця,Шевченківський
#
# 0,Гречаний,провулок,Дарницький
#
# 0,Григоренка Петра,проспект,Дарницький
#
# 2018,Григорія Голоскевича,вулиця,Голосіївський
#
# 0,Григорія Косинки,вулиця,Деснянський
#
# 0,Григоровича-Барського,вулиця,Святошинський
#
# 2010,Гришка Миколи,вулиця,Деснянський
#
# 2017,Гришка Михайла,вулиця,Дарницький
#
# 2017,Грінченка Бориса,вулиця,Шевченківський
#
# 0,Грінченка Миколи,вулиця,"Голосіївський, Солом’янський"
#
# 1955,Гродненська,вулиця,Дніпровський
#
# 0,Гродненський,провулок,Дніпровський
#
# 2018,Грозненська,вулиця,Шевченківський
#
# 2014,Громадська,вулиця,Солом’янський
#
# 0,Громової Уляни,вулиця,Солом’янський
#
# 0,Грузинська,вулиця,Дарницький
#
# 2015,Грузинський,провулок,Дарницький
#
# 2002,Грушева,вулиця,Солом'янський
#
# 2016,Грушевського Михайла,вулиця,Печерський
#
# 2019,Гулака Миколи,вулиця,Оболонський
#
# 0,Гурамішвілі Давида,вулиця,Святошинський
#
# 0,Гусовського,вулиця,Печерський
#
# 2019,Гучний,провулок,Солом’янський
#
# 0,Ґалаґанівська,вулиця,Святошинський
#
# 1975,Ґренджі-Донського,вулиця,Солом'янський
#
# 2017,Далека,вулиця,Солом'янський
#
# 2010,Даля Олександра,вулиця,Деснянський
#
# 1977,Дамбова,вулиця,Дніпровський
#
# 2019,Дамбова 1,вулиця,Дніпровський
#
# 0,Дамбова 2,вулиця,Дніпровський
#
# 2019,Дамбова 3,вулиця,Дніпровський
#
# 2013,Данченка Сергія,вулиця,Подільський
#
# 2018,Данькевича Костянтина,вулиця,Деснянський
#
# 2019,Дарвіна,вулиця,Печерський
#
# 2018,Дарницька,площа,Дніпровський
#
# 2009,Дарницький,бульвар,Дніпровський
#
# 0,Дачна,вулиця,Деснянський
#
# 1961,Дачний,провулок,Деснянський
#
# 2003,Дашавська,вулиця,Солом'янський
#
# 2018,Двінська,вулиця,Дніпровський
#
# 2008,Дегтярівська,вулиця,Шевченківський
#
# 1967,Дегтярна,вулиця,Подільський
#
# 2017,Дежнєва,вулиця,Солом'янський
#
# 1936,Дежнєва,провулок,Солом'янський
#
# 0,Декабристів,вулиця,Дарницький
#
# 2010,Делегатський,провулок,Шевченківський
#
# 2019,Демидівська,вулиця,Дарницький
#
# 2013,Деміївська,площа,Голосіївський
#
# 2012,Деміївська,вулиця,Голосіївський
#
# 0,Деміївський,провулок,Голосіївський
#
# 0,Депутатська,вулиця,Святошинський
#
# 0,Деревлянська,вулиця,Шевченківський
#
# 2013,Деревообробна,вулиця,Голосіївський
#
# 0,Деревообробний,провулок,Голосіївський
#
# 2009,Десенський ,провулок,Деснянський
#
# 1985,Деснянська,вулиця,Солом'янський
#
# 2018,Деснянська,вулиця,Деснянський
#
# 1989,Деснянська,вулиця,Дніпровський
#
# 2019,Деснянський,провулок,Деснянський
#
# 1998,Десятинна,вулиця,Шевченківський
#
# 2013,Десятинний,провулок,Шевченківський
#
# 2008,Джаліля Муси,вулиця,Подільський
#
# 2015,Джеймса Мейса,вулиця,Солом'янський
#
# 2019,Джерельна,вулиця,Оболонський
#
# 0,Джерельна,вулиця,Дарницький
#
# 2018,Джерельний,провулок,Оболонський
#
# 2006,Джона Маккейна,вулиця,Печерський
#
# 1972,Дзиґи Вертова,провулок,Дніпровський
#
# 1976,Диканський,провулок,Дарницький
#
# 1914,Димерська,вулиця,Святошинський
#
# 0,Діамантовий,провулок,Деснянський
#
# 0,Дібровна ,вулиця,Голосіївський
#
# 2008,Дібровний,провулок,Голосіївський
#
# 2017,Ділова,вулиця,"Голосіївський, Печерський"
#
# 1973,Дмитра Григоровича,вулиця,Солом’янський
#
# 1956,Дмитра Загула,вулиця,Деснянський
#
# 2020,Дмитрівська,вулиця,Шевченківський
#
# 1981,Дмитрівська,вулиця,Подільський
#
# 0,Дніпрова,вулиця,Дарницький
#
# 0,Дніпровий,провулок,Дарницький
#
# 0,Дніпроводська,вулиця,Оболонський
#
# 2005,Дніпровська,вулиця,Оболонський
#
# 1940,Дніпровська ,набережна,"Дніпровський, Дарницький"
#
# 0,Дніпровське,шосе,Голосіївський
#
# 1976,Дніпровський ,узвіз,Печерський
#
# 2018,Дністровська,вулиця,Солом'янський
#
# 2010,Добрий Шлях,вулиця,Голосіївський
#
# 2022,Добринінська,вулиця,Оболонський
#
# 2006,Добробутна,вулиця,Солом'янський
#
# 1957,Добровольчих батальйонів,вулиця,Печерський
#
# 2019,Добролюбова,вулиця,Печерський
#
# 2004,Добролюбова,провулок,Печерський
#
# 2016,Добросусідська,вулиця,Солом'янський
#
# 1977,Добросусідський,провулок,Солом'янський
#
# 0,Доброхотова Академіка,вулиця,Святошинський
#
# 1973,Добрузька,вулиця,Солом'янський
#
# 0,Доватора Генерала,вулиця,Голосіївський
#
# 0,Доватора Генерала,провулок,Голосіївський
#
# 2015,Довбуша Олекси,вулиця,Дніпровський
#
# 2018,Довженка,вулиця,Деснянський
#
# 1910,Довженка Олександра,вулиця,Шевченківський
#
# 0,Докучаєвська,вулиця,Солом'янський
#
# 1967,Докучаєвський,тупик,Солом'янський
#
# 1972,Докучаєвський,провулок,Солом'янський
#
# 2010,Долинна,вулиця,Солом'янський
#
# 0,Донецька,вулиця,Солом'янський
#
# 2013,Донецький,провулок,Солом'янський
#
# 2013,Донська,вулиця,Солом'янський
#
# 1961,Донський,провулок,Солом'янський
#
# 2017,Донця Михайла,вулиця,Солом'янський
#
# 0,Дончука Василя,вулиця,Шевченківський
#
# 2005,Дорогожицька,вулиця,Шевченківський
#
# 2017,Достоєвського,провулок,Подільський
#
# 2007,Достоєвського,вулиця,Подільський
#
# 0,Драгоманова,вулиця,Дарницький
#
# 1955,Драгомирова Михайла,вулиця,Печерський
#
# 2020,Драйзера Теодора,вулиця,Деснянський
#
# 0,Драй-Хмари Михайла,вулиця,Святошинський
#
# 0,Друга,вулиця,Оболонський
#
# 2013,Дружби,вулиця,Дарницький
#
# 2013,Дружби 1,провулок,Дарницький
#
# 1977,Дружби 2,провулок,Дарницький
#
# 0,Дружби 3,провулок,Дарницький
#
# 0,Дружби Народів,бульвар,Печерський
#
# 0,Дружківська,вулиця,Святошинський
#
# 0,Дружня,вулиця,Солом'янський
#
# 1954,Дубенська,вулиця,Печерський
#
# 1972,Дубичнянська,вулиця,Деснянський
#
# 0,Дубищанська,вулиця,Оболонський
#
# 2018,Дубищанський,провулок,Оболонський
#
# 2018,Дубініна Володі,вулиця,Голосіївський
#
# 1957,Дубка (Озерна 15),вулиця,Дарницький
#
# 2009,Дубровицька,вулиця,Оболонський
#
# 0,Дубровицький,провулок,Оболонський
#
# 2019,Дубровського Віктора,провулок,Святошинський
#
# 0,Дудника Георгія,вулиця,Шевченківський
#
# 0,Дуки Степана,вулиця,Голосіївський
#
# 2005,Дунаєвського,вулиця,Святошинський
#
# 2018,Дунаєвського,провулок,Святошинський
#
# 2017,Дурдуківського Володимира,вулиця,Святошинський
#
# 2011,Дяченка Івана,вулиця,Дарницький
#
# 0,Екскаваторна,вулиця,Святошинський
#
# 1977,Електриків,вулиця,Подільський
#
# 2015,Електриків,провулок,Подільський
#
# 1987,Електротехнічна,вулиця,Деснянський
#
# 0,Енгельса,провулок,Дарницький
#
# 1995,Енгельса,вулиця,Дарницький
#
# 2005,Енергетиків,вулиця,Солом'янський
#
# 1961,Енергетиків,вулиця,Дніпровський
#
# 2000,Енергетиків,провулок,Солом'янський
#
# 2008,Ентузіастів,вулиця,Дніпровський
#
# 2018,Ентузіастів 1,вулиця,Дарницький
#
# 2014,Ентузіастів 10,вулиця,Дарницький
#
# 0,Ентузіастів 2,вулиця,Дарницький
#
# 0,Ентузіастів 3,вулиця,Дарницький
#
# 2010,Ентузіастів 4,вулиця,Дарницький
#
# 1966,Ентузіастів 5,вулиця,Дарницький
#
# 0,Ентузіастів 6,вулиця,Дарницький
#
# 2005,Ентузіастів 7,вулиця,Дарницький
#
# 2015,Ентузіастів 8,вулиця,Дарницький
#
# 0,Ентузіастів 9,вулиця,Дарницький
#
# 1962,Еренбурга Іллі,вулиця,Голосіївський
#
# 2015,Ернста Федора,вулиця,Солом'янський
#
# 2012,Еспланадна,вулиця,Печерський
#
# 1903,Естонська,вулиця,Шевченківський
#
# 1998,Естонський,провулок,Шевченківський
#
# 2016,Євгена Гуцала,провулок,Печерський
#
# 2020,Євгена Коновальця,вулиця,Печерський
#
# 1938,Євгена Плужника,вулиця,Деснянський
#
# 0,Євгена Сверстюка,вулиця,Дніпровський
#
# 0,Європейська,площа,Печерський
#
# 1966,Єдності,вулиця,Деснянський
#
# 1937,Єжи Ґедройця,вулиця,"Голосіївський, Печерський"
#
# 2019,Єнісейська,вулиця,Голосіївський
#
# 2019,Єреванська,вулиця,Солом'янський
#
# 0,Єрмака,вулиця,Оболонський
#
# 2019,Єсеніна Сергія,вулиця,Святошинський
#
# 1985,Жабаєва Жамбила,вулиця,Шевченківський
#
# 0,Жашківська,вулиця,Подільський
#
# 1981,Живописна,вулиця,Святошинський
#
# 0,Жигулівська,вулиця,Голосіївський
#
# 2011,Жилянська,вулиця,"Печерський, Голосіївський, Шевченківський"
#
# 0,Житкова Бориса,вулиця,Шевченківський
#
# 1983,Житньоторзька,вулиця,Подільський
#
# 0,Житньоторзька,площа,Подільський
#
# 0,Жмаченка Генерала,вулиця,Дніпровський
#
# 2018,Жмеринська,вулиця,Святошинський
#
# 0,Жмеринський,провулок,Святошинський
#
# 2019,Жовтнева,вулиця,Святошинський
#
# 2004,Жовтневий,провулок,Святошинський
#
# 2014,Жолудєва,вулиця,Святошинський
#
# 2017,Жуків Затон,вулиця,Голосіївський
#
# 2000,Жуковського Василя,провулок,Голосіївський
#
# 2004,Жуковського Василя,вулиця,Голосіївський
#
# 2012,Жулянська,вулиця,Голосіївський
#
# 0,Журавлина,вулиця,Дарницький
#
# 2019,Журавлина,вулиця,Солом'янський
#
# 2017,Забайківська,вулиця,Голосіївський
#
# 2001,Забіли Віктора,вулиця,Голосіївський
#
# 1948,Заболотний,провулок,Голосіївський
#
# 0,Заболотного Академіка,вулиця,Голосіївський
#
# 2013,Завальна,вулиця,Дарницький
#
# 2018,Заводська,вулиця,Подільський
#
# 2018,Заводський,провулок,Дарницький
#
# 2017,Заглади Леоніли,вулиця,Дарницький
#
# 2010,Загороднього Михайла,площа,Оболонський
#
# 0,Загородня,вулиця,Голосіївський
#
# 0,Задніпровського Михайла,вулиця,Печерський
#
# 1987,Задорожний,провулок,Голосіївський
#
# 2018,Заканальна,вулиця,Дарницький
#
# 1973,Закарпатська,вулиця,Голосіївський
#
# 1969,Закревського Миколи,вулиця,Деснянський
#
# 2015,Заливна,вулиця,Голосіївський
#
# 2016,Залізнична,вулиця,Солом'янський
#
# 2014,Залізнична,вулиця,Дніпровський
#
# 0,Залізнична 1,вулиця,Дніпровський
#
# 1965,Залізнична 2,вулиця,Дніпровський
#
# 2016,Залізнична 3,вулиця,Дніпровський
#
# 2004,Залізнична 4,вулиця,Дніпровський
#
# 0,Залізничне,шосе,Печерський
#
# 2011,Залізняка Максима,вулиця,Святошинський
#
# 0,Залісна,вулиця,Солом'янський
#
# 0,Заломова Петра,вулиця,Солом'янський
#
# 2019,Залужна ,вулиця,Голосіївський
#
# 2019,Залужний ,провулок,Голосіївський
#
# 0,Заміський,провулок,Дарницький
#
# 2008,Замковецька,вулиця,Подільський
#
# 0,Замковецький,провулок,Подільський
#
# 2018,Заньковецької,вулиця,Печерський
#
# 2016,Заозерний,провулок,Деснянський
#
# 0,Западинська,вулиця,Подільський
#
# 2006,Запашний,провулок,Дарницький
#
# 0,Запечерний,провулок,Печерський
#
# 2019,Заплавна,вулиця,Дарницький
#
# 0,Заплавний,провулок,Дарницький
#
# 1963,Заповітна,вулиця,Солом'янський
#
# 2014,Заповітний,провулок,Солом'янський
#
# 2017,Запорізька,вулиця,Солом'янський
#
# 1911,Запорожця Петра,вулиця,Дніпровський
#
# 0,Запорожця Петра,вулиця,Деснянський
#
# 0,Заремби Владислава,провулок,Голосіївський
#
# 1969,Зарічна,вулиця,Дарницький
#
# 0,Зарубинецька,вулиця,Подільський
#
# 1967,Заслонова Костянтина,вулиця,Дарницький
#
# 2019,Затєвахіна Полковника,вулиця,Голосіївський
#
# 2019,Затишна,вулиця,Дарницький
#
# 1965,Захарівська,вулиця,Подільський
#
# 2020,Захисників,провулок,Деснянський
#
# 2012,Західна,вулиця,Солом'янський
#
# 0,Західний,провулок,Солом'янський
#
# 1963,Звенигородська,вулиця,Святошинський
#
# 1995,Звіринецька,вулиця,Печерський
#
# 0,Звіринецький,провулок,Печерський
#
# 0,Зв'язківців,вулиця,Святошинський
#
# 1959,Згурівська,вулиця,Солом'янський
#
# 2014,Здолбунівська,вулиця,Дарницький
#
# 2013,Зелена,вулиця,Солом'янський
#
# 0,Зелена,вулиця,Дніпровський
#
# 2014,Зелена,вулиця,Шевченківський
#
# 2017,Зеленогірська,вулиця,Солом'янський
#
# 1917,Зелінського Академіка,провулок,Подільський
#
# 2019,Землянична,вулиця,Подільський
#
# 0,Землянська,вулиця,Печерський
#
# 0,Землянський,провулок,Печерський
#
# 2008,Зенітна,вулиця,Солом'янський
#
# 0,Зимова,вулиця,Подільський
#
# 1962,Златопільська,вулиця,Солом'янський
#
# 2014,Знам'янська,вулиця,Солом'янський
#
# 2018,Зовнішня,вулиця,Дарницький
#
# 0,Зодчих,вулиця,Святошинський
#
# 0,Золота,вулиця,Дніпровський
#
# 0,Золоті Джерела,вулиця,Голосіївський
#
# 1977,Золотоворітська,вулиця,Шевченківський
#
# 2006,Золотоворітський,проїзд,Шевченківський
#
# 0,Золотоніська,вулиця,Голосіївський
#
# 2017,Золотоустівська,вулиця,Шевченківський
#
# 1972,Золочевська,вулиця,Подільський
#
# 2018,Золочевський,провулок,Подільський
#
# 0,Зоологічна,вулиця,Шевченківський
#
# 1977,Зоотехніків,вулиця,Дарницький
#
# 0,Зорге Ріхарда,вулиця,Святошинський
#
# 0,Зоряна,вулиця,Подільський
#
# 0,Зоряна,вулиця,Солом'янський
#
# 0,Зоряний,провулок,Подільський
#
# 2016,Зрошувальна,вулиця,Дарницький
#
# 1987,Івана Білика,вулиця,Солом'янський
#
# 2020,Івана Виговського,вулиця,Подільський
#
# 0,Івана Рогача,вулиця,Деснянський
#
# 2007,Івашкевича Ярослава,вулиця,Оболонський
#
# 1993,Івченка Михайла,провулок,Святошинський
#
# 0,Ігорівська,вулиця,Подільський
#
# 0,Ігоря Диченка,вулиця,Голосіївський
#
# 2011,Їжакевича Івана,вулиця,Подільський
#
# 2006,Іжевська,вулиця,Дарницький
#
# 0,Іжевський,провулок,Дарницький
#
# 2001,Ізюмська,вулиця,Голосіївський
#
# 1994,Ізяславський,провулок,Солом'янський
#
# 0,Іллінська,вулиця,Подільський
#
# 1959,Інгульський,провулок,Голосіївський
#
# 0,Індустріальний,провулок,Солом'янський
#
# 1986,Інженера Бородіна,вулиця,Дніпровський
#
# 0,Інженерна,вулиця,Голосіївський
#
# 0,Інженерна,вулиця,Дарницький
#
# 0,Інженерний,провулок,Печерський
#
# 1997,Інженерний,провулок,Дарницький
#
# 2012,Інститутська,вулиця,Печерський
#
# 2016,Іоанна Павла ІІ,вулиця,Печерський
#
# 2001,Іпсилантіївський,провулок,Печерський
#
# 0,Ірининська,вулиця,Шевченківський
#
# 0,Ірпінська,вулиця,Святошинський
#
# 1917,Іртишська,вулиця,Голосіївський
#
# 2017,Ірчана Мирослава,вулиця,Святошинський
#
# 1990,Ісаакяна,вулиця,Шевченківський
#
# 2007,Іси Мунаєва,вулиця,Деснянський
#
# 1977,Іскрівська,вулиця,Солом'янський
#
# 0,Йова Борецького,провулок,Печерський
#
# 2021,Йорданська,вулиця,Оболонський
#
# 2010,Кабельна ,вулиця,Оболонський
#
# 1997,Каблукова Академіка,вулиця,Солом'янський
#
# 2013,Кавалерідзе Івана,вулиця,Подільський
#
# 0,Кавказька,вулиця,Солом'янський
#
# 201,Кадетський Гай ,вулиця,Солом'янський

# %% [markdown]
# #### імпортувати в БД отриманий файл 'street_flat_propery.csv' через CLI
# - __sqlite3 districts.db__ - запустити SQLite та відкрити БД
# - __.mode csv__ - перевести БД для роботи з csv-файлами
# - __.import street_flat_propery.csv street_flat_propery__ - створює таблицю _street_flat_propery_ та завантажує в неї вміст файлу _street_flat_propery.csv_
# - __SELECT * FROM street_flat_propery LIMIT 10;__ - вивести 10 записів для перевірки
# - __.quit__ - завершити роботу з CLI SQLite

# %%
# Підключитись до БД 'districts.db' в якій є прив'язка вулиць до районів 
conn = sqlite3.connect("districts.db")

# створити відповідний курсор
cur  = conn.cursor()

# %%
# для перевірки виведіть 10 записів з таблиці 'street_district'
t_cur = cur.execute("SELECT * FROM street_district LIMIT 10")

t_list = t_cur.fetchall()

_ = [print(x) for x in t_list]
# Out:
# ('9-го Травня', 'вулиця', 'Святошинський')
# ('Абрикосова', 'вулиця', 'Оболонський')
# ('Абрикосова', 'вулиця', 'Дарницький')
# ('Абрикосова', 'вулиця', 'Подільський')
# ('Августина Волошина', 'вулиця', 'Солом’янський')
# ('Авдєєнка Генерала', 'вулиця', 'Святошинський')
# ('Автозаводська', 'вулиця', 'Оболонський')
# ('Автозаводський ', 'провулок', 'Оболонський')
# ('Автопаркова', 'вулиця', 'Дарницький')
# ('Авторемонтна', 'вулиця', "Солом'янський")

# %%
# побудувати запит на створення таблиці 'result' з 3-ма полями:
#     district - текстове
#     street - текстове
#     property - числове
stmt = "CREATE TABLE IF NOT EXISTS result \
              (district TEXT,         \
               street TEXT,            \
               property INT);"

# %%
# виконати запит
cur.execute(stmt)

# %%
# перевірити схему таблиці
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('result');").fetchall()
# Out:
# [('district',), ('street',), ('property',)]

# %%
# створити запит на злиття таблиці 'street_flat_propery' та 'street_district' 
# по полю 'street'
stmt_join = "SELECT street_district.*, street_flat_propery.year FROM  \
            street_district LEFT JOIN street_flat_propery ON street_district.street = street_flat_propery.street"

# %%
# перевірити запит
cur.execute(stmt_join).fetchall()
# Out:
# [('9-го Травня', 'вулиця', 'Святошинський', 2015),
#  ('Абрикосова', 'вулиця', 'Оболонський', 0),
#  ('Абрикосова', 'вулиця', 'Оболонський', 1902),
#  ('Абрикосова', 'вулиця', 'Оболонський', 2011),
#  ('Абрикосова', 'вулиця', 'Дарницький', 0),
#  ('Абрикосова', 'вулиця', 'Дарницький', 1902),
#  ('Абрикосова', 'вулиця', 'Дарницький', 2011),
#  ('Абрикосова', 'вулиця', 'Подільський', 0),
#  ('Абрикосова', 'вулиця', 'Подільський', 1902),
#  ('Абрикосова', 'вулиця', 'Подільський', 2011),
#  ('Августина Волошина', 'вулиця', 'Солом’янський', 2014),
#  ('Авдєєнка Генерала', 'вулиця', 'Святошинський', 2009),
#  ('Автозаводська', 'вулиця', 'Оболонський', 2018),
#  ('Автозаводський ', 'провулок', 'Оболонський', None),
#  ('Автопаркова', 'вулиця', 'Дарницький', 2017),
#  ('Авторемонтна', 'вулиця', "Солом'янський", 1980),
#  ('Автотранспортна', 'вулиця', 'Дарницький', 2012),
#  ('Агітаторська', 'вулиця', "Солом'янський", 0),
#  ('Агрегатна', 'вулиця', 'Оболонський', 2018),
#  ('Аеродромна', 'вулиця', "Солом'янський", 1985),
#  ('Азербайджанська', 'вулиця', 'Дніпровський', 2017),
#  ('Азовська', 'вулиця', "Солом'янський", 1981),
#  ('Айвазовського', 'провулок', 'Шевченківський', 2016),
#  ('Академіка Єфремова', 'вулиця', 'Святошинський', 0),
#  ('Академіка Оппокова', 'вулиця', 'Оболонський', 1987),
#  ('Академіка Ромоданова', 'вулиця', 'Шевченківський', 0),
#  ('Академіка Тронька', 'вулиця', 'Голосіївський', 2016),
#  ('Акацієвий', 'провулок', 'Дарницький', 1976),
#  ('Алексухіна Василя', 'вулиця', 'Святошинський', 1960),
#  ('Алли Горської', 'провулок', 'Шевченківський', 1966),
#  ('Алматинська', 'вулиця', 'Дніпровський', 1964),
#  ("Аляб'єва", 'вулиця', 'Оболонський', 2008),
#  ('Аманда Струве', 'вулиця', 'Оболонський', 0),
#  ('Аміни Окуєвої ', 'вулиця', 'Шевченківський', None),
#  ('Амосова Миколи', 'вулиця', "Солом'янський", 2007),
#  ('Амурська', 'вулиця', 'Голосіївський', 0),
#  ('Амурська', 'вулиця', 'Голосіївський', 1916),
#  ('Амурська', 'площа', 'Голосіївський', 0),
#  ('Амурська', 'площа', 'Голосіївський', 1916),
#  ('Ананасна', 'вулиця', 'Подільський', 0),
#  ('Анатоліївська', 'вулиця', 'Деснянський', 2013),
#  ('Анатолія Кентія', 'вулиця', 'Голосіївський', 2019),
#  ('Анатолія Лупиноса', 'вулиця', 'Солом’янський', 0),
#  ("Анатолія Солов'яненка", 'вулиця', 'Дніпровський', 2009),
#  ('Андріївська', 'вулиця', 'Подільський', 2017),
#  ('Андріївський ', 'узвіз', 'Подільський', None),
#  ('Андрія Аболмасова ', 'вулиця', 'Дніпровський', None),
#  ('Андрія Кизила', 'вулиця', 'Дарницький', 2016),
#  ('Андрія Меленського', 'вулиця', 'Голосіївський', 1986),
#  ('Андрія Ніковського', 'вулиця', 'Голосіївський', 2019),
#  ('Андрія Первозванного', 'площа', 'Печерський', 1977),
#  ('Андрющенка Григорія', 'вулиця', 'Шевченківський', 0),
#  ('Анкари', 'площа', 'Деснянський', 2018),
#  ('Анни Ярославни', 'вулиця', 'Святошинський', 1983),
#  ('Антіна Ждановича', 'вулиця', "Солом'янський", 0),
#  ('Антона Цедіка', 'вулиця', 'Шевченківський', 1963),
#  ('Антоненка-Давидовича Бориса', 'вулиця', 'Дарницький', 2014),
#  ('Антоні Новосельського', 'вулиця', 'Святошинський', 1906),
#  ('Антонова Авіаконструктора', 'вулиця', "Солом'янський", 1962),
#  ('Антоновича', 'вулиця', 'Голосіївський, Печерський', 0),
#  ("Ареф'єва Костянтина", 'вулиця', 'Дарницький', 2017),
#  ('Аркасівська', 'вулиця', 'Оболонський', 2009),
#  ('Армійська ', 'вулиця', 'Голосіївський', None),
#  ('Арсенальна ', 'площа', 'Печерський', None),
#  ('Арсенальна ', 'вулиця', 'Печерський', None),
#  ('Арсенальний', 'провулок', 'Печерський', 2010),
#  ('Артезіанський', 'провулок', 'Подільський', 1969),
#  ('Артемія Веделя', 'вулиця', 'Голосіївський', 0),
#  ('Артилерійський', 'провулок', 'Шевченківський', 1983),
#  ('Архипа Люльки', 'вулиця', 'Солом’янський', 1892),
#  ('Архипенка Олександра', 'вулиця', 'Оболонський', 0),
#  ('Архітектора Дяченка', 'вулиця', 'Голосіївський', 2006),
#  ('Архітектора Кобелєва', 'вулиця', "Солом'янський", 2017),
#  ('Архітекторська', 'вулиця', "Солом'янський", 0),
#  ('Аскольдів', 'провулок', 'Печерський', 0),
#  ('Астраханська', 'вулиця', 'Дніпровський', 0),
#  ('Астраханський', 'провулок', 'Дніпровський', 2008),
#  ('Астрономічна', 'вулиця', 'Святошинський', 2010),
#  ('Атени Пашко', 'вулиця', 'Голосіївський', 1990),
#  ('Аттили Могильного', 'вулиця', 'Солом’янський', 2018),
#  ('Ахматової Анни', 'вулиця', 'Дарницький', 2014),
#  ('Бабушкіна', 'провулок', 'Шевченківський', 1906),
#  ('Багговутівська', 'вулиця', 'Шевченківський', 1962),
#  ('Багратіона', 'вулиця', "Солом'янський", 0),
#  ('Багряна Дуброва', 'вулиця', 'Голосіївський', 2017),
#  ('Багряного Івана', 'вулиця', 'Дніпровський', 2009),
#  ('Бажана Миколи', 'проспект', 'Дарницький', 2002),
#  ('Бажова', 'вулиця', 'Дніпровський', 1990),
#  ('Байкальська', 'вулиця', 'Голосіївський', 1971),
#  ('Байкова', 'вулиця', 'Голосіївський', 2010),
#  ('Бакинська', 'вулиця', 'Шевченківський', 1969),
#  ('Бакинський', 'провулок', 'Шевченківський', 0),
#  ('Баклажанна', 'вулиця', 'Подільський', 1983),
#  ('Бакуніна', 'вулиця', "Солом'янський", 1892),
#  ('Балакірева', 'вулиця', 'Голосіївський', 0),
#  ('Балаклієвська', 'вулиця', 'Шевченківський', 2006),
#  ('Балтійський', 'провулок', 'Оболонський', 2017),
#  ('Бальзака Оноре де', 'вулиця', 'Деснянський', 0),
#  ('Банкова', 'вулиця', 'Печерський', 0),
#  ('Баренбойма', 'вулиця', 'Голосіївський', 0),
#  ('Барикадна', 'вулиця', 'Голосіївський', 2008),
#  ('Баришівська', 'вулиця', 'Печерський', 2010),
#  ('Басейна', 'вулиця', 'Печерський, Шевченківський', 1990),
#  ('Бастіонна', 'вулиця', 'Печерський', 2018),
#  ('Бастіонний', 'провулок', 'Печерський', 1994),
#  ('Батумська', 'вулиця', 'Голосіївський', 2016),
#  ('Батуринська', 'вулиця', 'Дарницький', 2014),
#  ('Батуринський  ', 'провулок', 'Дарницький', None),
#  ('Баха Академіка ', 'вулиця', 'Дніпровський', None),
#  ('Бахмацька', 'вулиця', 'Святошинський', 1962),
#  ('Бджолиний', 'провулок', 'Дарницький', 2017),
#  ('Безручка Марка', 'вулиця', 'Шевченківський', 2013),
#  ('Бердичівська', 'вулиця', 'Шевченківський', 0),
#  ('Бердянська', 'вулиця', 'Шевченківський', 1969),
#  ('Бердянський', 'провулок', 'Шевченківський', 0),
#  ('Берегова', 'вулиця', 'Деснянський', 2020),
#  ('Бережанська', 'вулиця', 'Оболонський', 0),
#  ('Березнева', 'вулиця', 'Дніпровський', 2004),
#  ('Березнева', 'вулиця', 'Дніпровський', 2008),
#  ('Березнева', 'вулиця', 'Дарницький', 2004),
#  ('Березнева', 'вулиця', 'Дарницький', 2008),
#  ('Березневий', 'провулок', 'Дарницький', 2018),
#  ('Березневий 3', 'провулок', 'Дарницький', 2013),
#  ('Березняківська', 'вулиця', 'Дніпровський', 0),
#  ('Березова', 'вулиця', "Солом'янський", 2017),
#  ('Берестецька', 'вулиця', 'Оболонський', 2020),
#  ('Беретті Вікентія', 'вулиця', 'Деснянський', 2011),
#  ('Берізоньки (Озерна 14)', 'вулиця', 'Дарницький', 0),
#  ('Берковецька', 'вулиця', 'Святошинський', 2018),
#  ('Берлінського Максима', 'вулиця', 'Шевченківський', 2019),
#  ('Бессарабська', 'площа', 'Шевченківський', 2019),
#  ('Бестужева Олександра', 'провулок', 'Подільський', 1957),
#  ('Бестужева Олександра', 'провулок', 'Подільський', 2001),
#  ('Бестужева Олександра', 'вулиця', 'Подільський', 1957),
#  ('Бестужева Олександра', 'вулиця', 'Подільський', 2001),
#  ('Бетховена', 'вулиця', 'Святошинський', 2017),
#  ('Бехтерівський', 'провулок', 'Шевченківський', 2018),
#  ('Биківнянська', 'вулиця', 'Деснянський', 2013),
#  ('Биківнянський', 'провулок', 'Деснянський', 2007),
#  ('Биківський', 'провулок', 'Подільський', 0),
#  ('Бикова Леоніда', 'бульвар', 'Деснянський', 2020),
#  ('Бишівський', 'провулок', 'Дніпровський', 0),
#  ('Бігова ', 'вулиця', 'Деснянський', None),
#  ('Білаша Олександра', 'вулиця', 'Деснянський', 2015),
#  ('Білгородська', 'вулиця', "Солом'янський", 0),
#  ('Білецького Академіка', 'вулиця', "Солом'янський", 1963),
#  ('Білицька', 'вулиця', 'Подільський', 2019),
#  ('Білицький', 'провулок', 'Подільський', 2013),
#  ('Біличанська', 'вулиця', 'Святошинський', 0),
#  ('Білогородська', 'вулиця', 'Святошинський', 2018),
#  ('Білокур Катерини', 'вулиця', 'Печерський', 1981),
#  ('Біломорська', 'вулиця', 'Деснянський', 0),
#  ('Білоруська', 'вулиця', 'Шевченківський', 2015),
#  ('Біляшівського Академіка', 'вулиця', 'Святошинський', 2005),
#  ('Бірюзова Маршала', 'вулиця', 'Святошинський', 2003),
#  ('Блакитного', 'вулиця', 'Голосіївський', 0),
#  ('Блока Олександра', 'вулиця', 'Святошинський', 2019),
#  ('Бобринецька', 'вулиця', 'Деснянський', 1971),
#  ('Бобринецький', 'провулок', 'Деснянський', 0),
#  ('Бобруйський', 'провулок', 'Подільський', 1980),
#  ('Богатирська', 'вулиця', 'Оболонський', 1959),
#  ('Богатирський', 'проїзд', 'Оболонський', 2014),
#  ('Богдана Гаврилишина', 'вулиця', 'Шевченківський', 0),
#  ('Богданівська', 'вулиця', "Солом'янський", 0),
#  ('Богданівський', 'провулок', "Солом'янський", 1980),
#  ('Богомольця Академіка', 'вулиця', 'Печерський', 2019),
#  ('Богуна Івана', 'вулиця', 'Дарницький', 1993),
#  ('Богунська', 'вулиця', 'Голосіївський', 2003),
#  ('Богунський', 'провулок', 'Голосіївський', 2017),
#  ('Богуславський', 'узвіз', 'Подільський', 1996),
#  ('Богушевський', 'провулок', 'Деснянський', 0),
#  ('Божків Яр', 'вулиця', "Солом'янський", 0),
#  ('Бойка Івана', 'вулиця', 'Дарницький', 1914),
#  ('Бойова', 'вулиця', 'Голосіївський', 2005),
#  ('Бойчука Михайла', 'вулиця', 'Печерський', 0),
#  ('Болбочана Петра', 'вулиця', 'Печерський', 0),
#  ('Болсуновська', 'вулиця', 'Печерський', 0),
#  ('Бондарська', 'вулиця', 'Подільський', 0),
#  ('Бондарський', 'провулок', 'Подільський', 1999),
#  ('Бориса Матюшенка', 'вулиця', 'Голосіївський', 2007),
#  ('Бориса Мозолевського', 'вулиця', 'Голосіївський', 2009),
#  ('Бориса Тена', 'вулиця', 'Голосіївський', 2014),
#  ('Бориса Шахліна', 'провулок', 'Голосіївський', 2005),
#  ('Бориславська', 'вулиця', "Солом'янський", 2017),
#  ('Борисоглібська', 'вулиця', 'Подільський', 2007),
#  ('Бориспільська', 'вулиця', 'Дарницький', 0),
#  ('Бориспільське', 'шосе', 'Дарницький', 0),
#  ('Боричів ', 'узвіз', 'Подільський', None),
#  ('Боричів Тік', 'вулиця', 'Подільський', 0),
#  ('Борова', 'вулиця', 'Дарницький', 1977),
#  ('Борова', 'вулиця', 'Дарницький', 2014),
#  ('Борова', 'вулиця', 'Дарницький', 1977),
#  ('Борова', 'вулиця', 'Дарницький', 2014),
#  ('Боровий', 'провулок', 'Дарницький', 1974),
#  ('Боровий', 'провулок', 'Дарницький', 2005),
#  ('Боровий', 'провулок', 'Дарницький (Бортничі)', 1974),
#  ('Боровий', 'провулок', 'Дарницький (Бортничі)', 2005),
#  ('Боровиковського', 'вулиця', 'Оболонський', 1958),
#  ('Боровинська', 'вулиця', 'Подільський', 0),
#  ('Боровиченко Марії', 'вулиця', 'Голосіївський', 2017),
#  ('Бородянський ', 'провулок', 'Святошинський', None),
#  ('Бортницька', 'вулиця', 'Дарницький', 2005),
#  ('Бортницька', 'вулиця', 'Дарницький', 2012),
#  ('Бортницька', 'вулиця', 'Дарницький', 2005),
#  ('Бортницька', 'вулиця', 'Дарницький', 2012),
#  ('Бортницький', 'провулок', 'Дарницький', 1964),
#  ('Бортницький 1', 'провулок', 'Дарницький', 2015),
#  ('Бортницький 2', 'провулок', 'Дарницький', 2017),
#  ('Борщагівська', 'вулиця', "Солом'янський, Шевченківський ", 0),
#  ('Ботанічна', 'площа', 'Шевченківський', 2011),
#  ('Боткіна', 'вулиця', "Солом'янський", 1964),
#  ('Брановицького Ігоря', 'вулиця', 'Печерський', 2016),
#  ('Братиславська', 'вулиця', 'Деснянський, Дніпровський', 0),
#  ('Братів Зерових', 'вулиця', "Солом'янський", 2021),
#  ('Братів Шеметів', 'вулиця', 'Голосіївський', 1946),
#  ('Братська', 'вулиця', 'Подільський', 2017),
#  ('Брацлавська', 'вулиця', 'Дарницький', 1977),
#  ('Брест-Литовський', 'провулок', 'Шевченківський', 2018),
#  ('Брестська', 'вулиця', 'Подільський', 0),
#  ('Броварський', 'провулок', 'Деснянський', 2013),
#  ('Броварський', 'провулок', 'Деснянський', 2015),
#  ('Броварський', 'проспект', 'Деснянський, Дніпровський', 2013),
#  ('Броварський', 'проспект', 'Деснянський, Дніпровський', 2015),
#  ('Бродівська', 'вулиця', 'Голосіївський', 2001),
#  ('Бродівський', 'провулок', 'Голосіївський', 0),
#  ('Брусилівська', 'вулиця', 'Святошинський', 2015),
#  ('Брюлова', 'вулиця', "Солом'янський", 0),
#  ('Брюсова', 'вулиця', 'Подільський', 2003),
#  ('Брянська', 'вулиця', "Солом'янський", 1963),
#  ('Бугорна ', 'вулиця', 'Шевченківський', None),
#  ('Бугорний', 'провулок', 'Шевченківський', 1895),
#  ('Бударіна', 'вулиця', 'Святошинський', 0),
#  ('Будищанська', 'вулиця', 'Деснянський', 0),
#  ('Будівельників', 'провулок', 'Дніпровський', 0),
#  ('Будівельників', 'провулок', 'Дніпровський', 0),
#  ('Будівельників', 'провулок', 'Дніпровський', 1970),
#  ('Будівельників', 'провулок', 'Дніпровський', 2001),
#  ('Будівельників', 'вулиця', 'Дніпровський', 0),
#  ('Будівельників', 'вулиця', 'Дніпровський', 0),
#  ('Будівельників', 'вулиця', 'Дніпровський', 1970),
#  ('Будівельників', 'вулиця', 'Дніпровський', 2001),
#  ('Будівельників', 'вулиця', 'Деснянський', 0),
#  ('Будівельників', 'вулиця', 'Деснянський', 0),
#  ('Будівельників', 'вулиця', 'Деснянський', 1970),
#  ('Будівельників', 'вулиця', 'Деснянський', 2001),
#  ('Будівельників', 'провулок', 'Святошинський', 0),
#  ('Будівельників', 'провулок', 'Святошинський', 0),
#  ('Будівельників', 'провулок', 'Святошинський', 1970),
#  ('Будівельників', 'провулок', 'Святошинський', 2001),
#  ('Будіндустрії', 'вулиця', 'Голосіївський', 1973),
#  ('Бузинова', 'вулиця', 'Дарницький', 0),
#  ('Буйка Професора', 'вулиця', 'Голосіївський', 2010),
#  ('Букіної Раїси', 'вулиця', 'Святошинський', 0),
#  ('Букіної Раїси', 'вулиця', 'Святошинський', 1979),
#  ('Букіної Раїси', 'провулок', 'Святошинський', 0),
#  ('Букіної Раїси', 'провулок', 'Святошинський', 1979),
#  ('Буковинська', 'вулиця', 'Голосіївський', 2002),
#  ('Буковинський', 'провулок', 'Голосіївський', 2018),
#  ('Булаховського Академіка', 'вулиця', 'Святошинський', 2005),
#  ('Булгакова', 'вулиця', 'Святошинський', 0),
#  ('Бульварно-Кудрявська', 'вулиця', 'Шевченківський', 2019),
#  ('Бурденка', 'провулок', 'Подільський', 1975),
#  ('Бурмистенка', 'вулиця', 'Голосіївський', 2005),
#  ('Бурмистенка', 'вулиця', 'Голосіївський', 2010),
#  ('Бурмистенка', 'провулок', 'Голосіївський', 2005),
#  ('Бурмистенка', 'провулок', 'Голосіївський', 2010),
#  ('Буслівська', 'вулиця', 'Печерський', 2020),
#  ('Бутишів', 'провулок', 'Печерський', 1986),
#  ('Бутлерова Академіка', 'вулиця', 'Дніпровський', 0),
#  ('Бучанська', 'вулиця', 'Святошинський', 2005),
#  ('Бучми Амвросія', 'бульвар', 'Дніпровський', 2018),
#  ('В’ячеслава Липинського', 'вулиця', 'Шевченківський', 2011),
#  ('Вавілових', 'вулиця', 'Шевченківський', 2018),
#  ('Вакуленчука', 'вулиця', 'Дарницький', 1971),
#  ('Вакуленчука', 'вулиця', 'Дарницький', 2020),
#  ('Вакуленчука', 'провулок', 'Дарницький', 1971),
#  ('Вакуленчука', 'провулок', 'Дарницький', 2020),
#  ('Валентина Отамановського', 'вулиця', 'Голосіївський', 1960),
#  ('Валерія Марченка', 'площа', 'Подільський, Шевченківський', 2005),
#  ("Валер'яна Підмогильного", 'вулиця', 'Голосіївський', 0),
#  ('Валківська', 'вулиця', 'Подільський', 2006),
#  ('Василенка Миколи', 'вулиця', "Солом'янський", 1969),
#  ('Василівська', 'вулиця', "Солом'янський", 2015),
#  ('Васильківська', 'вулиця', 'Голосіївський', 0),
#  ('Васильківський', 'провулок', 'Голосіївський', 2006),
#  ('Васильченка', 'вулиця', "Солом'янський", 2019),
#  ('Василя Барки', 'вулиця', 'Солом’янський', 0),
#  ('Василя Біднова', 'вулиця', 'Деснянський', 2007),
#  ('Василя Вишиваного', 'вулиця', 'Дніпровський', 0),
#  ('Василя Макуха', 'вулиця', 'Шевченківський', 1973),
#  ('Василя Седляра', 'вулиця', "Солом'янський", 2012),
#  ('Василя Тютюнника', 'вулиця', 'Печерський', 2017),
#  ('Василя Щавинського', 'вулиця', 'Деснянський', 1997),
#  ('Васнецова', 'вулиця', 'Дніпровський', 1936),
#  ('Ватутіна', 'вулиця', "Солом'янський", 2005),
#  ('Ватутінський', 'провулок', 'Деснянський', 1971),
#  ('Ващенка Григорія', 'вулиця', 'Дарницький', 0),
#  ('Введенська', 'вулиця', 'Подільський', 1883),
#  ('Велика Васильківська',
#   'вулиця',
#   'Голосіївський, Шевченківський, Печерський',
#   2010),
#  ('Велика Житомирська', 'вулиця', 'Шевченківський', 2016),
#  ('Велика Китаївська', 'вулиця', 'Голосіївський', 2016),
#  ('Велика Кільцева', 'дорога', 'Оболонський', 2001),
#  ('Велика Окружна', 'вулиця', 'Святошинський', 0),
#  ('Вербицького Архітектора', 'вулиця', 'Дарницький', 2015),
#  ('Вербна', 'вулиця', 'Оболонський', 0),
#  ('Вербний', 'провулок', 'Деснянський', 0),
#  ('Вербова', 'вулиця', 'Оболонський', 0),
#  ('Верболозна', 'вулиця', 'Подільський', 0),
#  ('Верболозний', 'провулок', 'Подільський', 0),
#  ('Вересая Остапа', 'вулиця', 'Деснянський', 2013),
#  ('Вересковий', 'провулок', 'Дарницький', 0),
#  ('Вереснева', 'вулиця', 'Дарницький', 0),
#  ('Верещагіна', 'вулиця', 'Подільський', 0),
#  ('Вернадського Академіка', 'бульвар', 'Святошинський', 1982),
#  ('Верхній', 'провулок', 'Печерський', 0),
#  ('Верхній Вал', 'вулиця', 'Подільський', 0),
#  ('Верхньогірська', 'вулиця', 'Печерський', 1983),
#  ('Верхньоключова', 'вулиця', "Солом'янський", 0),
#  ('Верхня', 'вулиця', 'Печерський', 0),
#  ('Верховинна', 'вулиця', 'Святошинський', 2013),
#  ('Верховинця Василя', 'вулиця', 'Святошинський', 2014),
#  ('Верховної Ради', 'бульвар', 'Дніпровський, Деснянський', 2013),
#  ('Вершигори Петра', 'вулиця', 'Дніпровський', 2019),
#  ('Веселковий', 'провулок', 'Подільський', 0),
#  ('Весняна', 'вулиця', 'Голосіївський', 1905),
#  ('Вешенський', 'провулок', 'Деснянський', 0),
#  ('Виборзький', 'провулок', "Солом'янський", 2012),
#  ('Вигурівський', 'бульвар', 'Деснянський', 1959),
#  ('Видубицька', 'вулиця', 'Печерський', 2016),
#  ('Визволителів', 'проспект', 'Дніпровський', 0),
#  ('Винахідників', 'вулиця', 'Дніпровський', 0),
#  ('Винахідників', 'вулиця', 'Дніпровський', 1973),
#  ('Винахідників', 'провулок', 'Дніпровський', 0),
#  ('Винахідників', 'провулок', 'Дніпровський', 1973),
#  ('Виноградна', 'вулиця', "Солом'янський", 0),
#  ('Виноградний', 'провулок', 'Печерський', 2009),
#  ('Вирлицька', 'вулиця', 'Дарницький', 0),
#  ('Високовольтний', 'провулок', 'Дарницький', 0),
#  ('Висоцького Володимира', 'бульвар', 'Деснянський', 2003),
#  ('Вифлеємська', 'вулиця', 'Дніпровський', 1971),
#  ('Вишгородська', 'вулиця', 'Подільський, Оболонський', 0),
#  ('Вишнева', 'вулиця', "Солом'янський", 0),
#  ('Вишнева', 'вулиця', "Солом'янський", 1982),
#  ('Вишнева', 'вулиця', "Солом'янський", 1983),
#  ('Вишнева', 'вулиця', "Солом'янський", 2015),
#  ('Вишнева', 'вулиця', 'Святошинський', 0),
#  ('Вишнева', 'вулиця', 'Святошинський', 1982),
#  ('Вишнева', 'вулиця', 'Святошинський', 1983),
#  ('Вишнева', 'вулиця', 'Святошинський', 2015),
#  ('Вишнева', 'вулиця', 'Оболонський', 0),
#  ('Вишнева', 'вулиця', 'Оболонський', 1982),
#  ('Вишнева', 'вулиця', 'Оболонський', 1983),
#  ('Вишнева', 'вулиця', 'Оболонський', 2015),
#  ('Вишнева', 'вулиця', 'Дарницький', 0),
#  ('Вишнева', 'вулиця', 'Дарницький', 1982),
#  ('Вишнева', 'вулиця', 'Дарницький', 1983),
#  ('Вишнева', 'вулиця', 'Дарницький', 2015),
#  ('Вишнева (Озерна 3)', 'вулиця', 'Дарницький', 0),
#  ('Вишняківська', 'вулиця', 'Дарницький', 1961),
#  ('Відпочинку', 'вулиця', 'Святошинський', 2019),
#  ('Відрадний', 'проспект', "Солом'янський, Святошинський", 0),
#  ('Військова', 'вулиця', 'Голосіївський', 0),
#  ('Військовий', 'проїзд', 'Печерський', 2018),
#  ('Віктора Зарецького', 'вулиця', 'Голосіївський', 2016),
#  ('Вільде Едуарда', 'вулиця', 'Дніпровський', 2020),
#  ('Вільнюська', 'вулиця', 'Дніпровський', 2018),
#  ('Вільхова ', 'вулиця', 'Дніпровський', None),
#  ('Вільшанська', 'вулиця', 'Печерський', 2006),
#  ('Вільшанський ', 'провулок', 'Печерський', None),
#  ('Вільямса Академіка', 'вулиця', 'Голосіївський', 0),
#  ('Вінграновського Миколи', 'вулиця', 'Дарницький', 2015),
#  ('Вінницька', 'вулиця', "Солом'янський", 2014),
#  ('Вірменська', 'вулиця', 'Дарницький', 0),
#  ('Вірменський', 'провулок', 'Дарницький', 2004),
#  ('Вірності', 'вулиця', 'Деснянський', 0),
#  ('Вірського Павла', 'вулиця', 'Деснянський', 2018),
#  ('Вірьовки Григорія', 'вулиця', 'Деснянський', 2012),
#  ('Віскозна', 'вулиця', 'Дніпровський, Деснянський', 2015),
#  ('Вітавська', 'вулиця', 'Голосіївський', 2018),
#  ('Віто-Литовський', 'провулок', 'Голосіївський', 1977),
#  ('Вітрука Генерала', 'вулиця', 'Святошинський', 2012),
#  ('Вітряні Гори', 'вулиця', 'Подільський', 2006),
#  ('Вітчизняна', 'вулиця', 'Подільський', 2015),
#  ('Вітянська', 'вулиця', 'Голосіївський', 1966),
#  ('Владлена Кузнецова', 'вулиця', 'Деснянський', 2019),
#  ('Водників', 'вулиця', 'Подільський', 2018),
#  ('Водогінна', 'вулиця', 'Голосіївський', 0),
#  ('Воздвиженська', 'вулиця', 'Подільський', 0),
#  ('Воздвиженський', 'провулок', 'Подільський', 2014),
#  ('Вознесенський', 'узвіз', 'Шевченківський', 0),
#  ('Вокзальна', 'площа', "Солом'янський", 0),
#  ('Вокзальна', 'площа', "Солом'янський", 2017),
#  ('Вокзальна', 'вулиця', "Солом'янський, Шевченківський", 0),
#  ('Вокзальна', 'вулиця', "Солом'янський, Шевченківський", 2017),
#  ('Волгоградська', 'вулиця', "Солом'янський", 1879),
#  ('Волгоградська', 'вулиця', "Солом'янський", 2018),
#  ('Волгоградська', 'площа', 'Деснянський', 1879),
#  ('Волгоградська', 'площа', 'Деснянський', 2018),
#  ('Волго-Донська', 'вулиця', 'Дарницький', 1991),
#  ('Волго-Донський', 'провулок', 'Дарницький', 0),
#  ('Волзька', 'вулиця', 'Голосіївський', 0),
#  ('Волзький', 'провулок', 'Голосіївський', 1961),
#  ('Волинська', 'вулиця', "Солом'янський", 2017),
#  ('Волкова Космонавта', 'вулиця', 'Деснянський', 0),
#  ('Володарська', 'вулиця', 'Голосіївський', 1913),
#  ('Володимира Беца', 'вулиця', 'Деснянський', 0),
#  ('Володимира Брожка', 'вулиця', "Голосіївський, Солом'янський", 0),
#  ('Володимира Винниченка', 'вулиця', 'Шевченківський', 1999),
#  ('Володимира Горовиця', 'вулиця', 'Голосіївський', 1961),
#  ('Володимира Науменко', 'вулиця', 'Голосіївський', 0),
#  ('Володимиро-Либідська', 'вулиця', 'Голосіївський', 0),
#  ('Володимирська', 'вулиця', 'Голосіївський, Шевченківський', 0),
#  ('Володимирський', 'узвіз', 'Печерський, Подільський, Шевченківський', 0),
#  ('Володимирський', 'узвіз', 'Печерський, Подільський, Шевченківський', 2013),
#  ('Володимирський', 'проїзд', 'Шевченківський', 0),
#  ('Володимирський', 'проїзд', 'Шевченківський', 2013),
#  ('Волоська', 'вулиця', 'Подільський', 2013),
#  ('Волошкова', 'вулиця', "Солом'янський", 0),
#  ('Волошковий', 'провулок', 'Деснянський', 1993),
#  ('Волховська', 'вулиця', 'Дніпровський', 0),
#  ('Волховський', 'провулок', 'Дніпровський', 2016),
#  ('Воскресенська', 'вулиця', 'Дніпровський', 2018),
#  ('Восьмого Березня', 'вулиця', 'Оболонський', 0),
#  ('Врубелівський', 'узвіз', 'Шевченківський', 2015),
#  ('Всеволода Змієнка', 'вулиця', 'Подільський', 2019),
#  ('Вузівська', 'вулиця', "Солом'янський", 0),
#  ('Вуликова', 'вулиця', 'Дарницький', 0),
#  ('Вчительська', 'вулиця', "Солом'янський", 2010),
#  ('Гаванська', 'вулиця', 'Подільський', 2005),
#  ('Гаванський', 'провулок', 'Оболонський', 2011),
#  ('Гавела Вацлава', 'бульвар', "Солом'янський", 2007),
#  ('Гаврилюка', 'вулиця', 'Солом’янський', 2009),
#  ('Гагаріна Юрія', 'проспект', 'Деснянський, Дніпровський', 0),
#  ('Газова', 'вулиця', 'Солом’янський', 2003),
#  ('Газопровідна', 'вулиця', 'Подільський, Святошинський', 2014),
#  ('Гайдай Зої', 'вулиця', 'Оболонський', 1999),
#  ('Гайова', 'вулиця', 'Солом’янський', 2018),
#  ('Гайсинська', 'вулиця', 'Солом’янський', 2020),
#  ('Галерна', 'вулиця', 'Голосіївський', 2018),
#  ('Галицька', 'вулиця', 'Подільський', 1972),
#  ('Ганни Арендт', 'вулиця', "Солом'янський", 2018),
#  ('Ганни Барвінок', 'вулиця', 'Оболонський', 2011),
#  ('Гаражна', 'вулиця', 'Дніпровський', 0),
#  ('Гаражна', 'вулиця', 'Дніпровський', 2019),
#  ('Гаражна', 'вулиця', 'Дарницький', 0),
#  ('Гаражна', 'вулиця', 'Дарницький', 2019),
#  ('Гарета Джонса', 'провулок', 'Шевченківський', 2007),
#  ('Гаріна Бориса', 'вулиця', 'Солом’янський', 0),
#  ('Гарматна', 'вулиця', 'Солом’янський', 1978),
#  ('Гаршина', 'вулиця', 'Святошинський', 1858),
#  ('Гастелло Миколи', 'вулиця', 'Печерський', 1974),
#  ('Гатна', 'вулиця', 'Голосіївський', 2017),
#  ('Гашека Ярослава', 'бульвар', 'Дніпровський', 0),
#  ('Гвардійська', 'вулиця', 'Голосіївський', 2008),
#  ('Генерала Алмазова', 'вулиця', 'Печерський', 0),
#  ('Генерала Гандзюка', 'вулиця', 'Оболонський', 0),
#  ('Генерала Генадія Воробйова', 'вулиця', "Солом'янський", 2007),
#  ('Генерала Грекова', 'вулиця', 'Подільський', 2014),
#  ('Генерала Павленка', 'вулиця', "Солом'янський", 2016),
#  ('Генерала Шаповала', 'вулиця', "Солом'янський", 1993),
#  ('Георгіївський', 'провулок', 'Шевченківський', 1978),
#  ('Геофізиків', 'вулиця', 'Дарницький', 0),
#  ('Геофізиків', 'вулиця', 'Дарницький', 2016),
#  ('Геофізиків', 'провулок', 'Дарницький', 0),
#  ('Геофізиків', 'провулок', 'Дарницький', 2016),
#  ('Герасименка Костянтина', 'вулиця', 'Святошинський', 1936),
#  ('Героїв Бресту', 'площа', 'Святошинський', 0),
#  ('Героїв Великої Вітчизняної війни', 'площа', 'Печерський', 2005),
#  ('Героїв Війни', 'вулиця', 'Солом’янський', 1959),
#  ('Героїв Дніпра', 'вулиця', 'Оболонський', 2001),
#  ('Героїв Космосу', 'вулиця', 'Святошинський', 2015),
#  ('Героїв Крут', 'алея', 'Печерський', 1988),
#  ('Героїв Небесної Сотні', 'алея', 'Печерський', 1981),
#  ('Героїв Оборони', 'вулиця', 'Голосіївський', 1936),
#  ('Героїв Севастополя', 'вулиця', "Солом'янський", 2019),
#  ('Героїв Сталінграда', 'проспект', 'Оболонський', 2005),
#  ('Герцена', 'вулиця', 'Шевченківський', 0),
#  ('Герцена', 'вулиця', 'Шевченківський', 1965),
#  ('Герцена', 'вулиця', 'Шевченківський', 2018),
#  ('Герцена', 'узвіз', 'Шевченківський', 0),
#  ('Герцена', 'узвіз', 'Шевченківський', 1965),
#  ('Герцена', 'узвіз', 'Шевченківський', 2018),
#  ('Герцена', 'провулок', 'Шевченківський', 0),
#  ('Герцена', 'провулок', 'Шевченківський', 1965),
#  ('Герцена', 'провулок', 'Шевченківський', 2018),
#  ('Гетьмана Вадима', 'вулиця', "Солом'янський", 0),
#  ('Гійома де Боплана', 'вулиця', 'Деснянський', 2010),
#  ('Гіллястий', 'провулок', 'Дніпровський', 2014),
#  ('Гладківська', 'вулиця', "Солом'янський", 2016),
#  ('Глазунова', 'вулиця', 'Печерський', 2002),
#  ('Глибочицька', 'вулиця', 'Шевченківський', 0),
#  ('Глибочицький', 'проїзд', 'Шевченківський', 0),
#  ('Глібова', 'вулиця', 'Шевченківський', 1963),
#  ('Глієра Рейнгольда', 'вулиця', 'Святошинський', 2005),
#  ('Глінки', 'вулиця', 'Солом’янський', 2016),
#  ('Глухівська', 'вулиця', 'Подільський', 2018),
#  ('Глушкова Академіка', 'проспект', 'Голосіївський', 2015),
#  ('Гмирі Бориса', 'вулиця', 'Дарницький', 1985),
#  ('Говорова Маршала', 'вулиця', 'Голосіївський', 2007),
#  ('Говорова Маршала', 'вулиця', 'Голосіївський', 2010),
#  ('Говорова Маршала', 'провулок', 'Голосіївський', 2007),
#  ('Говорова Маршала', 'провулок', 'Голосіївський', 2010),
#  ('Гоголівська', 'вулиця', 'Шевченківський', 0),
#  ('Гоголя', 'вулиця', 'Солом’янський', 0),
#  ('Гоголя', 'вулиця', 'Солом’янський', 1970),
#  ('Гоголя', 'вулиця', 'Солом’янський', 2014),
#  ('Гоголя', 'вулиця', 'Дарницький', 0),
#  ('Гоголя', 'вулиця', 'Дарницький', 1970),
#  ('Гоголя', 'вулиця', 'Дарницький', 2014),
#  ('Гоголя', 'вулиця', 'Деснянський', 0),
#  ('Гоголя', 'вулиця', 'Деснянський', 1970),
#  ('Гоголя', 'вулиця', 'Деснянський', 2014),
#  ('Гоголя 2', 'провулок', 'Дарницький', 1975),
#  ('Голованьова Степана', 'вулиця', 'Дарницький', 2014),
#  ('Головка Андрія', 'вулиця', 'Солом’янський', 2012),
#  ('Голосіївська', 'площа', 'Голосіївський', 0),
#  ('Голосіївська', 'площа', 'Голосіївський', 2019),
#  ('Голосіївська', 'вулиця', 'Голосіївський', 0),
#  ('Голосіївська', 'вулиця', 'Голосіївський', 2019),
#  ('Голосіївський', 'проспект', 'Голосіївський', 1974),
#  ('Голосіївський', 'проспект', 'Голосіївський', 2019),
#  ('Голосіївський', 'провулок', 'Голосіївський', 1974),
#  ('Голосіївський', 'провулок', 'Голосіївський', 2019),
#  ('Гомельська', 'вулиця', 'Подільський', 1975),
#  ('Гомельський', 'провулок', 'Подільський', 2002),
#  ('Гонгадзе Георгія', 'проспект', 'Подільський', 1998),
#  ('Гонти Івана', 'вулиця', 'Шевченківський', 2016),
#  ('Гончара Олеся', 'вулиця', 'Шевченківський', 2016),
#  ('Гончарна', 'вулиця', 'Подільський', 2012),
#  ('Гончарова', 'вулиця', 'Шевченківський', 0),
#  ('Горбунова Академіка', 'вулиця', 'Дарницький', 2008),
#  ('Горенська', 'вулиця', 'Святошинський', 2013),
#  ('Гориста', 'вулиця', 'Голосіївський', 1969),
#  ('Гористий', 'провулок', 'Голосіївський', 2020),
#  ('Горіхова', 'вулиця', "Солом'янський", 1913),
#  ('Горіхова (Озерна 5)', 'вулиця', 'Дарницький', 2017),
#  ('Горлівська', 'вулиця', 'Дарницький', 2017),
#  ('Городецького Архітектора', 'вулиця', 'Печерський', 2020),
#  ('Городище', 'вулиця', 'Деснянський', 0),
#  ('Городищенська', 'вулиця', 'Подільський', 1954),
#  ('Городня', 'вулиця', 'Солом’янський', 0),
#  ('Горюшка Георгія', 'вулиця', 'Голосіївський', 1936),
#  ('Госпітальна', 'вулиця', 'Печерський', 2016),
#  ('Госпітальний', 'провулок', 'Печерський', 2018),
#  ('Гостинна', 'вулиця', 'Дарницький', 0),
#  ('Гостинний', 'провулок', 'Дарницький', 2019),
#  ('Гостомельська', 'вулиця', 'Святошинський', 0),
#  ('Гостомельська', 'вулиця', 'Святошинський', 2014),
#  ('Гостомельська', 'площа', 'Святошинський', 0),
#  ('Гостомельська', 'площа', 'Святошинський', 2014),
#  ('Гостомельське', 'шосе', 'Оболонський', 0),
#  ('Грабовського Павла', 'вулиця', 'Голосіївський', 2003),
#  ('Грабовського Павла', 'вулиця', 'Голосіївський', 2009),
#  ('Грабовського Павла', 'провулок', 'Голосіївський', 2003),
#  ('Грабовського Павла', 'провулок', 'Голосіївський', 2009),
#  ('Градинська', 'вулиця', 'Деснянський', 1964),
#  ('Гранична', 'вулиця', 'Святошинський', 1986),
#  ('Гребінки', 'вулиця', 'Голосіївський', 0),
#  ('Грекова Академіка', 'вулиця', 'Шевченківський', 2011),
#  ('Гречаний', 'провулок', 'Дарницький', 0),
#  ('Григоренка Петра', 'проспект', 'Дарницький', 0),
#  ('Григорія Голоскевича', 'вулиця', 'Голосіївський', 2018),
#  ('Григорія Косинки', 'вулиця', 'Деснянський', 0),
#  ('Григоровича-Барського', 'вулиця', 'Святошинський', 0),
#  ('Гришка Миколи', 'вулиця', 'Деснянський', 2010),
#  ('Гришка Михайла', 'вулиця', 'Дарницький', 2017),
#  ('Грінченка Бориса', 'вулиця', 'Шевченківський', 2017),
#  ('Грінченка Миколи', 'вулиця', 'Голосіївський, Солом’янський', 0),
#  ('Гродненська', 'вулиця', 'Дніпровський', 1955),
#  ('Гродненський', 'провулок', 'Дніпровський', 0),
#  ('Грозненська', 'вулиця', 'Шевченківський', 2018),
#  ('Громадська', 'вулиця', 'Солом’янський', 2014),
#  ('Громової Уляни', 'вулиця', 'Солом’янський', 0),
#  ('Грузинська', 'вулиця', 'Дарницький', 0),
#  ('Грузинський', 'провулок', 'Дарницький', 2015),
#  ('Грушева', 'вулиця', "Солом'янський", 2002),
#  ('Грушевського Михайла', 'вулиця', 'Печерський', 2016),
#  ('Гулака Миколи', 'вулиця', 'Оболонський', 2019),
#  ('Гурамішвілі Давида', 'вулиця', 'Святошинський', 0),
#  ('Гусовського', 'вулиця', 'Печерський', 0),
#  ('Гучний', 'провулок', 'Солом’янський', 2019),
#  ('Ґалаґанівська', 'вулиця', 'Святошинський', 0),
#  ('Ґренджі-Донського', 'вулиця', "Солом'янський", 1975),
#  ('Далека', 'вулиця', "Солом'янський", 2017),
#  ('Даля Олександра', 'вулиця', 'Деснянський', 2010),
#  ('Дамбова', 'вулиця', 'Дніпровський', 1977),
#  ('Дамбова 1', 'вулиця', 'Дніпровський', 2019),
#  ('Дамбова 2', 'вулиця', 'Дніпровський', 0),
#  ('Дамбова 3', 'вулиця', 'Дніпровський', 2019),
#  ('Данченка Сергія', 'вулиця', 'Подільський', 2013),
#  ('Данькевича Костянтина', 'вулиця', 'Деснянський', 2018),
#  ('Дарвіна', 'вулиця', 'Печерський', 2019),
#  ('Дарницька', 'площа', 'Дніпровський', 2018),
#  ('Дарницький', 'бульвар', 'Дніпровський', 2009),
#  ('Дачна', 'вулиця', 'Деснянський', 0),
#  ('Дачний', 'провулок', 'Деснянський', 1961),
#  ('Дашавська', 'вулиця', "Солом'янський", 2003),
#  ('Двінська', 'вулиця', 'Дніпровський', 2018),
#  ('Дегтярівська', 'вулиця', 'Шевченківський', 2008),
#  ('Дегтярна', 'вулиця', 'Подільський', 1967),
#  ('Дежнєва', 'вулиця', "Солом'янський", 1936),
#  ('Дежнєва', 'вулиця', "Солом'янський", 2017),
#  ('Дежнєва', 'провулок', "Солом'янський", 1936),
#  ('Дежнєва', 'провулок', "Солом'янський", 2017),
#  ('Декабристів', 'вулиця', 'Дарницький', 0),
#  ('Делегатський', 'провулок', 'Шевченківський', 2010),
#  ('Демидівська', 'вулиця', 'Дарницький', 2019),
#  ('Деміївська', 'площа', 'Голосіївський', 2012),
#  ('Деміївська', 'площа', 'Голосіївський', 2013),
#  ('Деміївська', 'вулиця', 'Голосіївський', 2012),
#  ('Деміївська', 'вулиця', 'Голосіївський', 2013),
#  ('Деміївський', 'провулок', 'Голосіївський', 0),
#  ('Депутатська', 'вулиця', 'Святошинський', 0),
#  ('Деревлянська', 'вулиця', 'Шевченківський', 0),
#  ('Деревообробна', 'вулиця', 'Голосіївський', 2013),
#  ('Деревообробний', 'провулок', 'Голосіївський', 0),
#  ('Десенський ', 'провулок', 'Деснянський', None),
#  ('Деснянська', 'вулиця', "Солом'янський", 1985),
#  ('Деснянська', 'вулиця', "Солом'янський", 1989),
#  ('Деснянська', 'вулиця', "Солом'янський", 2018),
#  ('Деснянська', 'вулиця', 'Деснянський', 1985),
#  ('Деснянська', 'вулиця', 'Деснянський', 1989),
#  ('Деснянська', 'вулиця', 'Деснянський', 2018),
#  ('Деснянська', 'вулиця', 'Дніпровський', 1985),
#  ('Деснянська', 'вулиця', 'Дніпровський', 1989),
#  ('Деснянська', 'вулиця', 'Дніпровський', 2018),
#  ('Деснянський', 'провулок', 'Деснянський', 2019),
#  ('Десятинна', 'вулиця', 'Шевченківський', 1998),
#  ('Десятинний', 'провулок', 'Шевченківський', 2013),
#  ('Джаліля Муси', 'вулиця', 'Подільський', 2008),
#  ('Джеймса Мейса', 'вулиця', "Солом'янський", 2015),
#  ('Джерельна', 'вулиця', 'Оболонський', 0),
#  ('Джерельна', 'вулиця', 'Оболонський', 2019),
#  ('Джерельна', 'вулиця', 'Дарницький', 0),
#  ('Джерельна', 'вулиця', 'Дарницький', 2019),
#  ('Джерельний', 'провулок', 'Оболонський', 2018),
#  ('Джона Маккейна', 'вулиця', 'Печерський', 2006),
#  ('Дзиґи Вертова', 'провулок', 'Дніпровський', 1972),
#  ('Диканський', 'провулок', 'Дарницький', 1976),
#  ('Димерська', 'вулиця', 'Святошинський', 1914),
#  ('Діамантовий', 'провулок', 'Деснянський', 0),
#  ('Дібровна ', 'вулиця', 'Голосіївський', None),
#  ('Дібровний', 'провулок', 'Голосіївський', 2008),
#  ('Ділова', 'вулиця', 'Голосіївський, Печерський', 2017),
#  ('Дмитра Григоровича', 'вулиця', 'Солом’янський', 1973),
#  ('Дмитра Загула', 'вулиця', 'Деснянський', 1956),
#  ('Дмитрівська', 'вулиця', 'Шевченківський', 1981),
#  ('Дмитрівська', 'вулиця', 'Шевченківський', 2020),
#  ('Дмитрівська', 'вулиця', 'Подільський', 1981),
#  ('Дмитрівська', 'вулиця', 'Подільський', 2020),
#  ('Дніпрова', 'вулиця', 'Дарницький', 0),
#  ('Дніпровий', 'провулок', 'Дарницький', 0),
#  ('Дніпроводська', 'вулиця', 'Оболонський', 0),
#  ('Дніпровська', 'вулиця', 'Оболонський', 1940),
#  ('Дніпровська', 'вулиця', 'Оболонський', 2005),
#  ('Дніпровська ', 'набережна', 'Дніпровський, Дарницький', None),
#  ('Дніпровське', 'шосе', 'Голосіївський', 0),
#  ('Дніпровський ', 'узвіз', 'Печерський', None),
#  ('Дністровська', 'вулиця', "Солом'янський", 2018),
#  ('Добрий Шлях', 'вулиця', 'Голосіївський', 2010),
#  ('Добринінська', 'вулиця', 'Оболонський', 2022),
#  ('Добробутна', 'вулиця', "Солом'янський", 2006),
#  ('Добровольчих батальйонів', 'вулиця', 'Печерський', 1957),
#  ('Добролюбова', 'вулиця', 'Печерський', 2004),
#  ('Добролюбова', 'вулиця', 'Печерський', 2019),
#  ('Добролюбова', 'провулок', 'Печерський', 2004),
#  ('Добролюбова', 'провулок', 'Печерський', 2019),
#  ('Добросусідська', 'вулиця', "Солом'янський", 2016),
#  ('Добросусідський', 'провулок', "Солом'янський", 1977),
#  ('Доброхотова Академіка', 'вулиця', 'Святошинський', 0),
#  ('Добрузька', 'вулиця', "Солом'янський", 1973),
#  ('Доватора Генерала', 'вулиця', 'Голосіївський', 0),
#  ('Доватора Генерала', 'вулиця', 'Голосіївський', 0),
#  ('Доватора Генерала', 'провулок', 'Голосіївський', 0),
#  ('Доватора Генерала', 'провулок', 'Голосіївський', 0),
#  ('Довбуша Олекси', 'вулиця', 'Дніпровський', 2015),
#  ('Довженка', 'вулиця', 'Деснянський', 2018),
#  ('Довженка Олександра', 'вулиця', 'Шевченківський', 1910),
#  ('Докучаєвська', 'вулиця', "Солом'янський", 0),
#  ('Докучаєвський', 'тупик', "Солом'янський", 1967),
#  ('Докучаєвський', 'тупик', "Солом'янський", 1972),
#  ('Докучаєвський', 'провулок', "Солом'янський", 1967),
#  ('Докучаєвський', 'провулок', "Солом'янський", 1972),
#  ('Долинна', 'вулиця', "Солом'янський", 2010),
#  ('Донецька', 'вулиця', "Солом'янський", 0),
#  ('Донецький', 'провулок', "Солом'янський", 2013),
#  ('Донська', 'вулиця', "Солом'янський", 2013),
#  ('Донський', 'провулок', "Солом'янський", 1961),
#  ('Донця Михайла', 'вулиця', "Солом'янський", 2017),
#  ('Дончука Василя', 'вулиця', 'Шевченківський', 0),
#  ('Дорогожицька', 'вулиця', 'Шевченківський', 2005),
#  ('Достоєвського', 'провулок', 'Подільський', 2007),
#  ('Достоєвського', 'провулок', 'Подільський', 2017),
#  ('Достоєвського', 'вулиця', 'Подільський', 2007),
#  ('Достоєвського', 'вулиця', 'Подільський', 2017),
#  ('Драгоманова', 'вулиця', 'Дарницький', 0),
#  ('Драгомирова Михайла', 'вулиця', 'Печерський', 1955),
#  ('Драйзера Теодора', 'вулиця', 'Деснянський', 2020),
#  ('Драй-Хмари Михайла', 'вулиця', 'Святошинський', 0),
#  ('Друга', 'вулиця', 'Оболонський', 0),
#  ('Дружби', 'вулиця', 'Дарницький', 2013),
#  ('Дружби 1', 'провулок', 'Дарницький', 2013),
#  ('Дружби 2', 'провулок', 'Дарницький', 1977),
#  ('Дружби 3', 'провулок', 'Дарницький', 0),
#  ('Дружби Народів', 'бульвар', 'Печерський', 0),
#  ('Дружківська', 'вулиця', 'Святошинський', 0),
#  ('Дружня', 'вулиця', "Солом'янський", 0),
#  ('Дубенська', 'вулиця', 'Печерський', 1954),
#  ('Дубичнянська', 'вулиця', 'Деснянський', 1972),
#  ('Дубищанська', 'вулиця', 'Оболонський', 0),
#  ('Дубищанський', 'провулок', 'Оболонський', 2018),
#  ('Дубініна Володі', 'вулиця', 'Голосіївський', 2018),
#  ('Дубка (Озерна 15)', 'вулиця', 'Дарницький', 1957),
#  ('Дубровицька', 'вулиця', 'Оболонський', 2009),
#  ('Дубровицький', 'провулок', 'Оболонський', 0),
#  ('Дубровського Віктора', 'провулок', 'Святошинський', 2019),
#  ('Дудника Георгія', 'вулиця', 'Шевченківський', 0),
#  ('Дуки Степана', 'вулиця', 'Голосіївський', 0),
#  ('Дунаєвського', 'вулиця', 'Святошинський', 2005),
#  ('Дунаєвського', 'вулиця', 'Святошинський', 2018),
#  ('Дунаєвського', 'провулок', 'Святошинський', 2005),
#  ('Дунаєвського', 'провулок', 'Святошинський', 2018),
#  ('Дурдуківського Володимира', 'вулиця', 'Святошинський', 2017),
#  ('Дяченка Івана', 'вулиця', 'Дарницький', 2011),
#  ('Екскаваторна', 'вулиця', 'Святошинський', 0),
#  ('Електриків', 'вулиця', 'Подільський', 1977),
#  ('Електриків', 'вулиця', 'Подільський', 2015),
#  ('Електриків', 'провулок', 'Подільський', 1977),
#  ('Електриків', 'провулок', 'Подільський', 2015),
#  ('Електротехнічна', 'вулиця', 'Деснянський', 1987),
#  ('Енгельса', 'провулок', 'Дарницький', 0),
#  ('Енгельса', 'провулок', 'Дарницький', 1995),
#  ('Енгельса', 'вулиця', 'Дарницький', 0),
#  ('Енгельса', 'вулиця', 'Дарницький', 1995),
#  ('Енергетиків', 'вулиця', "Солом'янський", 1961),
#  ('Енергетиків', 'вулиця', "Солом'янський", 2000),
#  ('Енергетиків', 'вулиця', "Солом'янський", 2005),
#  ('Енергетиків', 'вулиця', 'Дніпровський', 1961),
#  ('Енергетиків', 'вулиця', 'Дніпровський', 2000),
#  ('Енергетиків', 'вулиця', 'Дніпровський', 2005),
#  ('Енергетиків', 'провулок', "Солом'янський", 1961),
#  ('Енергетиків', 'провулок', "Солом'янський", 2000),
#  ('Енергетиків', 'провулок', "Солом'янський", 2005),
#  ('Ентузіастів', 'вулиця', 'Дніпровський', 2008),
#  ('Ентузіастів 1', 'вулиця', 'Дарницький', 2018),
#  ('Ентузіастів 10', 'вулиця', 'Дарницький', 2014),
#  ('Ентузіастів 2', 'вулиця', 'Дарницький', 0),
#  ('Ентузіастів 3', 'вулиця', 'Дарницький', 0),
#  ('Ентузіастів 4', 'вулиця', 'Дарницький', 2010),
#  ('Ентузіастів 5', 'вулиця', 'Дарницький', 1966),
#  ('Ентузіастів 6', 'вулиця', 'Дарницький', 0),
#  ('Ентузіастів 7', 'вулиця', 'Дарницький', 2005),
#  ('Ентузіастів 8', 'вулиця', 'Дарницький', 2015),
#  ('Ентузіастів 9', 'вулиця', 'Дарницький', 0),
#  ('Еренбурга Іллі', 'вулиця', 'Голосіївський', 1962),
#  ('Ернста Федора', 'вулиця', "Солом'янський", 2015),
#  ('Еспланадна', 'вулиця', 'Печерський', 2012),
#  ('Естонська', 'вулиця', 'Шевченківський', 1903),
#  ('Естонський', 'провулок', 'Шевченківський', 1998),
#  ('Євгена Гуцала', 'провулок', 'Печерський', 2016),
#  ('Євгена Коновальця', 'вулиця', 'Печерський', 2020),
#  ('Євгена Плужника', 'вулиця', 'Деснянський', 1938),
#  ('Євгена Сверстюка', 'вулиця', 'Дніпровський', 0),
#  ('Європейська', 'площа', 'Печерський', 0),
#  ('Єдності', 'вулиця', 'Деснянський', 1966),
#  ('Єжи Ґедройця', 'вулиця', 'Голосіївський, Печерський', 1937),
#  ('Єнісейська', 'вулиця', 'Голосіївський', 2019),
#  ('Єреванська', 'вулиця', "Солом'янський", 2019),
#  ('Єрмака', 'вулиця', 'Оболонський', 0),
#  ('Єсеніна Сергія', 'вулиця', 'Святошинський', 2019),
#  ('Жабаєва Жамбила', 'вулиця', 'Шевченківський', 1985),
#  ('Жашківська', 'вулиця', 'Подільський', 0),
#  ('Живописна', 'вулиця', 'Святошинський', 1981),
#  ('Жигулівська', 'вулиця', 'Голосіївський', 0),
#  ('Жилянська', 'вулиця', 'Печерський, Голосіївський, Шевченківський', 2011),
#  ('Житкова Бориса', 'вулиця', 'Шевченківський', 0),
#  ('Житньоторзька', 'вулиця', 'Подільський', 0),
#  ('Житньоторзька', 'вулиця', 'Подільський', 1983),
#  ('Житньоторзька', 'площа', 'Подільський', 0),
#  ('Житньоторзька', 'площа', 'Подільський', 1983),
#  ('Жмаченка Генерала', 'вулиця', 'Дніпровський', 0),
#  ('Жмеринська', 'вулиця', 'Святошинський', 2018),
#  ('Жмеринський', 'провулок', 'Святошинський', 0),
#  ('Жовтнева', 'вулиця', 'Святошинський', 2019),
#  ('Жовтневий', 'провулок', 'Святошинський', 2004),
#  ('Жолудєва', 'вулиця', 'Святошинський', 2014),
#  ('Жуків Затон', 'вулиця', 'Голосіївський', 2017),
#  ('Жуковського Василя', 'провулок', 'Голосіївський', 2000),
#  ('Жуковського Василя', 'провулок', 'Голосіївський', 2004),
#  ('Жуковського Василя', 'вулиця', 'Голосіївський', 2000),
#  ('Жуковського Василя', 'вулиця', 'Голосіївський', 2004),
#  ('Жулянська', 'вулиця', 'Голосіївський', 2012),
#  ('Журавлина', 'вулиця', 'Дарницький', 0),
#  ('Журавлина', 'вулиця', 'Дарницький', 2019),
#  ('Журавлина', 'вулиця', "Солом'янський", 0),
#  ('Журавлина', 'вулиця', "Солом'янський", 2019),
#  ('Забайківська', 'вулиця', 'Голосіївський', 2017),
#  ('Забіли Віктора', 'вулиця', 'Голосіївський', 2001),
#  ('Заболотний', 'провулок', 'Голосіївський', 1948),
#  ('Заболотного Академіка', 'вулиця', 'Голосіївський', 0),
#  ('Завальна', 'вулиця', 'Дарницький', 2013),
#  ('Заводська', 'вулиця', 'Подільський', 2018),
#  ('Заводський', 'провулок', 'Дарницький', 2018),
#  ('Заглади Леоніли', 'вулиця', 'Дарницький', 2017),
#  ('Загороднього Михайла', 'площа', 'Оболонський', 2010),
#  ('Загородня', 'вулиця', 'Голосіївський', 0),
#  ('Задніпровського Михайла', 'вулиця', 'Печерський', 0),
#  ('Задорожний', 'провулок', 'Голосіївський', 1987),
#  ('Заканальна', 'вулиця', 'Дарницький', 2018),
#  ('Закарпатська', 'вулиця', 'Голосіївський', 1973),
#  ('Закревського Миколи', 'вулиця', 'Деснянський', 1969),
#  ('Заливна', 'вулиця', 'Голосіївський', 2015),
#  ('Залізнична', 'вулиця', "Солом'янський", 2014),
#  ('Залізнична', 'вулиця', "Солом'янський", 2016),
#  ('Залізнична', 'вулиця', 'Дніпровський', 2014),
#  ('Залізнична', 'вулиця', 'Дніпровський', 2016),
#  ('Залізнична 1', 'вулиця', 'Дніпровський', 0),
#  ('Залізнична 2', 'вулиця', 'Дніпровський', 1965),
#  ('Залізнична 3', 'вулиця', 'Дніпровський', 2016),
#  ('Залізнична 4', 'вулиця', 'Дніпровський', 2004),
#  ('Залізничне', 'шосе', 'Печерський', 0),
#  ('Залізняка Максима', 'вулиця', 'Святошинський', 2011),
#  ('Залісна', 'вулиця', "Солом'янський", 0),
#  ('Заломова Петра', 'вулиця', "Солом'янський", 0),
#  ('Залужна ', 'вулиця', 'Голосіївський', None),
#  ('Залужний ', 'провулок', 'Голосіївський', None),
#  ('Заміський', 'провулок', 'Дарницький', 0),
#  ('Замковецька', 'вулиця', 'Подільський', 2008),
#  ('Замковецький', 'провулок', 'Подільський', 0),
#  ('Заньковецької', 'вулиця', 'Печерський', 2018),
#  ('Заозерний', 'провулок', 'Деснянський', 2016),
#  ('Западинська', 'вулиця', 'Подільський', 0),
#  ('Запашний', 'провулок', 'Дарницький', 2006),
#  ('Запечерний', 'провулок', 'Печерський', 0),
#  ('Заплавна', 'вулиця', 'Дарницький', 2019),
#  ('Заплавний', 'провулок', 'Дарницький', 0),
#  ('Заповітна', 'вулиця', "Солом'янський", 1963),
#  ('Заповітний', 'провулок', "Солом'янський", 2014),
#  ('Запорізька', 'вулиця', "Солом'янський", 2017),
#  ('Запорожця Петра', 'вулиця', 'Дніпровський', 0),
#  ('Запорожця Петра', 'вулиця', 'Дніпровський', 1911),
#  ('Запорожця Петра', 'вулиця', 'Деснянський', 0),
#  ('Запорожця Петра', 'вулиця', 'Деснянський', 1911),
#  ('Заремби Владислава', 'провулок', 'Голосіївський', 0),
#  ('Зарічна', 'вулиця', 'Дарницький', 1969),
#  ('Зарубинецька', 'вулиця', 'Подільський', 0),
#  ('Заслонова Костянтина', 'вулиця', 'Дарницький', 1967),
#  ('Затєвахіна Полковника', 'вулиця', 'Голосіївський', 2019),
#  ('Затишна', 'вулиця', 'Дарницький', 2019),
#  ('Захарівська', 'вулиця', 'Подільський', 1965),
#  ('Захисників', 'провулок', 'Деснянський', 2020),
#  ('Західна', 'вулиця', "Солом'янський", 2012),
#  ('Західний', 'провулок', "Солом'янський", 0),
#  ('Звенигородська', 'вулиця', 'Святошинський', 1963),
#  ('Звіринецька', 'вулиця', 'Печерський', 1995),
#  ('Звіринецький', 'провулок', 'Печерський', 0),
#  ("Зв'язківців", 'вулиця', 'Святошинський', 0),
#  ('Згурівська', 'вулиця', "Солом'янський", 1959),
#  ('Здолбунівська', 'вулиця', 'Дарницький', 2014),
#  ('Зелена', 'вулиця', "Солом'янський", 0),
#  ('Зелена', 'вулиця', "Солом'янський", 2013),
#  ('Зелена', 'вулиця', "Солом'янський", 2014),
#  ('Зелена', 'вулиця', 'Дніпровський', 0),
#  ('Зелена', 'вулиця', 'Дніпровський', 2013),
#  ('Зелена', 'вулиця', 'Дніпровський', 2014),
#  ('Зелена', 'вулиця', 'Шевченківський', 0),
#  ('Зелена', 'вулиця', 'Шевченківський', 2013),
#  ('Зелена', 'вулиця', 'Шевченківський', 2014),
#  ('Зеленогірська', 'вулиця', "Солом'янський", 2017),
#  ('Зелінського Академіка', 'провулок', 'Подільський', 1917),
#  ('Землянична', 'вулиця', 'Подільський', 2019),
#  ('Землянська', 'вулиця', 'Печерський', 0),
#  ('Землянський', 'провулок', 'Печерський', 0),
#  ('Зенітна', 'вулиця', "Солом'янський", 2008),
#  ('Зимова', 'вулиця', 'Подільський', 0),
#  ('Златопільська', 'вулиця', "Солом'янський", 1962),
#  ("Знам'янська", 'вулиця', "Солом'янський", 2014),
#  ('Зовнішня', 'вулиця', 'Дарницький', 2018),
#  ('Зодчих', 'вулиця', 'Святошинський', 0),
#  ('Золота', 'вулиця', 'Дніпровський', 0),
#  ('Золоті Джерела', 'вулиця', 'Голосіївський', 0),
#  ('Золотоворітська', 'вулиця', 'Шевченківський', 1977),
#  ('Золотоворітський', 'проїзд', 'Шевченківський', 2006),
#  ('Золотоніська', 'вулиця', 'Голосіївський', 0),
#  ('Золотоустівська', 'вулиця', 'Шевченківський', 2017),
#  ('Золочевська', 'вулиця', 'Подільський', 1972),
#  ('Золочевський', 'провулок', 'Подільський', 2018),
#  ('Зоологічна', 'вулиця', 'Шевченківський', 0),
#  ('Зоотехніків', 'вулиця', 'Дарницький', 1977),
#  ('Зорге Ріхарда', 'вулиця', 'Святошинський', 0),
#  ('Зоряна', 'вулиця', 'Подільський', 0),
#  ('Зоряна', 'вулиця', 'Подільський', 0),
#  ('Зоряна', 'вулиця', "Солом'янський", 0),
#  ('Зоряна', 'вулиця', "Солом'янський", 0),
#  ('Зоряний', 'провулок', 'Подільський', 0),
#  ('Зрошувальна', 'вулиця', 'Дарницький', 2016),
#  ('Івана Білика', 'вулиця', "Солом'янський", 1987),
#  ('Івана Виговського', 'вулиця', 'Подільський', 2020),
#  ('Івана Рогача', 'вулиця', 'Деснянський', 0),
#  ('Івашкевича Ярослава', 'вулиця', 'Оболонський', 2007),
#  ('Івченка Михайла', 'провулок', 'Святошинський', 1993),
#  ('Ігорівська', 'вулиця', 'Подільський', 0),
#  ('Ігоря Диченка', 'вулиця', 'Голосіївський', 0),
#  ('Їжакевича Івана', 'вулиця', 'Подільський', 2011),
#  ('Іжевська', 'вулиця', 'Дарницький', 2006),
#  ('Іжевський', 'провулок', 'Дарницький', 0),
#  ('Ізюмська', 'вулиця', 'Голосіївський', 2001),
#  ('Ізяславський', 'провулок', "Солом'янський", 1994),
#  ('Іллінська', 'вулиця', 'Подільський', 0),
#  ('Інгульський', 'провулок', 'Голосіївський', 1959),
#  ('Індустріальний', 'провулок', "Солом'янський", 0),
#  ('Інженера Бородіна', 'вулиця', 'Дніпровський', 1986),
#  ('Інженерна', 'вулиця', 'Голосіївський', 0),
#  ('Інженерна', 'вулиця', 'Голосіївський', 0),
#  ('Інженерна', 'вулиця', 'Дарницький', 0),
#  ('Інженерна', 'вулиця', 'Дарницький', 0),
#  ('Інженерний', 'провулок', 'Печерський', 0),
#  ('Інженерний', 'провулок', 'Печерський', 1997),
#  ('Інженерний', 'провулок', 'Дарницький', 0),
#  ('Інженерний', 'провулок', 'Дарницький', 1997),
#  ('Інститутська', 'вулиця', 'Печерський', 2012),
#  ('Іоанна Павла ІІ', 'вулиця', 'Печерський', 2016),
#  ('Іпсилантіївський', 'провулок', 'Печерський', 2001),
#  ('Ірининська', 'вулиця', 'Шевченківський', 0),
#  ('Ірпінська', 'вулиця', 'Святошинський', 0),
#  ('Іртишська', 'вулиця', 'Голосіївський', 1917),
#  ('Ірчана Мирослава', 'вулиця', 'Святошинський', 2017),
#  ('Ісаакяна', 'вулиця', 'Шевченківський', 1990),
#  ('Іси Мунаєва', 'вулиця', 'Деснянський', 2007),
#  ('Іскрівська', 'вулиця', "Солом'янський", 1977),
#  ('Йова Борецького', 'провулок', 'Печерський', 0),
#  ('Йорданська', 'вулиця', 'Оболонський', 2021),
#  ('Кабельна ', 'вулиця', 'Оболонський', None),
#  ('Каблукова Академіка', 'вулиця', "Солом'янський", 1997),
#  ('Кавалерідзе Івана', 'вулиця', 'Подільський', 2013),
#  ('Кавказька', 'вулиця', "Солом'янський", 0),
#  ('Кадетський Гай ', 'вулиця', "Солом'янський", None),
#  ('Кадіївська', 'вулиця', 'Деснянський', None),
#  ('Кадіївський', 'провулок', 'Деснянський', None),
#  ('Казанська', 'вулиця', 'Оболонський', None),
#  ('Кайсарова', 'вулиця', "Голосіївський,Солом'янський", None),
#  ('Калачівська', 'вулиця', 'Дніпровський', None),
#  ('Калинова', 'вулиця', 'Шевченківський', None),
#  ('Калиновий Ріг', 'проїзд', 'Оболонський', None),
#  ('Калиновий Ріг', 'вулиця', 'Оболонський', None),
#  ('Калнишевського Петра', 'вулиця', 'Оболонський', None),
#  ('Кальвільна', 'вулиця', 'Подільський', None),
#  ('Каменярів', 'вулиця', "Солом'янський", None),
#  ('Каменярів', 'провулок', "Солом'янський", None),
#  ('Камишинська', 'вулиця', 'Голосіївський', None),
#  ("Кам'янець-Подільська", 'вулиця', 'Святошинський', None),
#  ("Кам'янець-Подільський", 'провулок', 'Святошинський', None),
#  ("Кам'янська", 'вулиця', 'Дарницький', None),
#  ('Канальна', 'вулиця', 'Дарницький', None),
#  ('Канальна 1', 'вулиця', 'Дніпровський', None),
#  ('Канальна 10', 'вулиця', 'Дніпровський', None),
#  ('Канальна 11', 'вулиця', 'Дніпровський', None),
#  ('Канальна 12', 'вулиця', 'Дніпровський', None),
#  ('Канальна 2', 'вулиця', 'Дніпровський', None),
#  ('Канальна 3', 'вулиця', 'Дніпровський', None),
#  ('Канальна 4', 'вулиця', 'Дніпровський', None),
#  ('Канальна 5', 'вулиця', 'Дніпровський', None),
#  ('Канальна 6', 'вулиця', 'Дніпровський', None),
#  ('Канальна 7', 'вулиця', 'Дніпровський', None),
#  ('Канальна 8', 'вулиця', 'Дніпровський', None),
#  ('Канальна 9', 'вулиця', 'Дніпровський', None),
#  ('Канівська', 'вулиця', 'Подільський', None),
#  ('Кантемирівський', 'провулок', 'Деснянський', None),
#  ('Караваєва Професора', 'вулиця', "Солом'янський", None),
#  ('Карбишева Генерала', 'вулиця', 'Дніпровський', None),
#  ('Карелівська', 'вулиця', 'Подільський', None),
#  ('Карельський', 'провулок', 'Деснянський, Дніпровський', None),
#  ("Кар'єрна", 'вулиця', "Солом'янський", None),
#  ('Кармелюка Устима', 'вулиця', 'Дніпровський', None),
#  ('Кармелюка Устима', 'провулок', 'Дніпровський', None),
#  ('Карпатська', 'вулиця', "Солом'янський", None),
#  ('Карпінського Академіка', 'вулиця', "Солом'янський", None),
#  ('Касіяна Василя', 'вулиця', 'Голосіївський', None),
#  ('Каунаська', 'вулиця', 'Дніпровський', None),
#  ('Кахи Бендукідзе', 'вулиця', 'Печерський', None),
#  ('Каховська', 'вулиця', 'Дніпровський', None),
#  ('Качалова', 'вулиця', "Солом'янський, Святошинський", None),
#  ('Качури Якова', 'провулок', 'Святошинський', None),
#  ('Качури Якова', 'вулиця', 'Святошинський', None),
#  ('Качуровського Ігоря', 'провулок', 'Дарницький', None),
#  ('Каштанова', 'вулиця', 'Деснянський', None),
#  ('Кащенка Академіка', 'вулиця', 'Голосіївський', None),
#  ('Квітки Цісик', 'вулиця', 'Оболонський', None),
#  ("Квітки-Основ'яненка", 'вулиця', 'Голосіївський', None),
#  ("Квітки-Основ'яненка", 'провулок', 'Голосіївський', None),
#  ('Квіткова', 'вулиця', 'Оболонський', None),
#  ('Квіткова', 'вулиця', 'Дніпровський', None),
#  ('Квіткові Луки', 'вулиця', 'Голосіївський', None),
#  ('Квітнева', 'вулиця', 'Голосіївський', None),
#  ('Квітнева', 'вулиця', 'Дарницький', None),
#  ('Квітневий', 'провулок', 'Подільський', None),
#  ('Квітникарська', 'вулиця', 'Подільський', None),
#  ('Квітуча', 'вулиця', 'Голосіївський', None),
#  ('Квітучий', 'провулок', 'Шевченківський', None),
#  ('Кемеровська', 'вулиця', 'Оболонський', None),
#  ...]

# %%
# створити запит для наповнення таблиці `result` результатом запиту на об'єднання
stmt_insert = cur.execute("INSERT INTO result " + stmt_join)

# %%
# виконати запит на заповнення
cur.execute("INSERT INTO result " + stmt_join)

# %%
# сберегти вміст створеної таблиці у вигляді списка
result_list = cur.execute("SELECT * FROM result").fetchall()

_ = [print(x) for x in result_list]
# Out:
# ('9-го Травня', 'вулиця', 'Святошинський', '2015')
# ('Абрикосова', 'вулиця', 'Оболонський', '0')
# ('Абрикосова', 'вулиця', 'Оболонський', '1902')
# ('Абрикосова', 'вулиця', 'Оболонський', '2011')
# ('Абрикосова', 'вулиця', 'Дарницький', '0')
# ('Абрикосова', 'вулиця', 'Дарницький', '1902')
# ('Абрикосова', 'вулиця', 'Дарницький', '2011')
# ('Абрикосова', 'вулиця', 'Подільський', '0')
# ('Абрикосова', 'вулиця', 'Подільський', '1902')
# ('Абрикосова', 'вулиця', 'Подільський', '2011')
# ('Августина Волошина', 'вулиця', 'Солом’янський', '2014')
# ('Авдєєнка Генерала', 'вулиця', 'Святошинський', '2009')
# ('Автозаводська', 'вулиця', 'Оболонський', '2018')
# ('Автозаводський ', 'провулок', 'Оболонський', None)
# ('Автопаркова', 'вулиця', 'Дарницький', '2017')
# ('Авторемонтна', 'вулиця', "Солом'янський", '1980')
# ('Автотранспортна', 'вулиця', 'Дарницький', '2012')
# ('Агітаторська', 'вулиця', "Солом'янський", '0')
# ('Агрегатна', 'вулиця', 'Оболонський', '2018')
# ('Аеродромна', 'вулиця', "Солом'янський", '1985')
# ('Азербайджанська', 'вулиця', 'Дніпровський', '2017')
# ('Азовська', 'вулиця', "Солом'янський", '1981')
# ('Айвазовського', 'провулок', 'Шевченківський', '2016')
# ('Академіка Єфремова', 'вулиця', 'Святошинський', '0')
# ('Академіка Оппокова', 'вулиця', 'Оболонський', '1987')
# ('Академіка Ромоданова', 'вулиця', 'Шевченківський', '0')
# ('Академіка Тронька', 'вулиця', 'Голосіївський', '2016')
# ('Акацієвий', 'провулок', 'Дарницький', '1976')
# ('Алексухіна Василя', 'вулиця', 'Святошинський', '1960')
# ('Алли Горської', 'провулок', 'Шевченківський', '1966')
# ('Алматинська', 'вулиця', 'Дніпровський', '1964')
# ("Аляб'єва", 'вулиця', 'Оболонський', '2008')
# ('Аманда Струве', 'вулиця', 'Оболонський', '0')
# ('Аміни Окуєвої ', 'вулиця', 'Шевченківський', None)
# ('Амосова Миколи', 'вулиця', "Солом'янський", '2007')
# ('Амурська', 'вулиця', 'Голосіївський', '0')
# ('Амурська', 'вулиця', 'Голосіївський', '1916')
# ('Амурська', 'площа', 'Голосіївський', '0')
# ('Амурська', 'площа', 'Голосіївський', '1916')
# ('Ананасна', 'вулиця', 'Подільський', '0')
# ('Анатоліївська', 'вулиця', 'Деснянський', '2013')
# ('Анатолія Кентія', 'вулиця', 'Голосіївський', '2019')
# ('Анатолія Лупиноса', 'вулиця', 'Солом’янський', '0')
# ("Анатолія Солов'яненка", 'вулиця', 'Дніпровський', '2009')
# ('Андріївська', 'вулиця', 'Подільський', '2017')
# ('Андріївський ', 'узвіз', 'Подільський', None)
# ('Андрія Аболмасова ', 'вулиця', 'Дніпровський', None)
# ('Андрія Кизила', 'вулиця', 'Дарницький', '2016')
# ('Андрія Меленського', 'вулиця', 'Голосіївський', '1986')
# ('Андрія Ніковського', 'вулиця', 'Голосіївський', '2019')
# ('Андрія Первозванного', 'площа', 'Печерський', '1977')
# ('Андрющенка Григорія', 'вулиця', 'Шевченківський', '0')
# ('Анкари', 'площа', 'Деснянський', '2018')
# ('Анни Ярославни', 'вулиця', 'Святошинський', '1983')
# ('Антіна Ждановича', 'вулиця', "Солом'янський", '0')
# ('Антона Цедіка', 'вулиця', 'Шевченківський', '1963')
# ('Антоненка-Давидовича Бориса', 'вулиця', 'Дарницький', '2014')
# ('Антоні Новосельського', 'вулиця', 'Святошинський', '1906')
# ('Антонова Авіаконструктора', 'вулиця', "Солом'янський", '1962')
# ('Антоновича', 'вулиця', 'Голосіївський, Печерський', '0')
# ("Ареф'єва Костянтина", 'вулиця', 'Дарницький', '2017')
# ('Аркасівська', 'вулиця', 'Оболонський', '2009')
# ('Армійська ', 'вулиця', 'Голосіївський', None)
# ('Арсенальна ', 'площа', 'Печерський', None)
# ('Арсенальна ', 'вулиця', 'Печерський', None)
# ('Арсенальний', 'провулок', 'Печерський', '2010')
# ('Артезіанський', 'провулок', 'Подільський', '1969')
# ('Артемія Веделя', 'вулиця', 'Голосіївський', '0')
# ('Артилерійський', 'провулок', 'Шевченківський', '1983')
# ('Архипа Люльки', 'вулиця', 'Солом’янський', '1892')
# ('Архипенка Олександра', 'вулиця', 'Оболонський', '0')
# ('Архітектора Дяченка', 'вулиця', 'Голосіївський', '2006')
# ('Архітектора Кобелєва', 'вулиця', "Солом'янський", '2017')
# ('Архітекторська', 'вулиця', "Солом'янський", '0')
# ('Аскольдів', 'провулок', 'Печерський', '0')
# ('Астраханська', 'вулиця', 'Дніпровський', '0')
# ('Астраханський', 'провулок', 'Дніпровський', '2008')
# ('Астрономічна', 'вулиця', 'Святошинський', '2010')
# ('Атени Пашко', 'вулиця', 'Голосіївський', '1990')
# ('Аттили Могильного', 'вулиця', 'Солом’янський', '2018')
# ('Ахматової Анни', 'вулиця', 'Дарницький', '2014')
# ('Бабушкіна', 'провулок', 'Шевченківський', '1906')
# ('Багговутівська', 'вулиця', 'Шевченківський', '1962')
# ('Багратіона', 'вулиця', "Солом'янський", '0')
# ('Багряна Дуброва', 'вулиця', 'Голосіївський', '2017')
# ('Багряного Івана', 'вулиця', 'Дніпровський', '2009')
# ('Бажана Миколи', 'проспект', 'Дарницький', '2002')
# ('Бажова', 'вулиця', 'Дніпровський', '1990')
# ('Байкальська', 'вулиця', 'Голосіївський', '1971')
# ('Байкова', 'вулиця', 'Голосіївський', '2010')
# ('Бакинська', 'вулиця', 'Шевченківський', '1969')
# ('Бакинський', 'провулок', 'Шевченківський', '0')
# ('Баклажанна', 'вулиця', 'Подільський', '1983')
# ('Бакуніна', 'вулиця', "Солом'янський", '1892')
# ('Балакірева', 'вулиця', 'Голосіївський', '0')
# ('Балаклієвська', 'вулиця', 'Шевченківський', '2006')
# ('Балтійський', 'провулок', 'Оболонський', '2017')
# ('Бальзака Оноре де', 'вулиця', 'Деснянський', '0')
# ('Банкова', 'вулиця', 'Печерський', '0')
# ('Баренбойма', 'вулиця', 'Голосіївський', '0')
# ('Барикадна', 'вулиця', 'Голосіївський', '2008')
# ('Баришівська', 'вулиця', 'Печерський', '2010')
# ('Басейна', 'вулиця', 'Печерський, Шевченківський', '1990')
# ('Бастіонна', 'вулиця', 'Печерський', '2018')
# ('Бастіонний', 'провулок', 'Печерський', '1994')
# ('Батумська', 'вулиця', 'Голосіївський', '2016')
# ('Батуринська', 'вулиця', 'Дарницький', '2014')
# ('Батуринський  ', 'провулок', 'Дарницький', None)
# ('Баха Академіка ', 'вулиця', 'Дніпровський', None)
# ('Бахмацька', 'вулиця', 'Святошинський', '1962')
# ('Бджолиний', 'провулок', 'Дарницький', '2017')
# ('Безручка Марка', 'вулиця', 'Шевченківський', '2013')
# ('Бердичівська', 'вулиця', 'Шевченківський', '0')
# ('Бердянська', 'вулиця', 'Шевченківський', '1969')
# ('Бердянський', 'провулок', 'Шевченківський', '0')
# ('Берегова', 'вулиця', 'Деснянський', '2020')
# ('Бережанська', 'вулиця', 'Оболонський', '0')
# ('Березнева', 'вулиця', 'Дніпровський', '2004')
# ('Березнева', 'вулиця', 'Дніпровський', '2008')
# ('Березнева', 'вулиця', 'Дарницький', '2004')
# ('Березнева', 'вулиця', 'Дарницький', '2008')
# ('Березневий', 'провулок', 'Дарницький', '2018')
# ('Березневий 3', 'провулок', 'Дарницький', '2013')
# ('Березняківська', 'вулиця', 'Дніпровський', '0')
# ('Березова', 'вулиця', "Солом'янський", '2017')
# ('Берестецька', 'вулиця', 'Оболонський', '2020')
# ('Беретті Вікентія', 'вулиця', 'Деснянський', '2011')
# ('Берізоньки (Озерна 14)', 'вулиця', 'Дарницький', '0')
# ('Берковецька', 'вулиця', 'Святошинський', '2018')
# ('Берлінського Максима', 'вулиця', 'Шевченківський', '2019')
# ('Бессарабська', 'площа', 'Шевченківський', '2019')
# ('Бестужева Олександра', 'провулок', 'Подільський', '1957')
# ('Бестужева Олександра', 'провулок', 'Подільський', '2001')
# ('Бестужева Олександра', 'вулиця', 'Подільський', '1957')
# ('Бестужева Олександра', 'вулиця', 'Подільський', '2001')
# ('Бетховена', 'вулиця', 'Святошинський', '2017')
# ('Бехтерівський', 'провулок', 'Шевченківський', '2018')
# ('Биківнянська', 'вулиця', 'Деснянський', '2013')
# ('Биківнянський', 'провулок', 'Деснянський', '2007')
# ('Биківський', 'провулок', 'Подільський', '0')
# ('Бикова Леоніда', 'бульвар', 'Деснянський', '2020')
# ('Бишівський', 'провулок', 'Дніпровський', '0')
# ('Бігова ', 'вулиця', 'Деснянський', None)
# ('Білаша Олександра', 'вулиця', 'Деснянський', '2015')
# ('Білгородська', 'вулиця', "Солом'янський", '0')
# ('Білецького Академіка', 'вулиця', "Солом'янський", '1963')
# ('Білицька', 'вулиця', 'Подільський', '2019')
# ('Білицький', 'провулок', 'Подільський', '2013')
# ('Біличанська', 'вулиця', 'Святошинський', '0')
# ('Білогородська', 'вулиця', 'Святошинський', '2018')
# ('Білокур Катерини', 'вулиця', 'Печерський', '1981')
# ('Біломорська', 'вулиця', 'Деснянський', '0')
# ('Білоруська', 'вулиця', 'Шевченківський', '2015')
# ('Біляшівського Академіка', 'вулиця', 'Святошинський', '2005')
# ('Бірюзова Маршала', 'вулиця', 'Святошинський', '2003')
# ('Блакитного', 'вулиця', 'Голосіївський', '0')
# ('Блока Олександра', 'вулиця', 'Святошинський', '2019')
# ('Бобринецька', 'вулиця', 'Деснянський', '1971')
# ('Бобринецький', 'провулок', 'Деснянський', '0')
# ('Бобруйський', 'провулок', 'Подільський', '1980')
# ('Богатирська', 'вулиця', 'Оболонський', '1959')
# ('Богатирський', 'проїзд', 'Оболонський', '2014')
# ('Богдана Гаврилишина', 'вулиця', 'Шевченківський', '0')
# ('Богданівська', 'вулиця', "Солом'янський", '0')
# ('Богданівський', 'провулок', "Солом'янський", '1980')
# ('Богомольця Академіка', 'вулиця', 'Печерський', '2019')
# ('Богуна Івана', 'вулиця', 'Дарницький', '1993')
# ('Богунська', 'вулиця', 'Голосіївський', '2003')
# ('Богунський', 'провулок', 'Голосіївський', '2017')
# ('Богуславський', 'узвіз', 'Подільський', '1996')
# ('Богушевський', 'провулок', 'Деснянський', '0')
# ('Божків Яр', 'вулиця', "Солом'янський", '0')
# ('Бойка Івана', 'вулиця', 'Дарницький', '1914')
# ('Бойова', 'вулиця', 'Голосіївський', '2005')
# ('Бойчука Михайла', 'вулиця', 'Печерський', '0')
# ('Болбочана Петра', 'вулиця', 'Печерський', '0')
# ('Болсуновська', 'вулиця', 'Печерський', '0')
# ('Бондарська', 'вулиця', 'Подільський', '0')
# ('Бондарський', 'провулок', 'Подільський', '1999')
# ('Бориса Матюшенка', 'вулиця', 'Голосіївський', '2007')
# ('Бориса Мозолевського', 'вулиця', 'Голосіївський', '2009')
# ('Бориса Тена', 'вулиця', 'Голосіївський', '2014')
# ('Бориса Шахліна', 'провулок', 'Голосіївський', '2005')
# ('Бориславська', 'вулиця', "Солом'янський", '2017')
# ('Борисоглібська', 'вулиця', 'Подільський', '2007')
# ('Бориспільська', 'вулиця', 'Дарницький', '0')
# ('Бориспільське', 'шосе', 'Дарницький', '0')
# ('Боричів ', 'узвіз', 'Подільський', None)
# ('Боричів Тік', 'вулиця', 'Подільський', '0')
# ('Борова', 'вулиця', 'Дарницький', '1977')
# ('Борова', 'вулиця', 'Дарницький', '2014')
# ('Борова', 'вулиця', 'Дарницький', '1977')
# ('Борова', 'вулиця', 'Дарницький', '2014')
# ('Боровий', 'провулок', 'Дарницький', '1974')
# ('Боровий', 'провулок', 'Дарницький', '2005')
# ('Боровий', 'провулок', 'Дарницький (Бортничі)', '1974')
# ('Боровий', 'провулок', 'Дарницький (Бортничі)', '2005')
# ('Боровиковського', 'вулиця', 'Оболонський', '1958')
# ('Боровинська', 'вулиця', 'Подільський', '0')
# ('Боровиченко Марії', 'вулиця', 'Голосіївський', '2017')
# ('Бородянський ', 'провулок', 'Святошинський', None)
# ('Бортницька', 'вулиця', 'Дарницький', '2005')
# ('Бортницька', 'вулиця', 'Дарницький', '2012')
# ('Бортницька', 'вулиця', 'Дарницький', '2005')
# ('Бортницька', 'вулиця', 'Дарницький', '2012')
# ('Бортницький', 'провулок', 'Дарницький', '1964')
# ('Бортницький 1', 'провулок', 'Дарницький', '2015')
# ('Бортницький 2', 'провулок', 'Дарницький', '2017')
# ('Борщагівська', 'вулиця', "Солом'янський, Шевченківський ", '0')
# ('Ботанічна', 'площа', 'Шевченківський', '2011')
# ('Боткіна', 'вулиця', "Солом'янський", '1964')
# ('Брановицького Ігоря', 'вулиця', 'Печерський', '2016')
# ('Братиславська', 'вулиця', 'Деснянський, Дніпровський', '0')
# ('Братів Зерових', 'вулиця', "Солом'янський", '2021')
# ('Братів Шеметів', 'вулиця', 'Голосіївський', '1946')
# ('Братська', 'вулиця', 'Подільський', '2017')
# ('Брацлавська', 'вулиця', 'Дарницький', '1977')
# ('Брест-Литовський', 'провулок', 'Шевченківський', '2018')
# ('Брестська', 'вулиця', 'Подільський', '0')
# ('Броварський', 'провулок', 'Деснянський', '2013')
# ('Броварський', 'провулок', 'Деснянський', '2015')
# ('Броварський', 'проспект', 'Деснянський, Дніпровський', '2013')
# ('Броварський', 'проспект', 'Деснянський, Дніпровський', '2015')
# ('Бродівська', 'вулиця', 'Голосіївський', '2001')
# ('Бродівський', 'провулок', 'Голосіївський', '0')
# ('Брусилівська', 'вулиця', 'Святошинський', '2015')
# ('Брюлова', 'вулиця', "Солом'янський", '0')
# ('Брюсова', 'вулиця', 'Подільський', '2003')
# ('Брянська', 'вулиця', "Солом'янський", '1963')
# ('Бугорна ', 'вулиця', 'Шевченківський', None)
# ('Бугорний', 'провулок', 'Шевченківський', '1895')
# ('Бударіна', 'вулиця', 'Святошинський', '0')
# ('Будищанська', 'вулиця', 'Деснянський', '0')
# ('Будівельників', 'провулок', 'Дніпровський', '0')
# ('Будівельників', 'провулок', 'Дніпровський', '0')
# ('Будівельників', 'провулок', 'Дніпровський', '1970')
# ('Будівельників', 'провулок', 'Дніпровський', '2001')
# ('Будівельників', 'вулиця', 'Дніпровський', '0')
# ('Будівельників', 'вулиця', 'Дніпровський', '0')
# ('Будівельників', 'вулиця', 'Дніпровський', '1970')
# ('Будівельників', 'вулиця', 'Дніпровський', '2001')
# ('Будівельників', 'вулиця', 'Деснянський', '0')
# ('Будівельників', 'вулиця', 'Деснянський', '0')
# ('Будівельників', 'вулиця', 'Деснянський', '1970')
# ('Будівельників', 'вулиця', 'Деснянський', '2001')
# ('Будівельників', 'провулок', 'Святошинський', '0')
# ('Будівельників', 'провулок', 'Святошинський', '0')
# ('Будівельників', 'провулок', 'Святошинський', '1970')
# ('Будівельників', 'провулок', 'Святошинський', '2001')
# ('Будіндустрії', 'вулиця', 'Голосіївський', '1973')
# ('Бузинова', 'вулиця', 'Дарницький', '0')
# ('Буйка Професора', 'вулиця', 'Голосіївський', '2010')
# ('Букіної Раїси', 'вулиця', 'Святошинський', '0')
# ('Букіної Раїси', 'вулиця', 'Святошинський', '1979')
# ('Букіної Раїси', 'провулок', 'Святошинський', '0')
# ('Букіної Раїси', 'провулок', 'Святошинський', '1979')
# ('Буковинська', 'вулиця', 'Голосіївський', '2002')
# ('Буковинський', 'провулок', 'Голосіївський', '2018')
# ('Булаховського Академіка', 'вулиця', 'Святошинський', '2005')
# ('Булгакова', 'вулиця', 'Святошинський', '0')
# ('Бульварно-Кудрявська', 'вулиця', 'Шевченківський', '2019')
# ('Бурденка', 'провулок', 'Подільський', '1975')
# ('Бурмистенка', 'вулиця', 'Голосіївський', '2005')
# ('Бурмистенка', 'вулиця', 'Голосіївський', '2010')
# ('Бурмистенка', 'провулок', 'Голосіївський', '2005')
# ('Бурмистенка', 'провулок', 'Голосіївський', '2010')
# ('Буслівська', 'вулиця', 'Печерський', '2020')
# ('Бутишів', 'провулок', 'Печерський', '1986')
# ('Бутлерова Академіка', 'вулиця', 'Дніпровський', '0')
# ('Бучанська', 'вулиця', 'Святошинський', '2005')
# ('Бучми Амвросія', 'бульвар', 'Дніпровський', '2018')
# ('В’ячеслава Липинського', 'вулиця', 'Шевченківський', '2011')
# ('Вавілових', 'вулиця', 'Шевченківський', '2018')
# ('Вакуленчука', 'вулиця', 'Дарницький', '1971')
# ('Вакуленчука', 'вулиця', 'Дарницький', '2020')
# ('Вакуленчука', 'провулок', 'Дарницький', '1971')
# ('Вакуленчука', 'провулок', 'Дарницький', '2020')
# ('Валентина Отамановського', 'вулиця', 'Голосіївський', '1960')
# ('Валерія Марченка', 'площа', 'Подільський, Шевченківський', '2005')
# ("Валер'яна Підмогильного", 'вулиця', 'Голосіївський', '0')
# ('Валківська', 'вулиця', 'Подільський', '2006')
# ('Василенка Миколи', 'вулиця', "Солом'янський", '1969')
# ('Василівська', 'вулиця', "Солом'янський", '2015')
# ('Васильківська', 'вулиця', 'Голосіївський', '0')
# ('Васильківський', 'провулок', 'Голосіївський', '2006')
# ('Васильченка', 'вулиця', "Солом'янський", '2019')
# ('Василя Барки', 'вулиця', 'Солом’янський', '0')
# ('Василя Біднова', 'вулиця', 'Деснянський', '2007')
# ('Василя Вишиваного', 'вулиця', 'Дніпровський', '0')
# ('Василя Макуха', 'вулиця', 'Шевченківський', '1973')
# ('Василя Седляра', 'вулиця', "Солом'янський", '2012')
# ('Василя Тютюнника', 'вулиця', 'Печерський', '2017')
# ('Василя Щавинського', 'вулиця', 'Деснянський', '1997')
# ('Васнецова', 'вулиця', 'Дніпровський', '1936')
# ('Ватутіна', 'вулиця', "Солом'янський", '2005')
# ('Ватутінський', 'провулок', 'Деснянський', '1971')
# ('Ващенка Григорія', 'вулиця', 'Дарницький', '0')
# ('Введенська', 'вулиця', 'Подільський', '1883')
# ('Велика Васильківська', 'вулиця', 'Голосіївський, Шевченківський, Печерський', '2010')
# ('Велика Житомирська', 'вулиця', 'Шевченківський', '2016')
# ('Велика Китаївська', 'вулиця', 'Голосіївський', '2016')
# ('Велика Кільцева', 'дорога', 'Оболонський', '2001')
# ('Велика Окружна', 'вулиця', 'Святошинський', '0')
# ('Вербицького Архітектора', 'вулиця', 'Дарницький', '2015')
# ('Вербна', 'вулиця', 'Оболонський', '0')
# ('Вербний', 'провулок', 'Деснянський', '0')
# ('Вербова', 'вулиця', 'Оболонський', '0')
# ('Верболозна', 'вулиця', 'Подільський', '0')
# ('Верболозний', 'провулок', 'Подільський', '0')
# ('Вересая Остапа', 'вулиця', 'Деснянський', '2013')
# ('Вересковий', 'провулок', 'Дарницький', '0')
# ('Вереснева', 'вулиця', 'Дарницький', '0')
# ('Верещагіна', 'вулиця', 'Подільський', '0')
# ('Вернадського Академіка', 'бульвар', 'Святошинський', '1982')
# ('Верхній', 'провулок', 'Печерський', '0')
# ('Верхній Вал', 'вулиця', 'Подільський', '0')
# ('Верхньогірська', 'вулиця', 'Печерський', '1983')
# ('Верхньоключова', 'вулиця', "Солом'янський", '0')
# ('Верхня', 'вулиця', 'Печерський', '0')
# ('Верховинна', 'вулиця', 'Святошинський', '2013')
# ('Верховинця Василя', 'вулиця', 'Святошинський', '2014')
# ('Верховної Ради', 'бульвар', 'Дніпровський, Деснянський', '2013')
# ('Вершигори Петра', 'вулиця', 'Дніпровський', '2019')
# ('Веселковий', 'провулок', 'Подільський', '0')
# ('Весняна', 'вулиця', 'Голосіївський', '1905')
# ('Вешенський', 'провулок', 'Деснянський', '0')
# ('Виборзький', 'провулок', "Солом'янський", '2012')
# ('Вигурівський', 'бульвар', 'Деснянський', '1959')
# ('Видубицька', 'вулиця', 'Печерський', '2016')
# ('Визволителів', 'проспект', 'Дніпровський', '0')
# ('Винахідників', 'вулиця', 'Дніпровський', '0')
# ('Винахідників', 'вулиця', 'Дніпровський', '1973')
# ('Винахідників', 'провулок', 'Дніпровський', '0')
# ('Винахідників', 'провулок', 'Дніпровський', '1973')
# ('Виноградна', 'вулиця', "Солом'янський", '0')
# ('Виноградний', 'провулок', 'Печерський', '2009')
# ('Вирлицька', 'вулиця', 'Дарницький', '0')
# ('Високовольтний', 'провулок', 'Дарницький', '0')
# ('Висоцького Володимира', 'бульвар', 'Деснянський', '2003')
# ('Вифлеємська', 'вулиця', 'Дніпровський', '1971')
# ('Вишгородська', 'вулиця', 'Подільський, Оболонський', '0')
# ('Вишнева', 'вулиця', "Солом'янський", '0')
# ('Вишнева', 'вулиця', "Солом'янський", '1982')
# ('Вишнева', 'вулиця', "Солом'янський", '1983')
# ('Вишнева', 'вулиця', "Солом'янський", '2015')
# ('Вишнева', 'вулиця', 'Святошинський', '0')
# ('Вишнева', 'вулиця', 'Святошинський', '1982')
# ('Вишнева', 'вулиця', 'Святошинський', '1983')
# ('Вишнева', 'вулиця', 'Святошинський', '2015')
# ('Вишнева', 'вулиця', 'Оболонський', '0')
# ('Вишнева', 'вулиця', 'Оболонський', '1982')
# ('Вишнева', 'вулиця', 'Оболонський', '1983')
# ('Вишнева', 'вулиця', 'Оболонський', '2015')
# ('Вишнева', 'вулиця', 'Дарницький', '0')
# ('Вишнева', 'вулиця', 'Дарницький', '1982')
# ('Вишнева', 'вулиця', 'Дарницький', '1983')
# ('Вишнева', 'вулиця', 'Дарницький', '2015')
# ('Вишнева (Озерна 3)', 'вулиця', 'Дарницький', '0')
# ('Вишняківська', 'вулиця', 'Дарницький', '1961')
# ('Відпочинку', 'вулиця', 'Святошинський', '2019')
# ('Відрадний', 'проспект', "Солом'янський, Святошинський", '0')
# ('Військова', 'вулиця', 'Голосіївський', '0')
# ('Військовий', 'проїзд', 'Печерський', '2018')
# ('Віктора Зарецького', 'вулиця', 'Голосіївський', '2016')
# ('Вільде Едуарда', 'вулиця', 'Дніпровський', '2020')
# ('Вільнюська', 'вулиця', 'Дніпровський', '2018')
# ('Вільхова ', 'вулиця', 'Дніпровський', None)
# ('Вільшанська', 'вулиця', 'Печерський', '2006')
# ('Вільшанський ', 'провулок', 'Печерський', None)
# ('Вільямса Академіка', 'вулиця', 'Голосіївський', '0')
# ('Вінграновського Миколи', 'вулиця', 'Дарницький', '2015')
# ('Вінницька', 'вулиця', "Солом'янський", '2014')
# ('Вірменська', 'вулиця', 'Дарницький', '0')
# ('Вірменський', 'провулок', 'Дарницький', '2004')
# ('Вірності', 'вулиця', 'Деснянський', '0')
# ('Вірського Павла', 'вулиця', 'Деснянський', '2018')
# ('Вірьовки Григорія', 'вулиця', 'Деснянський', '2012')
# ('Віскозна', 'вулиця', 'Дніпровський, Деснянський', '2015')
# ('Вітавська', 'вулиця', 'Голосіївський', '2018')
# ('Віто-Литовський', 'провулок', 'Голосіївський', '1977')
# ('Вітрука Генерала', 'вулиця', 'Святошинський', '2012')
# ('Вітряні Гори', 'вулиця', 'Подільський', '2006')
# ('Вітчизняна', 'вулиця', 'Подільський', '2015')
# ('Вітянська', 'вулиця', 'Голосіївський', '1966')
# ('Владлена Кузнецова', 'вулиця', 'Деснянський', '2019')
# ('Водників', 'вулиця', 'Подільський', '2018')
# ('Водогінна', 'вулиця', 'Голосіївський', '0')
# ('Воздвиженська', 'вулиця', 'Подільський', '0')
# ('Воздвиженський', 'провулок', 'Подільський', '2014')
# ('Вознесенський', 'узвіз', 'Шевченківський', '0')
# ('Вокзальна', 'площа', "Солом'янський", '0')
# ('Вокзальна', 'площа', "Солом'янський", '2017')
# ('Вокзальна', 'вулиця', "Солом'янський, Шевченківський", '0')
# ('Вокзальна', 'вулиця', "Солом'янський, Шевченківський", '2017')
# ('Волгоградська', 'вулиця', "Солом'янський", '1879')
# ('Волгоградська', 'вулиця', "Солом'янський", '2018')
# ('Волгоградська', 'площа', 'Деснянський', '1879')
# ('Волгоградська', 'площа', 'Деснянський', '2018')
# ('Волго-Донська', 'вулиця', 'Дарницький', '1991')
# ('Волго-Донський', 'провулок', 'Дарницький', '0')
# ('Волзька', 'вулиця', 'Голосіївський', '0')
# ('Волзький', 'провулок', 'Голосіївський', '1961')
# ('Волинська', 'вулиця', "Солом'янський", '2017')
# ('Волкова Космонавта', 'вулиця', 'Деснянський', '0')
# ('Володарська', 'вулиця', 'Голосіївський', '1913')
# ('Володимира Беца', 'вулиця', 'Деснянський', '0')
# ('Володимира Брожка', 'вулиця', "Голосіївський, Солом'янський", '0')
# ('Володимира Винниченка', 'вулиця', 'Шевченківський', '1999')
# ('Володимира Горовиця', 'вулиця', 'Голосіївський', '1961')
# ('Володимира Науменко', 'вулиця', 'Голосіївський', '0')
# ('Володимиро-Либідська', 'вулиця', 'Голосіївський', '0')
# ('Володимирська', 'вулиця', 'Голосіївський, Шевченківський', '0')
# ('Володимирський', 'узвіз', 'Печерський, Подільський, Шевченківський', '0')
# ('Володимирський', 'узвіз', 'Печерський, Подільський, Шевченківський', '2013')
# ('Володимирський', 'проїзд', 'Шевченківський', '0')
# ('Володимирський', 'проїзд', 'Шевченківський', '2013')
# ('Волоська', 'вулиця', 'Подільський', '2013')
# ('Волошкова', 'вулиця', "Солом'янський", '0')
# ('Волошковий', 'провулок', 'Деснянський', '1993')
# ('Волховська', 'вулиця', 'Дніпровський', '0')
# ('Волховський', 'провулок', 'Дніпровський', '2016')
# ('Воскресенська', 'вулиця', 'Дніпровський', '2018')
# ('Восьмого Березня', 'вулиця', 'Оболонський', '0')
# ('Врубелівський', 'узвіз', 'Шевченківський', '2015')
# ('Всеволода Змієнка', 'вулиця', 'Подільський', '2019')
# ('Вузівська', 'вулиця', "Солом'янський", '0')
# ('Вуликова', 'вулиця', 'Дарницький', '0')
# ('Вчительська', 'вулиця', "Солом'янський", '2010')
# ('Гаванська', 'вулиця', 'Подільський', '2005')
# ('Гаванський', 'провулок', 'Оболонський', '2011')
# ('Гавела Вацлава', 'бульвар', "Солом'янський", '2007')
# ('Гаврилюка', 'вулиця', 'Солом’янський', '2009')
# ('Гагаріна Юрія', 'проспект', 'Деснянський, Дніпровський', '0')
# ('Газова', 'вулиця', 'Солом’янський', '2003')
# ('Газопровідна', 'вулиця', 'Подільський, Святошинський', '2014')
# ('Гайдай Зої', 'вулиця', 'Оболонський', '1999')
# ('Гайова', 'вулиця', 'Солом’янський', '2018')
# ('Гайсинська', 'вулиця', 'Солом’янський', '2020')
# ('Галерна', 'вулиця', 'Голосіївський', '2018')
# ('Галицька', 'вулиця', 'Подільський', '1972')
# ('Ганни Арендт', 'вулиця', "Солом'янський", '2018')
# ('Ганни Барвінок', 'вулиця', 'Оболонський', '2011')
# ('Гаражна', 'вулиця', 'Дніпровський', '0')
# ('Гаражна', 'вулиця', 'Дніпровський', '2019')
# ('Гаражна', 'вулиця', 'Дарницький', '0')
# ('Гаражна', 'вулиця', 'Дарницький', '2019')
# ('Гарета Джонса', 'провулок', 'Шевченківський', '2007')
# ('Гаріна Бориса', 'вулиця', 'Солом’янський', '0')
# ('Гарматна', 'вулиця', 'Солом’янський', '1978')
# ('Гаршина', 'вулиця', 'Святошинський', '1858')
# ('Гастелло Миколи', 'вулиця', 'Печерський', '1974')
# ('Гатна', 'вулиця', 'Голосіївський', '2017')
# ('Гашека Ярослава', 'бульвар', 'Дніпровський', '0')
# ('Гвардійська', 'вулиця', 'Голосіївський', '2008')
# ('Генерала Алмазова', 'вулиця', 'Печерський', '0')
# ('Генерала Гандзюка', 'вулиця', 'Оболонський', '0')
# ('Генерала Генадія Воробйова', 'вулиця', "Солом'янський", '2007')
# ('Генерала Грекова', 'вулиця', 'Подільський', '2014')
# ('Генерала Павленка', 'вулиця', "Солом'янський", '2016')
# ('Генерала Шаповала', 'вулиця', "Солом'янський", '1993')
# ('Георгіївський', 'провулок', 'Шевченківський', '1978')
# ('Геофізиків', 'вулиця', 'Дарницький', '0')
# ('Геофізиків', 'вулиця', 'Дарницький', '2016')
# ('Геофізиків', 'провулок', 'Дарницький', '0')
# ('Геофізиків', 'провулок', 'Дарницький', '2016')
# ('Герасименка Костянтина', 'вулиця', 'Святошинський', '1936')
# ('Героїв Бресту', 'площа', 'Святошинський', '0')
# ('Героїв Великої Вітчизняної війни', 'площа', 'Печерський', '2005')
# ('Героїв Війни', 'вулиця', 'Солом’янський', '1959')
# ('Героїв Дніпра', 'вулиця', 'Оболонський', '2001')
# ('Героїв Космосу', 'вулиця', 'Святошинський', '2015')
# ('Героїв Крут', 'алея', 'Печерський', '1988')
# ('Героїв Небесної Сотні', 'алея', 'Печерський', '1981')
# ('Героїв Оборони', 'вулиця', 'Голосіївський', '1936')
# ('Героїв Севастополя', 'вулиця', "Солом'янський", '2019')
# ('Героїв Сталінграда', 'проспект', 'Оболонський', '2005')
# ('Герцена', 'вулиця', 'Шевченківський', '0')
# ('Герцена', 'вулиця', 'Шевченківський', '1965')
# ('Герцена', 'вулиця', 'Шевченківський', '2018')
# ('Герцена', 'узвіз', 'Шевченківський', '0')
# ('Герцена', 'узвіз', 'Шевченківський', '1965')
# ('Герцена', 'узвіз', 'Шевченківський', '2018')
# ('Герцена', 'провулок', 'Шевченківський', '0')
# ('Герцена', 'провулок', 'Шевченківський', '1965')
# ('Герцена', 'провулок', 'Шевченківський', '2018')
# ('Гетьмана Вадима', 'вулиця', "Солом'янський", '0')
# ('Гійома де Боплана', 'вулиця', 'Деснянський', '2010')
# ('Гіллястий', 'провулок', 'Дніпровський', '2014')
# ('Гладківська', 'вулиця', "Солом'янський", '2016')
# ('Глазунова', 'вулиця', 'Печерський', '2002')
# ('Глибочицька', 'вулиця', 'Шевченківський', '0')
# ('Глибочицький', 'проїзд', 'Шевченківський', '0')
# ('Глібова', 'вулиця', 'Шевченківський', '1963')
# ('Глієра Рейнгольда', 'вулиця', 'Святошинський', '2005')
# ('Глінки', 'вулиця', 'Солом’янський', '2016')
# ('Глухівська', 'вулиця', 'Подільський', '2018')
# ('Глушкова Академіка', 'проспект', 'Голосіївський', '2015')
# ('Гмирі Бориса', 'вулиця', 'Дарницький', '1985')
# ('Говорова Маршала', 'вулиця', 'Голосіївський', '2007')
# ('Говорова Маршала', 'вулиця', 'Голосіївський', '2010')
# ('Говорова Маршала', 'провулок', 'Голосіївський', '2007')
# ('Говорова Маршала', 'провулок', 'Голосіївський', '2010')
# ('Гоголівська', 'вулиця', 'Шевченківський', '0')
# ('Гоголя', 'вулиця', 'Солом’янський', '0')
# ('Гоголя', 'вулиця', 'Солом’янський', '1970')
# ('Гоголя', 'вулиця', 'Солом’янський', '2014')
# ('Гоголя', 'вулиця', 'Дарницький', '0')
# ('Гоголя', 'вулиця', 'Дарницький', '1970')
# ('Гоголя', 'вулиця', 'Дарницький', '2014')
# ('Гоголя', 'вулиця', 'Деснянський', '0')
# ('Гоголя', 'вулиця', 'Деснянський', '1970')
# ('Гоголя', 'вулиця', 'Деснянський', '2014')
# ('Гоголя 2', 'провулок', 'Дарницький', '1975')
# ('Голованьова Степана', 'вулиця', 'Дарницький', '2014')
# ('Головка Андрія', 'вулиця', 'Солом’янський', '2012')
# ('Голосіївська', 'площа', 'Голосіївський', '0')
# ('Голосіївська', 'площа', 'Голосіївський', '2019')
# ('Голосіївська', 'вулиця', 'Голосіївський', '0')
# ('Голосіївська', 'вулиця', 'Голосіївський', '2019')
# ('Голосіївський', 'проспект', 'Голосіївський', '1974')
# ('Голосіївський', 'проспект', 'Голосіївський', '2019')
# ('Голосіївський', 'провулок', 'Голосіївський', '1974')
# ('Голосіївський', 'провулок', 'Голосіївський', '2019')
# ('Гомельська', 'вулиця', 'Подільський', '1975')
# ('Гомельський', 'провулок', 'Подільський', '2002')
# ('Гонгадзе Георгія', 'проспект', 'Подільський', '1998')
# ('Гонти Івана', 'вулиця', 'Шевченківський', '2016')
# ('Гончара Олеся', 'вулиця', 'Шевченківський', '2016')
# ('Гончарна', 'вулиця', 'Подільський', '2012')
# ('Гончарова', 'вулиця', 'Шевченківський', '0')
# ('Горбунова Академіка', 'вулиця', 'Дарницький', '2008')
# ('Горенська', 'вулиця', 'Святошинський', '2013')
# ('Гориста', 'вулиця', 'Голосіївський', '1969')
# ('Гористий', 'провулок', 'Голосіївський', '2020')
# ('Горіхова', 'вулиця', "Солом'янський", '1913')
# ('Горіхова (Озерна 5)', 'вулиця', 'Дарницький', '2017')
# ('Горлівська', 'вулиця', 'Дарницький', '2017')
# ('Городецького Архітектора', 'вулиця', 'Печерський', '2020')
# ('Городище', 'вулиця', 'Деснянський', '0')
# ('Городищенська', 'вулиця', 'Подільський', '1954')
# ('Городня', 'вулиця', 'Солом’янський', '0')
# ('Горюшка Георгія', 'вулиця', 'Голосіївський', '1936')
# ('Госпітальна', 'вулиця', 'Печерський', '2016')
# ('Госпітальний', 'провулок', 'Печерський', '2018')
# ('Гостинна', 'вулиця', 'Дарницький', '0')
# ('Гостинний', 'провулок', 'Дарницький', '2019')
# ('Гостомельська', 'вулиця', 'Святошинський', '0')
# ('Гостомельська', 'вулиця', 'Святошинський', '2014')
# ('Гостомельська', 'площа', 'Святошинський', '0')
# ('Гостомельська', 'площа', 'Святошинський', '2014')
# ('Гостомельське', 'шосе', 'Оболонський', '0')
# ('Грабовського Павла', 'вулиця', 'Голосіївський', '2003')
# ('Грабовського Павла', 'вулиця', 'Голосіївський', '2009')
# ('Грабовського Павла', 'провулок', 'Голосіївський', '2003')
# ('Грабовського Павла', 'провулок', 'Голосіївський', '2009')
# ('Градинська', 'вулиця', 'Деснянський', '1964')
# ('Гранична', 'вулиця', 'Святошинський', '1986')
# ('Гребінки', 'вулиця', 'Голосіївський', '0')
# ('Грекова Академіка', 'вулиця', 'Шевченківський', '2011')
# ('Гречаний', 'провулок', 'Дарницький', '0')
# ('Григоренка Петра', 'проспект', 'Дарницький', '0')
# ('Григорія Голоскевича', 'вулиця', 'Голосіївський', '2018')
# ('Григорія Косинки', 'вулиця', 'Деснянський', '0')
# ('Григоровича-Барського', 'вулиця', 'Святошинський', '0')
# ('Гришка Миколи', 'вулиця', 'Деснянський', '2010')
# ('Гришка Михайла', 'вулиця', 'Дарницький', '2017')
# ('Грінченка Бориса', 'вулиця', 'Шевченківський', '2017')
# ('Грінченка Миколи', 'вулиця', 'Голосіївський, Солом’янський', '0')
# ('Гродненська', 'вулиця', 'Дніпровський', '1955')
# ('Гродненський', 'провулок', 'Дніпровський', '0')
# ('Грозненська', 'вулиця', 'Шевченківський', '2018')
# ('Громадська', 'вулиця', 'Солом’янський', '2014')
# ('Громової Уляни', 'вулиця', 'Солом’янський', '0')
# ('Грузинська', 'вулиця', 'Дарницький', '0')
# ('Грузинський', 'провулок', 'Дарницький', '2015')
# ('Грушева', 'вулиця', "Солом'янський", '2002')
# ('Грушевського Михайла', 'вулиця', 'Печерський', '2016')
# ('Гулака Миколи', 'вулиця', 'Оболонський', '2019')
# ('Гурамішвілі Давида', 'вулиця', 'Святошинський', '0')
# ('Гусовського', 'вулиця', 'Печерський', '0')
# ('Гучний', 'провулок', 'Солом’янський', '2019')
# ('Ґалаґанівська', 'вулиця', 'Святошинський', '0')
# ('Ґренджі-Донського', 'вулиця', "Солом'янський", '1975')
# ('Далека', 'вулиця', "Солом'янський", '2017')
# ('Даля Олександра', 'вулиця', 'Деснянський', '2010')
# ('Дамбова', 'вулиця', 'Дніпровський', '1977')
# ('Дамбова 1', 'вулиця', 'Дніпровський', '2019')
# ('Дамбова 2', 'вулиця', 'Дніпровський', '0')
# ('Дамбова 3', 'вулиця', 'Дніпровський', '2019')
# ('Данченка Сергія', 'вулиця', 'Подільський', '2013')
# ('Данькевича Костянтина', 'вулиця', 'Деснянський', '2018')
# ('Дарвіна', 'вулиця', 'Печерський', '2019')
# ('Дарницька', 'площа', 'Дніпровський', '2018')
# ('Дарницький', 'бульвар', 'Дніпровський', '2009')
# ('Дачна', 'вулиця', 'Деснянський', '0')
# ('Дачний', 'провулок', 'Деснянський', '1961')
# ('Дашавська', 'вулиця', "Солом'янський", '2003')
# ('Двінська', 'вулиця', 'Дніпровський', '2018')
# ('Дегтярівська', 'вулиця', 'Шевченківський', '2008')
# ('Дегтярна', 'вулиця', 'Подільський', '1967')
# ('Дежнєва', 'вулиця', "Солом'янський", '1936')
# ('Дежнєва', 'вулиця', "Солом'янський", '2017')
# ('Дежнєва', 'провулок', "Солом'янський", '1936')
# ('Дежнєва', 'провулок', "Солом'янський", '2017')
# ('Декабристів', 'вулиця', 'Дарницький', '0')
# ('Делегатський', 'провулок', 'Шевченківський', '2010')
# ('Демидівська', 'вулиця', 'Дарницький', '2019')
# ('Деміївська', 'площа', 'Голосіївський', '2012')
# ('Деміївська', 'площа', 'Голосіївський', '2013')
# ('Деміївська', 'вулиця', 'Голосіївський', '2012')
# ('Деміївська', 'вулиця', 'Голосіївський', '2013')
# ('Деміївський', 'провулок', 'Голосіївський', '0')
# ('Депутатська', 'вулиця', 'Святошинський', '0')
# ('Деревлянська', 'вулиця', 'Шевченківський', '0')
# ('Деревообробна', 'вулиця', 'Голосіївський', '2013')
# ('Деревообробний', 'провулок', 'Голосіївський', '0')
# ('Десенський ', 'провулок', 'Деснянський', None)
# ('Деснянська', 'вулиця', "Солом'янський", '1985')
# ('Деснянська', 'вулиця', "Солом'янський", '1989')
# ('Деснянська', 'вулиця', "Солом'янський", '2018')
# ('Деснянська', 'вулиця', 'Деснянський', '1985')
# ('Деснянська', 'вулиця', 'Деснянський', '1989')
# ('Деснянська', 'вулиця', 'Деснянський', '2018')
# ('Деснянська', 'вулиця', 'Дніпровський', '1985')
# ('Деснянська', 'вулиця', 'Дніпровський', '1989')
# ('Деснянська', 'вулиця', 'Дніпровський', '2018')
# ('Деснянський', 'провулок', 'Деснянський', '2019')
# ('Десятинна', 'вулиця', 'Шевченківський', '1998')
# ('Десятинний', 'провулок', 'Шевченківський', '2013')
# ('Джаліля Муси', 'вулиця', 'Подільський', '2008')
# ('Джеймса Мейса', 'вулиця', "Солом'янський", '2015')
# ('Джерельна', 'вулиця', 'Оболонський', '0')
# ('Джерельна', 'вулиця', 'Оболонський', '2019')
# ('Джерельна', 'вулиця', 'Дарницький', '0')
# ('Джерельна', 'вулиця', 'Дарницький', '2019')
# ('Джерельний', 'провулок', 'Оболонський', '2018')
# ('Джона Маккейна', 'вулиця', 'Печерський', '2006')
# ('Дзиґи Вертова', 'провулок', 'Дніпровський', '1972')
# ('Диканський', 'провулок', 'Дарницький', '1976')
# ('Димерська', 'вулиця', 'Святошинський', '1914')
# ('Діамантовий', 'провулок', 'Деснянський', '0')
# ('Дібровна ', 'вулиця', 'Голосіївський', None)
# ('Дібровний', 'провулок', 'Голосіївський', '2008')
# ('Ділова', 'вулиця', 'Голосіївський, Печерський', '2017')
# ('Дмитра Григоровича', 'вулиця', 'Солом’янський', '1973')
# ('Дмитра Загула', 'вулиця', 'Деснянський', '1956')
# ('Дмитрівська', 'вулиця', 'Шевченківський', '1981')
# ('Дмитрівська', 'вулиця', 'Шевченківський', '2020')
# ('Дмитрівська', 'вулиця', 'Подільський', '1981')
# ('Дмитрівська', 'вулиця', 'Подільський', '2020')
# ('Дніпрова', 'вулиця', 'Дарницький', '0')
# ('Дніпровий', 'провулок', 'Дарницький', '0')
# ('Дніпроводська', 'вулиця', 'Оболонський', '0')
# ('Дніпровська', 'вулиця', 'Оболонський', '1940')
# ('Дніпровська', 'вулиця', 'Оболонський', '2005')
# ('Дніпровська ', 'набережна', 'Дніпровський, Дарницький', None)
# ('Дніпровське', 'шосе', 'Голосіївський', '0')
# ('Дніпровський ', 'узвіз', 'Печерський', None)
# ('Дністровська', 'вулиця', "Солом'янський", '2018')
# ('Добрий Шлях', 'вулиця', 'Голосіївський', '2010')
# ('Добринінська', 'вулиця', 'Оболонський', '2022')
# ('Добробутна', 'вулиця', "Солом'янський", '2006')
# ('Добровольчих батальйонів', 'вулиця', 'Печерський', '1957')
# ('Добролюбова', 'вулиця', 'Печерський', '2004')
# ('Добролюбова', 'вулиця', 'Печерський', '2019')
# ('Добролюбова', 'провулок', 'Печерський', '2004')
# ('Добролюбова', 'провулок', 'Печерський', '2019')
# ('Добросусідська', 'вулиця', "Солом'янський", '2016')
# ('Добросусідський', 'провулок', "Солом'янський", '1977')
# ('Доброхотова Академіка', 'вулиця', 'Святошинський', '0')
# ('Добрузька', 'вулиця', "Солом'янський", '1973')
# ('Доватора Генерала', 'вулиця', 'Голосіївський', '0')
# ('Доватора Генерала', 'вулиця', 'Голосіївський', '0')
# ('Доватора Генерала', 'провулок', 'Голосіївський', '0')
# ('Доватора Генерала', 'провулок', 'Голосіївський', '0')
# ('Довбуша Олекси', 'вулиця', 'Дніпровський', '2015')
# ('Довженка', 'вулиця', 'Деснянський', '2018')
# ('Довженка Олександра', 'вулиця', 'Шевченківський', '1910')
# ('Докучаєвська', 'вулиця', "Солом'янський", '0')
# ('Докучаєвський', 'тупик', "Солом'янський", '1967')
# ('Докучаєвський', 'тупик', "Солом'янський", '1972')
# ('Докучаєвський', 'провулок', "Солом'янський", '1967')
# ('Докучаєвський', 'провулок', "Солом'янський", '1972')
# ('Долинна', 'вулиця', "Солом'янський", '2010')
# ('Донецька', 'вулиця', "Солом'янський", '0')
# ('Донецький', 'провулок', "Солом'янський", '2013')
# ('Донська', 'вулиця', "Солом'янський", '2013')
# ('Донський', 'провулок', "Солом'янський", '1961')
# ('Донця Михайла', 'вулиця', "Солом'янський", '2017')
# ('Дончука Василя', 'вулиця', 'Шевченківський', '0')
# ('Дорогожицька', 'вулиця', 'Шевченківський', '2005')
# ('Достоєвського', 'провулок', 'Подільський', '2007')
# ('Достоєвського', 'провулок', 'Подільський', '2017')
# ('Достоєвського', 'вулиця', 'Подільський', '2007')
# ('Достоєвського', 'вулиця', 'Подільський', '2017')
# ('Драгоманова', 'вулиця', 'Дарницький', '0')
# ('Драгомирова Михайла', 'вулиця', 'Печерський', '1955')
# ('Драйзера Теодора', 'вулиця', 'Деснянський', '2020')
# ('Драй-Хмари Михайла', 'вулиця', 'Святошинський', '0')
# ('Друга', 'вулиця', 'Оболонський', '0')
# ('Дружби', 'вулиця', 'Дарницький', '2013')
# ('Дружби 1', 'провулок', 'Дарницький', '2013')
# ('Дружби 2', 'провулок', 'Дарницький', '1977')
# ('Дружби 3', 'провулок', 'Дарницький', '0')
# ('Дружби Народів', 'бульвар', 'Печерський', '0')
# ('Дружківська', 'вулиця', 'Святошинський', '0')
# ('Дружня', 'вулиця', "Солом'янський", '0')
# ('Дубенська', 'вулиця', 'Печерський', '1954')
# ('Дубичнянська', 'вулиця', 'Деснянський', '1972')
# ('Дубищанська', 'вулиця', 'Оболонський', '0')
# ('Дубищанський', 'провулок', 'Оболонський', '2018')
# ('Дубініна Володі', 'вулиця', 'Голосіївський', '2018')
# ('Дубка (Озерна 15)', 'вулиця', 'Дарницький', '1957')
# ('Дубровицька', 'вулиця', 'Оболонський', '2009')
# ('Дубровицький', 'провулок', 'Оболонський', '0')
# ('Дубровського Віктора', 'провулок', 'Святошинський', '2019')
# ('Дудника Георгія', 'вулиця', 'Шевченківський', '0')
# ('Дуки Степана', 'вулиця', 'Голосіївський', '0')
# ('Дунаєвського', 'вулиця', 'Святошинський', '2005')
# ('Дунаєвського', 'вулиця', 'Святошинський', '2018')
# ('Дунаєвського', 'провулок', 'Святошинський', '2005')
# ('Дунаєвського', 'провулок', 'Святошинський', '2018')
# ('Дурдуківського Володимира', 'вулиця', 'Святошинський', '2017')
# ('Дяченка Івана', 'вулиця', 'Дарницький', '2011')
# ('Екскаваторна', 'вулиця', 'Святошинський', '0')
# ('Електриків', 'вулиця', 'Подільський', '1977')
# ('Електриків', 'вулиця', 'Подільський', '2015')
# ('Електриків', 'провулок', 'Подільський', '1977')
# ('Електриків', 'провулок', 'Подільський', '2015')
# ('Електротехнічна', 'вулиця', 'Деснянський', '1987')
# ('Енгельса', 'провулок', 'Дарницький', '0')
# ('Енгельса', 'провулок', 'Дарницький', '1995')
# ('Енгельса', 'вулиця', 'Дарницький', '0')
# ('Енгельса', 'вулиця', 'Дарницький', '1995')
# ('Енергетиків', 'вулиця', "Солом'янський", '1961')
# ('Енергетиків', 'вулиця', "Солом'янський", '2000')
# ('Енергетиків', 'вулиця', "Солом'янський", '2005')
# ('Енергетиків', 'вулиця', 'Дніпровський', '1961')
# ('Енергетиків', 'вулиця', 'Дніпровський', '2000')
# ('Енергетиків', 'вулиця', 'Дніпровський', '2005')
# ('Енергетиків', 'провулок', "Солом'янський", '1961')
# ('Енергетиків', 'провулок', "Солом'янський", '2000')
# ('Енергетиків', 'провулок', "Солом'янський", '2005')
# ('Ентузіастів', 'вулиця', 'Дніпровський', '2008')
# ('Ентузіастів 1', 'вулиця', 'Дарницький', '2018')
# ('Ентузіастів 10', 'вулиця', 'Дарницький', '2014')
# ('Ентузіастів 2', 'вулиця', 'Дарницький', '0')
# ('Ентузіастів 3', 'вулиця', 'Дарницький', '0')
# ('Ентузіастів 4', 'вулиця', 'Дарницький', '2010')
# ('Ентузіастів 5', 'вулиця', 'Дарницький', '1966')
# ('Ентузіастів 6', 'вулиця', 'Дарницький', '0')
# ('Ентузіастів 7', 'вулиця', 'Дарницький', '2005')
# ('Ентузіастів 8', 'вулиця', 'Дарницький', '2015')
# ('Ентузіастів 9', 'вулиця', 'Дарницький', '0')
# ('Еренбурга Іллі', 'вулиця', 'Голосіївський', '1962')
# ('Ернста Федора', 'вулиця', "Солом'янський", '2015')
# ('Еспланадна', 'вулиця', 'Печерський', '2012')
# ('Естонська', 'вулиця', 'Шевченківський', '1903')
# ('Естонський', 'провулок', 'Шевченківський', '1998')
# ('Євгена Гуцала', 'провулок', 'Печерський', '2016')
# ('Євгена Коновальця', 'вулиця', 'Печерський', '2020')
# ('Євгена Плужника', 'вулиця', 'Деснянський', '1938')
# ('Євгена Сверстюка', 'вулиця', 'Дніпровський', '0')
# ('Європейська', 'площа', 'Печерський', '0')
# ('Єдності', 'вулиця', 'Деснянський', '1966')
# ('Єжи Ґедройця', 'вулиця', 'Голосіївський, Печерський', '1937')
# ('Єнісейська', 'вулиця', 'Голосіївський', '2019')
# ('Єреванська', 'вулиця', "Солом'янський", '2019')
# ('Єрмака', 'вулиця', 'Оболонський', '0')
# ('Єсеніна Сергія', 'вулиця', 'Святошинський', '2019')
# ('Жабаєва Жамбила', 'вулиця', 'Шевченківський', '1985')
# ('Жашківська', 'вулиця', 'Подільський', '0')
# ('Живописна', 'вулиця', 'Святошинський', '1981')
# ('Жигулівська', 'вулиця', 'Голосіївський', '0')
# ('Жилянська', 'вулиця', 'Печерський, Голосіївський, Шевченківський', '2011')
# ('Житкова Бориса', 'вулиця', 'Шевченківський', '0')
# ('Житньоторзька', 'вулиця', 'Подільський', '0')
# ('Житньоторзька', 'вулиця', 'Подільський', '1983')
# ('Житньоторзька', 'площа', 'Подільський', '0')
# ('Житньоторзька', 'площа', 'Подільський', '1983')
# ('Жмаченка Генерала', 'вулиця', 'Дніпровський', '0')
# ('Жмеринська', 'вулиця', 'Святошинський', '2018')
# ('Жмеринський', 'провулок', 'Святошинський', '0')
# ('Жовтнева', 'вулиця', 'Святошинський', '2019')
# ('Жовтневий', 'провулок', 'Святошинський', '2004')
# ('Жолудєва', 'вулиця', 'Святошинський', '2014')
# ('Жуків Затон', 'вулиця', 'Голосіївський', '2017')
# ('Жуковського Василя', 'провулок', 'Голосіївський', '2000')
# ('Жуковського Василя', 'провулок', 'Голосіївський', '2004')
# ('Жуковського Василя', 'вулиця', 'Голосіївський', '2000')
# ('Жуковського Василя', 'вулиця', 'Голосіївський', '2004')
# ('Жулянська', 'вулиця', 'Голосіївський', '2012')
# ('Журавлина', 'вулиця', 'Дарницький', '0')
# ('Журавлина', 'вулиця', 'Дарницький', '2019')
# ('Журавлина', 'вулиця', "Солом'янський", '0')
# ('Журавлина', 'вулиця', "Солом'янський", '2019')
# ('Забайківська', 'вулиця', 'Голосіївський', '2017')
# ('Забіли Віктора', 'вулиця', 'Голосіївський', '2001')
# ('Заболотний', 'провулок', 'Голосіївський', '1948')
# ('Заболотного Академіка', 'вулиця', 'Голосіївський', '0')
# ('Завальна', 'вулиця', 'Дарницький', '2013')
# ('Заводська', 'вулиця', 'Подільський', '2018')
# ('Заводський', 'провулок', 'Дарницький', '2018')
# ('Заглади Леоніли', 'вулиця', 'Дарницький', '2017')
# ('Загороднього Михайла', 'площа', 'Оболонський', '2010')
# ('Загородня', 'вулиця', 'Голосіївський', '0')
# ('Задніпровського Михайла', 'вулиця', 'Печерський', '0')
# ('Задорожний', 'провулок', 'Голосіївський', '1987')
# ('Заканальна', 'вулиця', 'Дарницький', '2018')
# ('Закарпатська', 'вулиця', 'Голосіївський', '1973')
# ('Закревського Миколи', 'вулиця', 'Деснянський', '1969')
# ('Заливна', 'вулиця', 'Голосіївський', '2015')
# ('Залізнична', 'вулиця', "Солом'янський", '2014')
# ('Залізнична', 'вулиця', "Солом'янський", '2016')
# ('Залізнична', 'вулиця', 'Дніпровський', '2014')
# ('Залізнична', 'вулиця', 'Дніпровський', '2016')
# ('Залізнична 1', 'вулиця', 'Дніпровський', '0')
# ('Залізнична 2', 'вулиця', 'Дніпровський', '1965')
# ('Залізнична 3', 'вулиця', 'Дніпровський', '2016')
# ('Залізнична 4', 'вулиця', 'Дніпровський', '2004')
# ('Залізничне', 'шосе', 'Печерський', '0')
# ('Залізняка Максима', 'вулиця', 'Святошинський', '2011')
# ('Залісна', 'вулиця', "Солом'янський", '0')
# ('Заломова Петра', 'вулиця', "Солом'янський", '0')
# ('Залужна ', 'вулиця', 'Голосіївський', None)
# ('Залужний ', 'провулок', 'Голосіївський', None)
# ('Заміський', 'провулок', 'Дарницький', '0')
# ('Замковецька', 'вулиця', 'Подільський', '2008')
# ('Замковецький', 'провулок', 'Подільський', '0')
# ('Заньковецької', 'вулиця', 'Печерський', '2018')
# ('Заозерний', 'провулок', 'Деснянський', '2016')
# ('Западинська', 'вулиця', 'Подільський', '0')
# ('Запашний', 'провулок', 'Дарницький', '2006')
# ('Запечерний', 'провулок', 'Печерський', '0')
# ('Заплавна', 'вулиця', 'Дарницький', '2019')
# ('Заплавний', 'провулок', 'Дарницький', '0')
# ('Заповітна', 'вулиця', "Солом'янський", '1963')
# ('Заповітний', 'провулок', "Солом'янський", '2014')
# ('Запорізька', 'вулиця', "Солом'янський", '2017')
# ('Запорожця Петра', 'вулиця', 'Дніпровський', '0')
# ('Запорожця Петра', 'вулиця', 'Дніпровський', '1911')
# ('Запорожця Петра', 'вулиця', 'Деснянський', '0')
# ('Запорожця Петра', 'вулиця', 'Деснянський', '1911')
# ('Заремби Владислава', 'провулок', 'Голосіївський', '0')
# ('Зарічна', 'вулиця', 'Дарницький', '1969')
# ('Зарубинецька', 'вулиця', 'Подільський', '0')
# ('Заслонова Костянтина', 'вулиця', 'Дарницький', '1967')
# ('Затєвахіна Полковника', 'вулиця', 'Голосіївський', '2019')
# ('Затишна', 'вулиця', 'Дарницький', '2019')
# ('Захарівська', 'вулиця', 'Подільський', '1965')
# ('Захисників', 'провулок', 'Деснянський', '2020')
# ('Західна', 'вулиця', "Солом'янський", '2012')
# ('Західний', 'провулок', "Солом'янський", '0')
# ('Звенигородська', 'вулиця', 'Святошинський', '1963')
# ('Звіринецька', 'вулиця', 'Печерський', '1995')
# ('Звіринецький', 'провулок', 'Печерський', '0')
# ("Зв'язківців", 'вулиця', 'Святошинський', '0')
# ('Згурівська', 'вулиця', "Солом'янський", '1959')
# ('Здолбунівська', 'вулиця', 'Дарницький', '2014')
# ('Зелена', 'вулиця', "Солом'янський", '0')
# ('Зелена', 'вулиця', "Солом'янський", '2013')
# ('Зелена', 'вулиця', "Солом'янський", '2014')
# ('Зелена', 'вулиця', 'Дніпровський', '0')
# ('Зелена', 'вулиця', 'Дніпровський', '2013')
# ('Зелена', 'вулиця', 'Дніпровський', '2014')
# ('Зелена', 'вулиця', 'Шевченківський', '0')
# ('Зелена', 'вулиця', 'Шевченківський', '2013')
# ('Зелена', 'вулиця', 'Шевченківський', '2014')
# ('Зеленогірська', 'вулиця', "Солом'янський", '2017')
# ('Зелінського Академіка', 'провулок', 'Подільський', '1917')
# ('Землянична', 'вулиця', 'Подільський', '2019')
# ('Землянська', 'вулиця', 'Печерський', '0')
# ('Землянський', 'провулок', 'Печерський', '0')
# ('Зенітна', 'вулиця', "Солом'янський", '2008')
# ('Зимова', 'вулиця', 'Подільський', '0')
# ('Златопільська', 'вулиця', "Солом'янський", '1962')
# ("Знам'янська", 'вулиця', "Солом'янський", '2014')
# ('Зовнішня', 'вулиця', 'Дарницький', '2018')
# ('Зодчих', 'вулиця', 'Святошинський', '0')
# ('Золота', 'вулиця', 'Дніпровський', '0')
# ('Золоті Джерела', 'вулиця', 'Голосіївський', '0')
# ('Золотоворітська', 'вулиця', 'Шевченківський', '1977')
# ('Золотоворітський', 'проїзд', 'Шевченківський', '2006')
# ('Золотоніська', 'вулиця', 'Голосіївський', '0')
# ('Золотоустівська', 'вулиця', 'Шевченківський', '2017')
# ('Золочевська', 'вулиця', 'Подільський', '1972')
# ('Золочевський', 'провулок', 'Подільський', '2018')
# ('Зоологічна', 'вулиця', 'Шевченківський', '0')
# ('Зоотехніків', 'вулиця', 'Дарницький', '1977')
# ('Зорге Ріхарда', 'вулиця', 'Святошинський', '0')
# ('Зоряна', 'вулиця', 'Подільський', '0')
# ('Зоряна', 'вулиця', 'Подільський', '0')
# ('Зоряна', 'вулиця', "Солом'янський", '0')
# ('Зоряна', 'вулиця', "Солом'янський", '0')
# ('Зоряний', 'провулок', 'Подільський', '0')
# ('Зрошувальна', 'вулиця', 'Дарницький', '2016')
# ('Івана Білика', 'вулиця', "Солом'янський", '1987')
# ('Івана Виговського', 'вулиця', 'Подільський', '2020')
# ('Івана Рогача', 'вулиця', 'Деснянський', '0')
# ('Івашкевича Ярослава', 'вулиця', 'Оболонський', '2007')
# ('Івченка Михайла', 'провулок', 'Святошинський', '1993')
# ('Ігорівська', 'вулиця', 'Подільський', '0')
# ('Ігоря Диченка', 'вулиця', 'Голосіївський', '0')
# ('Їжакевича Івана', 'вулиця', 'Подільський', '2011')
# ('Іжевська', 'вулиця', 'Дарницький', '2006')
# ('Іжевський', 'провулок', 'Дарницький', '0')
# ('Ізюмська', 'вулиця', 'Голосіївський', '2001')
# ('Ізяславський', 'провулок', "Солом'янський", '1994')
# ('Іллінська', 'вулиця', 'Подільський', '0')
# ('Інгульський', 'провулок', 'Голосіївський', '1959')
# ('Індустріальний', 'провулок', "Солом'янський", '0')
# ('Інженера Бородіна', 'вулиця', 'Дніпровський', '1986')
# ('Інженерна', 'вулиця', 'Голосіївський', '0')
# ('Інженерна', 'вулиця', 'Голосіївський', '0')
# ('Інженерна', 'вулиця', 'Дарницький', '0')
# ('Інженерна', 'вулиця', 'Дарницький', '0')
# ('Інженерний', 'провулок', 'Печерський', '0')
# ('Інженерний', 'провулок', 'Печерський', '1997')
# ('Інженерний', 'провулок', 'Дарницький', '0')
# ('Інженерний', 'провулок', 'Дарницький', '1997')
# ('Інститутська', 'вулиця', 'Печерський', '2012')
# ('Іоанна Павла ІІ', 'вулиця', 'Печерський', '2016')
# ('Іпсилантіївський', 'провулок', 'Печерський', '2001')
# ('Ірининська', 'вулиця', 'Шевченківський', '0')
# ('Ірпінська', 'вулиця', 'Святошинський', '0')
# ('Іртишська', 'вулиця', 'Голосіївський', '1917')
# ('Ірчана Мирослава', 'вулиця', 'Святошинський', '2017')
# ('Ісаакяна', 'вулиця', 'Шевченківський', '1990')
# ('Іси Мунаєва', 'вулиця', 'Деснянський', '2007')
# ('Іскрівська', 'вулиця', "Солом'янський", '1977')
# ('Йова Борецького', 'провулок', 'Печерський', '0')
# ('Йорданська', 'вулиця', 'Оболонський', '2021')
# ('Кабельна ', 'вулиця', 'Оболонський', None)
# ('Каблукова Академіка', 'вулиця', "Солом'янський", '1997')
# ('Кавалерідзе Івана', 'вулиця', 'Подільський', '2013')
# ('Кавказька', 'вулиця', "Солом'янський", '0')
# ('Кадетський Гай ', 'вулиця', "Солом'янський", None)
# ('Кадіївська', 'вулиця', 'Деснянський', None)
# ('Кадіївський', 'провулок', 'Деснянський', None)
# ('Казанська', 'вулиця', 'Оболонський', None)
# ('Кайсарова', 'вулиця', "Голосіївський,Солом'янський", None)
# ('Калачівська', 'вулиця', 'Дніпровський', None)
# ('Калинова', 'вулиця', 'Шевченківський', None)
# ('Калиновий Ріг', 'проїзд', 'Оболонський', None)
# ('Калиновий Ріг', 'вулиця', 'Оболонський', None)
# ('Калнишевського Петра', 'вулиця', 'Оболонський', None)
# ...
# ('Тимірязєвська', 'вулиця', 'Печерський', None)
# ('Тимірязєвський', 'провулок', 'Печерський', None)
# ('Тимошенка Маршала', 'вулиця', 'Оболонський', None)
# ('Тираспольська', 'вулиця', 'Подільський', None)
# ('Тиха ', 'вулиця', 'Печерський', None)
# ('Тихвінський', 'провулок', 'Голосіївський', None)
# ('Тихонівський', 'провулок', 'Голосіївський', None)
# ('Тихорецька', 'вулиця', 'Голосіївський', None)
# ('Тихорецький', 'провулок', 'Голосіївський', None)
# ('Тичини Павла', 'проспект', 'Дніпровський', None)
# ('Тобольський', 'провулок', 'Голосіївський', None)
# ('Товарна', 'вулиця', 'Печерський', None)
# ('Тодося Осьмачки', 'вулиця', 'Деснянський', None)
# ('Толбухіна', 'вулиця', 'Шевченківський', None)
# ('Толбухіна', 'провулок', 'Шевченківський', None)
# ('Толочанська', 'вулиця', 'Деснянський', None)
# ('Толстого', 'провулок', 'Дарницький', None)
# ('Толстого Льва', 'вулиця', "Шевченківський, Солом'янський, Голосіївський", None)
# ('Толстого Льва', 'площа', 'Шевченківський', None)
# ('Толстого Льва', 'вулиця', 'Дарницький', None)
# ('Томашевська', 'вулиця', 'Деснянський', None)
# ('Томашпільська', 'вулиця', 'Дарницький', None)
# ('Тополева ', 'вулиця', "Солом'янський", None)
# ('Тороповського Георгія', 'вулиця', 'Дніпровський', None)
# ('Травнева', 'вулиця', "Солом'янський", None)
# ('Травнева', 'вулиця', 'Дніпровський', None)
# ('Травневий', 'провулок', "Солом'янський", None)
# ('Трактористів', 'вулиця', 'Дніпровський', None)
# ('Траншейна', 'вулиця', "Солом'янський", None)
# ('Трахтемирівська', 'вулиця', 'Голосіївський', None)
# ('Третя', 'вулиця', 'Оболонський', None)
# ('Трипільська', 'вулиця', 'Дарницький', None)
# ('Троїцька', 'площа', 'Печерський', None)
# ('Тропініна', 'провулок', 'Шевченківський', None)
# ('Тропініна', 'вулиця', 'Шевченківський', None)
# ('Тростянецька ', 'вулиця', 'Дарницький', None)
# ('Трояндова', 'вулиця', 'Дарницький', None)
# ('Трояндова', 'вулиця', "Солом'янський", None)
# ('Трублаїні ', 'вулиця', 'Святошинський', None)
# ('Трудова ', 'вулиця', 'Шевченківський', None)
# ('Трускавецька', 'вулиця', 'Дарницький', None)
# ('Труханівська', 'вулиця', 'Дніпровський', None)
# ('Трьохсвятительська', 'вулиця', 'Шевченківський', None)
# ('Тулузи', 'вулиця', 'Святошинський', None)
# ('Тульська', 'площа', 'Оболонський', None)
# ('Тульський', 'провулок', 'Голосіївський', None)
# ('Тульчинська', 'вулиця', 'Подільський', None)
# ('Туманяна Ованеса', 'вулиця', 'Дніпровський', None)
# ('Тупиковий 1', 'провулок', 'Дарницький', None)
# ('Тупиковий 2', 'провулок', 'Дарницький', None)
# ('Тупиковий 3', 'провулок', 'Дарницький', None)
# ('Тупікова Генерала', 'вулиця', "Солом'янський", None)
# ('Туполєва Академіка', 'вулиця', 'Святошинський, Шевченківський', None)
# ('Тургенєва', 'вулиця', 'Деснянський', None)
# ('Тургенєва', 'провулок', 'Дарницький', None)
# ('Тургенєва Івана', 'вулиця', 'Дарницький', None)
# ('Тургенєвська', 'вулиця', 'Шевченківський', None)
# ('Турівська', 'вулиця', 'Подільський', None)
# ('Турчина Ігоря', 'вулиця', 'Шевченківський', None)
# ('Тутковського Академіка', 'вулиця', "Солом'янський", None)
# ('Ужвій Наталії', 'вулиця', 'Подільський', None)
# ('Ужгородська', 'вулиця', 'Голосіївський', None)
# ('Ужгородський', 'провулок', 'Голосіївський', None)
# ('Узинська', 'вулиця', 'Святошинський', None)
# ('Українська', 'вулиця', 'Шевченківський', None)
# ('Улітіна Івана', 'вулиця', 'Святошинський', None)
# ('Уманська', 'вулиця', "Солом'янський", None)
# ('Університетська', 'вулиця', "Солом'янський", None)
# ('Уральська', 'вулиця', 'Голосіївський', None)
# ('Уральський', 'провулок', 'Голосіївський', None)
# ('Урлівська', 'вулиця', 'Дарницький', None)
# ('Урожайна', 'вулиця', 'Дарницький', None)
# ('Усенка Павла', 'вулиця', 'Дніпровський', None)
# ('Успішна', 'вулиця', 'Голосіївський', None)
# ('Уссурійська', 'вулиця', 'Шевченківський', None)
# ('Уссурійський', 'провулок', 'Шевченківський', None)
# ('Устинівський', 'провулок', "Солом'янський", None)
# ('Учбова', 'вулиця', 'Голосіївський', None)
# ('Учбовий', 'провулок', 'Голосіївський', None)
# ('Учительський', 'провулок', "Солом'янський", None)
# ('Ушакова Адмірала', 'вулиця', 'Голосіївський', None)
# ('Ушакова Миколи', 'вулиця', 'Святошинський', None)
# ('Ушинського', 'провулок', "Солом'янський", None)
# ('Ушинського', 'вулиця', "Солом'янський", None)
# ('Ушицька', 'вулиця', 'Деснянський', None)
# ('Фанерна', 'вулиця', 'Дніпровський', None)
# ('Фанерний', 'провулок', 'Дніпровський', None)
# ('Фастівська', 'вулиця', "Солом'янський", None)
# ('Федора Андерса', 'вулиця', 'Солом’янський', None)
# ('Федорова Івана', 'вулиця', "Голосіївський, Печерський, Солом'янський", None)
# ('Федосєєва', 'вулиця', "Солом'янський", None)
# ('Федосєєва', 'провулок', "Солом'янський", None)
# ('Федьковича', 'вулиця', "Солом'янський", None)
# ('Федьковича', 'провулок', "Солом'янський", None)
# ('Феодосійська', 'вулиця', 'Голосіївський', None)
# ('Феодосійський', 'провулок', 'Голосіївський', None)
# ('Феодосія Печерського', 'вулиця', 'Голосіївський', None)
# ('Феофанівський', 'провулок', 'Голосіївський', None)
# ('Фестивальна', 'вулиця', 'Голосіївський', None)
# ('Фіалкова', 'вулиця', 'Голосіївський', None)
# ('Фізкультури', 'вулиця', 'Голосіївський, Печерський', None)
# ('Фізкультури', 'провулок', 'Голосіївський', None)
# ('Філатова Академіка', 'вулиця', 'Печерський', None)
# ('Філатова Академіка', 'провулок', 'Печерський', None)
# ('Фісташкова', 'вулиця', 'Дарницький', None)
# ('Флоренції', 'вулиця', 'Дніпровський', None)
# ('Франка Івана', 'вулиця', 'Шевченківський', None)
# ('Франка Івана', 'площа', 'Печерський', None)
# ('Франка Івана', 'вулиця', 'Дарницький', None)
# ('Франка Івана', 'провулок', 'Дарницький', None)
# ('Франка Івана 1', 'провулок', 'Дарницький', None)
# ('Франка Івана 2', 'провулок', 'Дарницький', None)
# ('Франка Івана 3', 'провулок', 'Дарницький', None)
# ('Франка Івана 4', 'провулок', 'Дарницький', None)
# ('Фролівська', 'вулиця', 'Подільський', None)
# ('Фролівський', 'провулок', 'Подільський', None)
# ('Фрометівська', 'вулиця', 'Голосіївський', None)
# ('Фрометівський', 'узвіз', 'Голосіївський', None)
# ('Фруктова', 'вулиця', 'Подільський', None)
# ('Фузиків', 'провулок', 'Шевченківський', None)
# ('Фучика Юліуса', 'вулиця', "Солом'янський", None)
# ('Харківська', 'площа', 'Дарницький', None)
# ('Харківське', 'шосе', 'Дніпровський, Дарницький', None)
# ('Харківський ', 'провулок', 'Дарницький', None)
# ('Харченка Євгена', 'вулиця', 'Дарницький', None)
# ('Хвойки Вікентія', 'вулиця', 'Подільський, Оболонський', None)
# ('Хвойна', 'вулиця', 'Дарницький', None)
# ('Хлібний', 'провулок', 'Дарницький', None)
# ('Хмельницька', 'вулиця', 'Святошинський', None)
# ('Хмельницького Богдана', 'вулиця', 'Шевченківський', None)
# ('Хмельницького Богдана', 'вулиця', 'Деснянський', None)
# ('Холмогорська', 'вулиця', 'Голосіївський', None)
# ('Холмогорський', 'провулок', 'Голосіївський', None)
# ('Хомова Ярослава', 'провулок', "Солом'янський", None)
# ('Хорива', 'провулок', 'Подільський', None)
# ('Хорива', 'вулиця', 'Подільський', None)
# ('Хорольська', 'вулиця', 'Дніпровський', None)
# ('Хорольський', 'провулок', 'Дніпровський', None)
# ('Хортицька', 'вулиця', 'Голосіївський', None)
# ('Хортицький', 'провулок', 'Голосіївський', None)
# ('Хотинська', 'вулиця', 'Подільський', None)
# ('Хотівська', 'вулиця', 'Голосіївський', None)
# ('Хоткевича Гната', 'провулок', 'Деснянський,Дніпровський ', None)
# ('Хоткевича Гната', 'вулиця', 'Деснянський,Дніпровський ', None)
# ('Хотянівська', 'вулиця', 'Оболонський', None)
# ('Хотянівська', 'вулиця', 'Деснянський', None)
# ('Хохлова Костянтина', 'вулиця', 'Голосіївський', None)
# ("Хохлових Сім'ї", 'вулиця', 'Шевченківський', None)
# ('Хрестовий', 'провулок', 'Печерський', None)
# ('Хрещатик', 'вулиця', 'Печерський, Шевченківський', None)
# ('Хутірська', 'вулиця', 'Голосіївський', None)
# ('Хутірський', 'провулок', 'Голосіївський', None)
# ('Хутоярівський', 'провулок', 'Голосіївський', None)
# ('Царика Григорія', 'вулиця', 'Печерський', None)
# ('Цвєтаєвої Марини', 'вулиця', 'Деснянський', None)
# ('Цегельна ', 'вулиця', 'Дніпровський', None)
# ('Цегельний ', 'провулок', 'Голосіївський', None)
# ('Центральна', 'вулиця', 'Дніпровський', None)
# ('Центральна', 'вулиця', 'Оболонський', None)
# ('Центральна', 'вулиця', 'Шевченківський', None)
# ('Центральна ', 'вулиця', 'Дарницький', None)
# ('Центральна Садова', 'вулиця', 'Дніпровський', None)
# ('Цеткін Клари', 'вулиця', 'Оболонський', None)
# ('Цимбалів Яр', 'провулок', 'Голосіївський', None)
# ('Цимбалів Яр', 'вулиця', 'Голосіївський', None)
# ('Цимлянський ', 'провулок', 'Подільський', None)
# ('Цитадельна', 'вулиця', 'Печерський', None)
# ('Цілинна', 'вулиця', 'Голосіївський', None)
# ('Ціолковського', 'вулиця', 'Голосіївський', None)
# ('Ціолковського', 'провулок', 'Голосіївський', None)
# ('Цукровий', 'провулок', 'Подільський', None)
# ('Цулукідзе', 'вулиця', 'Шевченківський', None)
# ('Чаадаєва Петра', 'вулиця', 'Дніпровський', None)
# ('Чаадаєва Петра', 'вулиця', 'Святошинський', None)
# ('Чабанівська', 'вулиця', 'Голосіївський', None)
# ('Чавдар Єлизавети', 'вулиця', 'Дарницький', None)
# ('Чайківська', 'вулиця', 'Святошинський', None)
# ('Чайкіної Лізи ', 'вулиця', 'Печерський', None)
# ('Чайковського', 'вулиця', 'Дарницький', None)
# ('Чалого Михайла', 'вулиця', 'Святошинський', None)
# ('Чаплигіна', 'провулок', 'Шевченківський', None)
# ('Чаплигіна', 'вулиця', 'Шевченківський', None)
# ('Челюскінців', 'вулиця', 'Дарницький', None)
# ('Челябінська', 'вулиця', 'Дніпровський', None)
# ('Червона', 'вулиця', "Солом'янський", None)
# ('Червона Калина', 'вулиця', 'Дарницький', None)
# ('Червоний', 'провулок', "Солом'янський", None)
# ('Червонозаводська', 'вулиця', 'Святошинський', None)
# ('Червонозаводський', 'провулок', 'Святошинський', None)
# ('Червонопільська ', 'вулиця', 'Подільський', None)
# ('Червоноткацька ', 'вулиця', 'Деснянський,Дніпровський ', None)
# ('Черешневий ', 'провулок', 'Голосіївський', None)
# ('Черкаська', 'вулиця', 'Шевченківський', None)
# ('Чернишевського', 'вулиця', "Солом'янський", None)
# ('Чернівецька', 'вулиця', "Солом'янський", None)
# ('Чернігівська', 'площа', 'Деснянський, Дніпровський', None)
# ('Чернігівська', 'вулиця', 'Дарницький', None)
# ('Чернігівська', 'вулиця', 'Дніпровський', None)
# ('Чернігівський', 'провулок', 'Дарницький', None)
# ('Черняховського', 'вулиця', 'Шевченківський', None)
# ('Чеська', 'вулиця', 'Печерський', None)
# ('Четверта', 'вулиця', 'Оболонський', None)
# ('Чехова', 'вулиця', 'Дарницький', None)
# ('Чехова 1', 'провулок', 'Дарницький', None)
# ('Чехова 2', 'провулок', 'Дарницький', None)
# ('Чеховський', 'провулок', 'Шевченківський', None)
# ('Чигиринська', 'вулиця', 'Подільський', None)
# ('Чигиринський', 'провулок', 'Подільський', None)
# ('Чигоріна', 'вулиця', 'Печерський', None)
# ('Чистяківська', 'вулиця', 'Святошинський', None)
# ('Чистяківський', 'провулок', 'Святошинський', None)
# ('Чкалова', 'вулиця', 'Дарницький', None)
# ('Чоколівський', 'бульвар', "Солом'янський", None)
# ('Чорнична (Озерна 8)', 'вулиця', 'Дарницький', None)
# ('Чорнобильська', 'вулиця', 'Святошинський', None)
# ('Чорнобильський', 'провулок', 'Святошинський', None)
# ("Чорновола В'ячеслава", 'вулиця', 'Шевченківський', None)
# ('Чорногірська', 'вулиця', 'Печерський', None)
# ('Чорноморська', 'вулиця', 'Оболонський', None)
# ('Чугуївський ', 'провулок', "Солом'янський", None)
# ('Чумака Василя', 'вулиця', "Солом'янський", None)
# ('Чупринки Григорія', 'вулиця', 'Дніпровський', None)
# ('Чурилівська', 'вулиця', 'Деснянський', None)
# ('Шалетт Міста', 'вулиця', 'Дніпровський', None)
# ('Шамо Ігоря', 'бульвар', 'Дніпровський', None)
# ('Шахтарська', 'вулиця', 'Оболонський', None)
# ('Шевельова Юрія', 'вулиця', 'Дарницький', None)
# ('Шевченка', 'вулиця', 'Деснянський', None)
# ('Шевченка', 'вулиця', "Солом'янський", None)
# ('Шевченка', 'провулок', "Солом'янський", None)
# ('Шевченка', 'вулиця', 'Дарницький', None)
# ('Шевченка', 'провулок', 'Дарницький', None)
# ('Шевченка Тараса', 'бульвар', 'Шевченківський', None)
# ('Шевченка Тараса', 'провулок', 'Шевченківський', None)
# ('Шевченка Тараса', 'площа', 'Оболонський', None)
# ('Шепелєва Миколи', 'вулиця', "Солом'янський", None)
# ('Шепетівська', 'вулиця', 'Святошинський', None)
# ('Шимановського Віталія', 'вулиця', 'Дніпровський', None)
# ('Широка', 'вулиця', 'Голосіївський', None)
# ('Шишкінський', 'провулок', 'Шевченківський', None)
# ('Шкільна', 'вулиця', 'Голосіївський', None)
# ('Шкільна', 'вулиця', 'Святошинський', None)
# ('Шкільна', 'вулиця', "Солом'янський", None)
# ('Шкільна', 'вулиця', 'Дарницький', None)
# ('Шляховиків', 'вулиця', 'Дніпровський', None)
# ('Шляховиків', 'провулок', 'Дніпровський', None)
# ('Шмідта Отто', 'вулиця', 'Шевченківський', None)
# ('Шовковична', 'вулиця', 'Печерський', None)
# ('Шовкуненка', 'вулиця', "Солом'янський", None)
# ('Шолом-Алейхема', 'вулиця', 'Деснянський', None)
# ('Шолуденка', 'вулиця', 'Шевченківський', None)
# ('Шоста', 'вулиця', 'Оболонський', None)
# ('Шпака Миколи', 'вулиця', 'Шевченківський', None)
# ('Шпильова', 'вулиця', "Солом'янський", None)
# ('Шполянська', 'вулиця', 'Подільський', None)
# ('Шульгина Володимира', 'вулиця', 'Святошинський', None)
# ('Шульгина Якова', 'провулок', 'Святошинський', None)
# ('Шулявська', 'вулиця', 'Шевченківський', None)
# ('Шумського Юрія', 'вулиця', 'Дніпровський', None)
# ('Шутова Полковника', 'вулиця', "Солом'янський", None)
# ('Щаслива', 'вулиця', 'Голосіївський', None)
# ('Щасливий', 'провулок', 'Дарницький', None)
# ('Щекавицька', 'площа', 'Подільський', None)
# ('Щекавицька', 'вулиця', 'Подільський', None)
# ('Щепкіна', 'вулиця', 'Дніпровський', None)
# ('Щербаківського Данила', 'вулиця', 'Шевченківський', None)
# ('Щоглівський', 'провулок', 'Голосіївський', None)
# ('Щусєва', 'вулиця', 'Шевченківський', None)
# ('Щусєва', 'провулок', 'Шевченківський', None)
# ('Юлаєва Салавата', 'вулиця', 'Голосіївський', None)
# ('Юнацька', 'вулиця', 'Святошинський', None)
# ('Юнацька', 'вулиця', "Солом'янський", None)
# ('Юнкерова Миколи', 'вулиця', 'Оболонський', None)
# ('Юності', 'вулиця', 'Дніпровський', None)
# ('Юри Гната', 'вулиця', 'Святошинський', None)
# ('Юрівський', 'провулок', 'Голосіївський', None)
# ('Юрія Глушка', 'вулиця', 'Шевченківський', None)
# ('Юрія Іллєнка', 'вулиця', 'Шевченківський', None)
# ('Юрія Липи', 'вулиця', 'Дніпровський', None)
# ('Юрія Литвинського', 'вулиця', 'Дарницький', None)
# ('Юрія Немирича', 'вулиця', 'Голосіївський', None)
# ('Юрія Поправки', 'вулиця', 'Дніпровський', None)
# ('Юрківська', 'вулиця', 'Подільський', None)
# ('Юровської Ольги', 'вулиця', 'Голосіївський', None)
# ('Яблонської Тетяни', 'вулиця', "Солом'янський", None)
# ('Яблочкова', 'вулиця', 'Подільський', None)
# ('Яблочкова', 'провулок', 'Подільський', None)
# ('Яблунева', 'вулиця', "Солом'янський", None)
# ('Яблуневий', 'провулок', "Солом'янський", None)
# ('Яворівський', 'провулок', 'Деснянський', None)
# ('Яворницького Дмитра', 'вулиця', 'Святошинський', None)
# ('Ягідна', 'вулиця', 'Голосіївський', None)
# ('Ягідний', 'провулок', 'Голосіївський', None)
# ('Яготинська', 'вулиця', 'Печерський', None)
# ('Якова Щоголева', 'провулок', 'Дарницький', None)
# ('Якуба Коласа', 'вулиця', 'Святошинський', None)
# ('Якубовских Родини', 'провулок', 'Голосіївський', None)
# ('Якубовського Маршала', 'вулиця', 'Голосіївський', None)
# ('Якутська', 'вулиця', 'Святошинський', None)
# ('Ялинкова', 'вулиця', 'Дарницький', None)
# ('Ялинковий', 'провулок', 'Дарницький', None)
# ('Ялинковий', 'провулок', 'Дарницький', None)
# ('Ялтинська', 'вулиця', 'Дарницький', None)
# ('Ямська', 'вулиця', 'Голосіївський', None)
# ('Яна Василя', 'вулиця', 'Голосіївський', None)
# ('Яна Райніса', 'вулиця', "Солом'янський", None)
# ('Янгеля Академіка', 'вулиця', "Солом'янський", None)
# ('Янки Купали', 'вулиця', "Солом'янський", None)
# ('Янтарна', 'вулиця', 'Святошинський', None)
# ('Януша Корчака', 'вулиця', 'Шевченківський', None)
# ('Ярмоли Віктора', 'вулиця', 'Шевченківський', None)
# ('Яровий', 'провулок', "Солом'янський", None)
# ('Ярослави Стецько', 'вулиця', 'Деснянський', None)
# ('Ярославів Вал', 'вулиця', 'Шевченківський', None)
# ('Ярославська', 'вулиця', 'Подільський', None)
# ('Ярославський', 'провулок', 'Подільський', None)
# ('Ясеневий', 'провулок', 'Печерський', None)
# ('Ясинуватський', 'провулок', 'Голосіївський', None)
# ('Яслинська', 'вулиця', "Солом'янський", None)
# ('Ясна', 'вулиця', "Солом'янський", None)
# ('Ясний', 'провулок', "Солом'янський", None)
# ('Ясногірська', 'вулиця', 'Шевченківський', None)
# ('Яснополянська', 'вулиця', 'Святошинський', None)

# %% [markdown]
# #### для аналізу скористатися бібліотекою NumPy

# %%
import numpy as np

# %%
# створити np-масив з списку `result_list`
result_arr = np.array(result_list)
print(type (result_arr), result_arr.shape)
year_result = np.delete(result_arr, [0,1,2], 1)
year_result[year_result == None] = 0
year_result = list(map(int, year_result))
print(year_result)
# Out:
# <class 'numpy.ndarray'> (5968, 4)
# [2015, 0, 1902, 2011, 0, 1902, 2011, 0, 1902, 2011, 2014, 2009, 2018, 0, 2017, 1980, 2012, 0, 2018, 1985, 2017, 1981, 2016, 0, 1987, 0, 2016, 1976, 1960, 1966, 1964, 2008, 0, 0, 2007, 0, 1916, 0, 1916, 0, 2013, 2019, 0, 2009, 2017, 0, 0, 2016, 1986, 2019, 1977, 0, 2018, 1983, 0, 1963, 2014, 1906, 1962, 0, 2017, 2009, 0, 0, 0, 2010, 1969, 0, 1983, 1892, 0, 2006, 2017, 0, 0, 0, 2008, 2010, 1990, 2018, 2014, 1906, 1962, 0, 2017, 2009, 2002, 1990, 1971, 2010, 1969, 0, 1983, 1892, 0, 2006, 2017, 0, 0, 0, 2008, 2010, 1990, 2018, 1994, 2016, 2014, 0, 0, 1962, 2017, 2013, 0, 1969, 0, 2020, 0, 2004, 2008, 2004, 2008, 2018, 2013, 0, 2017, 2020, 2011, 0, 2018, 2019, 2019, 1957, 2001, 1957, 2001, 2017, 2018, 2013, 2007, 0, 2020, 0, 0, 2015, 0, 1963, 2019, 2013, 0, 2018, 1981, 0, 2015, 2005, 2003, 0, 2019, 1971, 0, 1980, 1959, 2014, 0, 0, 1980, 2019, 1993, 2003, 2017, 1996, 0, 0, 1914, 2005, 0, 0, 0, 0, 1999, 2007, 2009, 2014, 2005, 2017, 2007, 0, 0, 0, 0, 1977, 2014, 1977, 2014, 1974, 2005, 1974, 2005, 1958, 0, 2017, 0, 2005, 2012, 2005, 2012, 1964, 2015, 2017, 0, 2011, 1964, 2016, 0, 2021, 1946, 2017, 1977, 2018, 0, 2013, 2015, 2013, 2015, 2001, 0, 2015, 0, 2003, 1963, 0, 1895, 0, 0, 0, 0, 1970, 2001, 0, 0, 1970, 2001, 0, 0, 1970, 2001, 0, 0, 1970, 2001, 1973, 0, 2010, 0, 1979, 0, 1979, 2002, 2018, 2005, 0, 2019, 1975, 2005, 2010, 2005, 2010, 2020, 1986, 0, 2005, 2018, 2011, 2018, 1971, 2020, 1971, 2020, 1960, 2005, 0, 2006, 1969, 2015, 0, 2006, 2019, 0, 2007, 0, 1973, 2012, 2017, 1997, 1936, 2005, 1971, 0, 1883, 2010, 2016, 2016, 2001, 0, 2015, 0, 0, 0, 0, 0, 2013, 0, 0, 0, 1982, 0, 0, 1983, 0, 0, 2013, 2014, 2013, 2019, 0, 1905, 0, 2012, 1959, 2016, 0, 0, 1973, 0, 1973, 0, 2009, 0, 0, 2003, 1971, 0, 0, 1982, 1983, 2015, 0, 1982, 1983, 2015, 0, 1982, 1983, 2015, 0, 1982, 1983, 2015, 0, 1961, 2019, 0, 0, 2018, 2016, 2020, 2018, 0, 2006, 0, 0, 2015, 2014, 0, 2004, 0, 2018, 2012, 2015, 2018, 1977, 2012, 2006, 2015, 1966, 2019, 2018, 0, 0, 2014, 0, 0, 2017, 0, 2017, 1879, 2018, 1879, 2018, 1991, 0, 0, 1961, 2017, 0, 1913, 0, 0, 1999, 1961, 0, 0, 0, 0, 2013, 0, 2013, 2013, 0, 1993, 0, 2016, 2018, 0, 2015, 2019, 0, 0, 2010, 2005, 2011, 2007, 2009, 0, 2003, 2014, 1999, 2018, 2020, 2018, 1972, 2018, 2011, 0, 2019, 0, 2019, 2007, 0, 1978, 1858, 1974, 2017, 0, 2008, 0, 0, 2007, 2014, 2016, 1993, 1978, 0, 2016, 0, 2016, 1936, 0, 2005, 1959, 2001, 2015, 1988, 1981, 1936, 2019, 2005, 0, 1965, 2018, 0, 1965, 2018, 0, 1965, 2018, 0, 2010, 2014, 2016, 2002, 0, 0, 1963, 2005, 2016, 2018, 2015, 1985, 2007, 2010, 2007, 2010, 0, 0, 1970, 2014, 0, 1970, 2014, 0, 1970, 2014, 1975, 2014, 2012, 0, 2019, 0, 2019, 1974, 2019, 1974, 2019, 1975, 2002, 1998, 2016, 2016, 2012, 0, 2008, 2013, 1969, 2020, 1913, 2017, 2017, 2020, 0, 1954, 0, 1936, 2016, 2018, 0, 2019, 0, 2014, 0, 2014, 0, 2003, 2009, 2003, 2009, 1964, 1986, 0, 2011, 0, 0, 2018, 0, 0, 2010, 2017, 2017, 0, 1955, 0, 2018, 2014, 0, 0, 2015, 2002, 2016, 2019, 0, 0, 2019, 0, 1975, 2017, 2010, 1977, 2019, 0, 2019, 2013, 2018, 2019, 2018, 2009, 0, 1961, 2003, 2018, 2008, 1967, 1936, 2017, 1936, 2017, 0, 2010, 2019, 2012, 2013, 2012, 2013, 0, 0, 0, 2013, 0, 0, 1985, 1989, 2018, 1985, 1989, 2018, 1985, 1989, 2018, 2019, 1998, 2013, 2008, 2015, 0, 2019, 0, 2019, 2018, 2006, 1972, 1976, 1914, 0, 0, 2008, 2017, 1973, 1956, 1981, 2020, 1981, 2020, 0, 0, 0, 1940, 2005, 0, 0, 0, 2018, 2010, 2022, 2006, 1957, 2004, 2019, 2004, 2019, 2016, 1977, 0, 1973, 0, 0, 0, 0, 2015, 2018, 1910, 0, 1967, 1972, 1967, 1972, 2010, 0, 2013, 2013, 1961, 2017, 0, 2005, 2007, 2017, 2007, 2017, 0, 1955, 2020, 0, 0, 2013, 2013, 1977, 0, 0, 0, 0, 1954, 1972, 0, 2018, 2018, 1957, 2009, 0, 2019, 0, 0, 2005, 2018, 2005, 2018, 2017, 2011, 0, 1977, 2015, 1977, 2015, 1987, 0, 1995, 0, 1995, 1961, 2000, 2005, 1961, 2000, 2005, 1961, 2000, 2005, 2008, 2018, 2014, 0, 0, 2010, 1966, 0, 2005, 2015, 0, 1962, 2015, 2012, 1903, 1998, 2016, 2020, 1938, 0, 0, 1966, 1937, 2019, 2019, 0, 2019, 1985, 0, 1981, 0, 2011, 0, 0, 1983, 0, 1983, 0, 2018, 0, 2019, 200 ...

# %%
# побудувати словник для результатів аналізу
result_dict = {
    "кількість спостережень"   : len(year_result) ,
    "середнє значення"         : round(np.mean(year_result),1) ,
    "максимальне значення"     : np.max(year_result) ,
    "мінімальне значення"      : np.min(year_result) ,
    "стандартне відхилення"    : round(np.std(year_result),1),
    "розмах вариації"          : np.max(year_result) - np.min(year_result)
    }

# %%
# вивести шапку
print(
"""
================================================
№  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ     
================================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1
# Out:
# ================================================
# №  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ
# ================================================
#
# 1   кількість спостережень     5968
# 2   середнє значення           430.3
# 3   максимальне значення       2022
# 4   мінімальне значення        0
# 5   стандартне відхилення      821.1
# 6   розмах вариації            2022
